# %%
import pandas as pd
import numpy as np 
import re

# %%
# The file that includes the slot and intent information.
df = pd.read_excel("Appliance Slot Intent.xlsx",encoding = "ISO-8859-1", sheet_name="Main V4.")
# The file that includes the types of values inside that slot. 
slot_df = pd.read_excel("Appliance Slot Intent.xlsx",encoding = "ISO-8859-1", sheet_name="Slot Description V4.")

# %%
# print slot intent dataframe
df.head()
# Out:
#   QUESTION_LABEL                                    TARGET_QUESTION  \
# 0            buy  Where can I buy a @parts for my @appliance?\nI...
# 1         locate  Where can I locate the @object on the @applian...
# 2        Purpose  What is the purpose of the @with_feature_objec...
# 3           cook  What must I do to cook @food with the @applian...
# 4           cook  How can I @cooking_feature the @food with the ...
#
#                                   INTENT_DESCRIPTION  \
# 0  The sentence specifies that the user wants to ...
# 1  The sentence specifies that the user wants to ...
# 2  The sentence asks for a purpose of a feature.\...
# 3  The sentence asks how to prepare a certain typ...
# 4  The sentence asks how to use a feature to cook...
#
#                                     EXAMPLE_SENTENCE  \
# 0  Where can I buy a glass tray for my microwave?...
# 1  Where can I locate the model number on the mic...
# 2  What is the purpose of the warming center feat...
# 3  What must I do to cook popcorn with the microw...
# 4  How can I reheat the chicken with my oven?\nHo...
#
#              QUESTION_SHOULD_CONTAIN
# 0                  @parts @appliance
# 1                 @object @appliance
# 2    @with_feature_object @appliance
# 3                   @food @appliance
# 4  @food @cooking_feature @appliance

# %%
# print slot dataframe
slot_df.head()
# Out:
#             Slot                                        Description  \
# 0         @parts  A Physical part from an appliance.\nSomething ...
# 1     @appliance  Any type of appliance. This slot is \nused to ...
# 2        @object                        Anything that is physical.
# 3       @feature  Features that has settings that can be \nmanip...
# 4  @with_feature  Features that has settings that can be \nmanip...
#
#                                             Examples  \
# 0  door, light, storage drawer, exhaust adaptor, ...
# 1                                        microwavawe
# 2  door, light, storage-drawer, exhaust-adaptor, ...
# 3  cooking, boiling, melting, surface-cooking, so...
# 4  cooking feature, boiling feature, melting feat...
#
#                                    Extra Explanation
# 0  The following slot values are items that can b...
# 1  This slot describes the appliance that the use...
# 2  This slot is the larger set which contains all...
# 3                                                NaN
# 4                                                NaN

# %%
# Slot dataframe trimmed so that the Description is removed. 
slot_df_ = slot_df.iloc[:,[0,2]]

# %%
# replace the Example column with an array of the values separated by a comma
slot_df_['Examples'] = slot_df_["Examples"].apply(lambda x: x.split(', '))
# Out:
# C:\Users\l.kwon\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# dictionary of the slots. Key: slot value: possible vallues of the slot. 
slot_dict = dict(zip(slot_df_.Slot, slot_df_.Examples))

# %%
# Split the TARGET_QUESTION column and make it into an array of questions
df.iloc[:,1] = df.iloc[:,1].apply(lambda x: x.split('\n'))

# %%
#Temporary extract the TARGET_QUESTION column that was processed above. 
target = df.iloc[:,1]
# for s in range(len(temp)):
#     for j in range(len(temp[s])):
#         print(temp[s][j])
#     print("-----------------------------------------------")

# %%
df
# Out:
#                      QUESTION_LABEL  \
# 0                               buy
# 1                            locate
# 2                           Purpose
# 3                              cook
# 4                              cook
# 5                  Information Code
# 6                         Existance
# 7                           Options
# 8                             image
# 9                            remove
# 10                        reinstall
# 11                      appropriate
# 12                            clean
# 13  how to\nInstructions\n(General)
# 14                              set
# 15                  Time\n(setting)
# 16           Speed Level\n(setting)
# 17           Power Level\n(setting)
# 18                    on\n(Setting)
# 19                   off\n(Setting)
#
#                                       TARGET_QUESTION  \
# 0   [Where can I buy a @parts for my @appliance?, ...
# 1   [Where can I locate the @object on the @applia...
# 2   [What is the purpose of the @with_feature_obje...
# 3   [What must I do to cook @food with the @applia...
# 4   [How can I @cooking_feature the @food with the...
# 5   [What does @info_code mean on my @appliance?, ...
# 6   [Is there an @feature_object feature in the @a...
# 7   [What are the different options of the @with_f...
# 8   [What does the @object look like in the @appli...
# 9   [How do I remove @removeable_parts from the @a...
# 10  [How do I reinstall @replaceable_parts from th...
# 11  [Is it safe to use @cookware in a @appliance?,...
# 12  [How do I clean the @cleanable on the @applian...
# 13  [How can I use the @with_feature_object on the...
# 14  [How do I set the @with_feature on my @applian...
# 15       [How do I change the time on the @appliance]
# 16  [How do I set the speed levels of the @feature...
# 17  [How do I change the power levels of the @feat...
# 18  [How do I turn on the @with_feature on the @ap...
# 19  [How do I switch the @with_feature off on the ...
#
#                                    INTENT_DESCRIPTION  \
# 0   The sentence specifies that the user wants to ...
# 1   The sentence specifies that the user wants to ...
# 2   The sentence asks for a purpose of a feature.\...
# 3   The sentence asks how to prepare a certain typ...
# 4   The sentence asks how to use a feature to cook...
# 5   The sentence is asking about the\nmeaning of t...
# 6   The sentence is asking if a certain function e...
# 7   The sentence asks about the different settings...
# 8        The sentence asks how an object looks like.
# 9   The sentence asks how to remove something\nfro...
# 10  The sentence asks how to reinstall something\n...
# 11  A sentence that asks if it is safe to use a ce...
# 12  The sentence asks how to clean a part of the a...
# 13  A sentence that describes the user wanting\nto...
# 14                                                NaN
# 15  The sentence specifies that the user wants to ...
# 16  The sentence specifies that the user wants to ...
# 17  The sentence specifies that the user wants to ...
# 18  The sentence specifies that the user wants to ...
# 19  The sentence specifies that the user wants to ...
#
#                                      EXAMPLE_SENTENCE  \
# 0   Where can I buy a glass tray for my microwave?...
# 1   Where can I locate the model number on the mic...
# 2   What is the purpose of the warming center feat...
# 3   What must I do to cook popcorn with the microw...
# 4   How can I reheat the chicken with my oven?\nHo...
# 5   What is the c-d0 mean on my oven?\nMy microwav...
# 6   Is there an autocook function in the oven?\nDo...
# 7   What are the different options of the Cook fea...
# 8   What does the Wire racks Look Like in the Micr...
# 9   How do I remove burned-on residue from the ove...
# 10  How do I reinstall the storage drawer from the...
# 11  Is it safe to use Glassware in the microwave?\...
# 12  How do I clean the glass cooktop on the oven?\...
# 13  How can I use the soften feature on the microw...
# 14           How do I set the Timer on the microwave?
# 15         How to I change the time on the Microwave?
# 16  How do I set the speed level of the fan on the...
# 17  How do I change the power levels with the bake...
# 18       How do I turn on the fan on the Microwave?\n
# 19  How do I switch the beeper off the Oven?\nHow ...
#
#               QUESTION_SHOULD_CONTAIN
# 0                   @parts @appliance
# 1                  @object @appliance
# 2     @with_feature_object @appliance
# 3                    @food @appliance
# 4   @food @cooking_feature @appliance
# 5               @info_code @appliance
# 6          @feature_object @appliance
# 7            @with_feature @appliance
# 8                  @object @appliance
# 9        @removeable_parts @appliance
# 10      @replaceable_parts @appliance
# 11               @cookware @appliance
# 12              @cleanable @appliance
# 13    @with_feature_object @appliance
# 14           @with_feature @appliance
# 15                         @appliance
# 16    @feature_speed_level @appliance
# 17    @feature_power_level @appliance
# 18           @with_feature @appliance
# 19           @with_feature @appliance

# %%
#creating the slots for each dictionary
slots = df.iloc[:,4].apply(lambda x: x.split(' '))

# %%
target_dic = df.iloc[:,[0,1]]

# %%
# for s in range(len(target)):
#     for j in range(len(target[s])):
#         print(target[s][j])
#     print("-----------------------------------------------")

# %%
# Print out all the sentences. 
# for s in range(len(temp)): #Intent number
#     for j in range(len(temp[s])): #Sentence in the intent
#         for i in range(len(slot_dict[slots[s][0]])): #Parts slot 1
#             for k in range(len(slot_dict[slots[s][1]])):
#                 x = temp[s][j]
#                 x = re.sub(slots[s][0], slot_dict[slots[s][0]][i], x)
#                 x = re.sub(slots[s][1], slot_dict[slots[s][1]][k], x)
#                 print(x)        
#     print("-----------------------------------------------")

# %%
i = 0
for s in range(len(target)): #Intent number
    print(len(slots[s]))
    for j in range(len(target[s])): #Sentence in the intent
        if (len(slots[s]) == 2):
            print("two slots")
            i += two_slots(s,j)    
        elif (len(slots[s]) == 3):
            print("three slots")
            i += three_slots(s,j)
        elif (len(slots[s]) == 1):
            print("one slot")
            i += one_slot(s,j)
    print("-----------------------------------------------")
    
print(i)
# Out:
# 2
# two slots
# Where can I buy a door for my microwavawe?
# Where can I buy a light for my microwavawe?
# Where can I buy a storage drawer for my microwavawe?
# Where can I buy a exhaust adaptor for my microwavawe?
# Where can I buy a grease filter for my microwavawe?
# Where can I buy a characol filter for my microwavawe?
# Where can I buy a wire rack for my microwavawe?
# Where can I buy a air fry tray for my microwavawe?
# Where can I buy a glass tray for my microwavawe?
# Where can I buy a grill rack for my microwavawe?
# Where can I buy a screw for my microwavawe?
# Where can I buy a bracket for my microwavawe?
# two slots
# I want to get a new door for my microwavawe.
# I want to get a new light for my microwavawe.
# I want to get a new storage drawer for my microwavawe.
# I want to get a new exhaust adaptor for my microwavawe.
# I want to get a new grease filter for my microwavawe.
# I want to get a new characol filter for my microwavawe.
# I want to get a new wire rack for my microwavawe.
# I want to get a new air fry tray for my microwavawe.
# I want to get a new glass tray for my microwavawe.
# I want to get a new grill rack for my microwavawe.
# I want to get a new screw for my microwavawe.
# I want to get a new bracket for my microwavawe.
# two slots
# How can I purchase a door for my microwavawe?
# How can I purchase a light for my microwavawe?
# How can I purchase a storage drawer for my microwavawe?
# How can I purchase a exhaust adaptor for my microwavawe?
# How can I purchase a grease filter for my microwavawe?
# How can I purchase a characol filter for my microwavawe?
# How can I purchase a wire rack for my microwavawe?
# How can I purchase a air fry tray for my microwavawe?
# How can I purchase a glass tray for my microwavawe?
# How can I purchase a grill rack for my microwavawe?
# How can I purchase a screw for my microwavawe?
# How can I purchase a bracket for my microwavawe?
# -----------------------------------------------
# 2
# two slots
# Where can I locate the door on the microwavawe?
# Where can I locate the light on the microwavawe?
# Where can I locate the storage-drawer on the microwavawe?
# Where can I locate the exhaust-adaptor on the microwavawe?
# Where can I locate the grease-filter on the microwavawe?
# Where can I locate the characol-filter on the microwavawe?
# Where can I locate the wire-rack on the microwavawe?
# Where can I locate the air-fry tray on the microwavawe?
# Where can I locate the glass-tray on the microwavawe?
# Where can I locate the grill-rack on the microwavawe?
# Where can I locate the cooking-button on the microwavawe?
# Where can I locate the melting-button on the microwavawe?
# Where can I locate the surface-cooking-button on the microwavawe?
# Where can I locate the softening-button on the microwavawe?
# Where can I locate the airfry-button on the microwavawe?
# Where can I locate the boiling-button on the microwavawe?
# Where can I locate the keep-warm-button on the microwavawe?
# Where can I locate the dehydrate-button on the microwavawe?
# Where can I locate the autocook-button on the microwavawe?
# Where can I locate the grill-button on the microwavawe?
# Where can I locate the microwave-grill-button on the microwavawe?
# Where can I locate the defrost-button on the microwavawe?
# Where can I locate the delay-start-button on the microwavawe?
# Where can I locate the fan-button on the microwavawe?
# Where can I locate the fan on the microwavawe?
# Where can I locate the power-defrost-button on the microwavawe?
# Where can I locate the reheat-button on the microwavawe?
# Where can I locate the auto-defrost-button on the microwavawe?
# Where can I locate the self-clean-button on the microwavawe?
# Where can I locate the timer-button on the microwavawe?
# Where can I locate the smart-control-button on the microwavawe?
# Where can I locate the lamp on the microwavawe?
# Where can I locate the lamp-button on the microwavawe?
# Where can I locate the lightings on the microwavawe?
# Where can I locate the clock-settings on the microwavawe?
# Where can I locate the child-lock on the microwavawe?
# Where can I locate the timer on the microwavawe?
# Where can I locate the echo-mode-button on the microwavawe?
# Where can I locate the child-lock-button on the microwavawe?
# Where can I locate the beeper on the microwavawe?
# Where can I locate the smart-controls on the microwavawe?
# Where can I locate the left-rear on the microwavawe?
# Where can I locate the right-rear on the microwavawe?
# Where can I locate the left-front on the microwavawe?
# Where can I locate the right-front on the microwavawe?
# Where can I locate the heating-center on the microwavawe?
# Where can I locate the surface-controls on the microwavawe?
# Where can I locate the warming-center on the microwavawe?
# Where can I locate the vent-button on the microwavawe?
# Where can I locate the model-number on the microwavawe?
# Where can I locate the vent on the microwavawe?
# Where can I locate the sorage-drawer on the microwavawe?
# Where can I locate the broil-oven-heater on the microwavawe?
# Where can I locate the convection-system on the microwavawe?
# Where can I locate the option-key on the microwavawe?
# Where can I locate the touch-pad on the microwavawe?
# Where can I locate the number-pad on the microwavawe?
# two slots
# How can I find the door on the microwavawe?
# How can I find the light on the microwavawe?
# How can I find the storage-drawer on the microwavawe?
# How can I find the exhaust-adaptor on the microwavawe?
# How can I find the grease-filter on the microwavawe?
# How can I find the characol-filter on the microwavawe?
# How can I find the wire-rack on the microwavawe?
# How can I find the air-fry tray on the microwavawe?
# How can I find the glass-tray on the microwavawe?
# How can I find the grill-rack on the microwavawe?
# How can I find the cooking-button on the microwavawe?
# How can I find the melting-button on the microwavawe?
# How can I find the surface-cooking-button on the microwavawe?
# How can I find the softening-button on the microwavawe?
# How can I find the airfry-button on the microwavawe?
# How can I find the boiling-button on the microwavawe?
# How can I find the keep-warm-button on the microwavawe?
# How can I find the dehydrate-button on the microwavawe?
# How can I find the autocook-button on the microwavawe?
# How can I find the grill-button on the microwavawe?
# How can I find the microwave-grill-button on the microwavawe?
# How can I find the defrost-button on the microwavawe?
# How can I find the delay-start-button on the microwavawe?
# How can I find the fan-button on the microwavawe?
# How can I find the fan on the microwavawe?
# How can I find the power-defrost-button on the microwavawe?
# How can I find the reheat-button on the microwavawe?
# How can I find the auto-defrost-button on the microwavawe?
# How can I find the self-clean-button on the microwavawe?
# How can I find the timer-button on the microwavawe?
# How can I find the smart-control-button on the microwavawe?
# How can I find the lamp on the microwavawe?
# How can I find the lamp-button on the microwavawe?
# How can I find the lightings on the microwavawe?
# How can I find the clock-settings on the microwavawe?
# How can I find the child-lock on the microwavawe?
# How can I find the timer on the microwavawe?
# How can I find the echo-mode-button on the microwavawe?
# How can I find the child-lock-button on the microwavawe?
# How can I find the beeper on the microwavawe?
# How can I find the smart-controls on the microwavawe?
# How can I find the left-rear on the microwavawe?
# How can I find the right-rear on the microwavawe?
# How can I find the left-front on the microwavawe?
# How can I find the right-front on the microwavawe?
# How can I find the heating-center on the microwavawe?
# How can I find the surface-controls on the microwavawe?
# How can I find the warming-center on the microwavawe?
# How can I find the vent-button on the microwavawe?
# How can I find the model-number on the microwavawe?
# How can I find the vent on the microwavawe?
# How can I find the sorage-drawer on the microwavawe?
# How can I find the broil-oven-heater on the microwavawe?
# How can I find the convection-system on the microwavawe?
# How can I find the option-key on the microwavawe?
# How can I find the touch-pad on the microwavawe?
# How can I find the number-pad on the microwavawe?
# two slots
# Where is the door located on the microwavawe?
# Where is the light located on the microwavawe?
# Where is the storage-drawer located on the microwavawe?
# Where is the exhaust-adaptor located on the microwavawe?
# Where is the grease-filter located on the microwavawe?
# Where is the characol-filter located on the microwavawe?
# Where is the wire-rack located on the microwavawe?
# Where is the air-fry tray located on the microwavawe?
# Where is the glass-tray located on the microwavawe?
# Where is the grill-rack located on the microwavawe?
# Where is the cooking-button located on the microwavawe?
# Where is the melting-button located on the microwavawe?
# Where is the surface-cooking-button located on the microwavawe?
# Where is the softening-button located on the microwavawe?
# Where is the airfry-button located on the microwavawe?
# Where is the boiling-button located on the microwavawe?
# Where is the keep-warm-button located on the microwavawe?
# Where is the dehydrate-button located on the microwavawe?
# Where is the autocook-button located on the microwavawe?
# Where is the grill-button located on the microwavawe?
# Where is the microwave-grill-button located on the microwavawe?
# Where is the defrost-button located on the microwavawe?
# Where is the delay-start-button located on the microwavawe?
# Where is the fan-button located on the microwavawe?
# Where is the fan located on the microwavawe?
# Where is the power-defrost-button located on the microwavawe?
# Where is the reheat-button located on the microwavawe?
# Where is the auto-defrost-button located on the microwavawe?
# Where is the self-clean-button located on the microwavawe?
# Where is the timer-button located on the microwavawe?
# Where is the smart-control-button located on the microwavawe?
# Where is the lamp located on the microwavawe?
# Where is the lamp-button located on the microwavawe?
# Where is the lightings located on the microwavawe?
# Where is the clock-settings located on the microwavawe?
# Where is the child-lock located on the microwavawe?
# Where is the timer located on the microwavawe?
# Where is the echo-mode-button located on the microwavawe?
# Where is the child-lock-button located on the microwavawe?
# Where is the beeper located on the microwavawe?
# Where is the smart-controls located on the microwavawe?
# Where is the left-rear located on the microwavawe?
# Where is the right-rear located on the microwavawe?
# Where is the left-front located on the microwavawe?
# Where is the right-front located on the microwavawe?
# Where is the heating-center located on the microwavawe?
# Where is the surface-controls located on the microwavawe?
# Where is the warming-center located on the microwavawe?
# Where is the vent-button located on the microwavawe?
# Where is the model-number located on the microwavawe?
# Where is the vent located on the microwavawe?
# Where is the sorage-drawer located on the microwavawe?
# Where is the broil-oven-heater located on the microwavawe?
# Where is the convection-system located on the microwavawe?
# Where is the option-key located on the microwavawe?
# Where is the touch-pad located on the microwavawe?
# Where is the number-pad located on the microwavawe?
# -----------------------------------------------
# 2
# two slots
# What is the purpose of the cooking feature on the microwavawe?
# What is the purpose of the boiling feature on the microwavawe?
# What is the purpose of the melting feature on the microwavawe?
# What is the purpose of the surface-cooking feature on the microwavawe?
# What is the purpose of the softening feature on the microwavawe?
# What is the purpose of the airfry feature on the microwavawe?
# What is the purpose of the boil feature on the microwavawe?
# What is the purpose of the keep-warm feature on the microwavawe?
# What is the purpose of the dehydrate feature on the microwavawe?
# What is the purpose of the autocook feature on the microwavawe?
# What is the purpose of the grill feature on the microwavawe?
# What is the purpose of the microwave-grill feature on the microwavawe?
# What is the purpose of the defrost feature on the microwavawe?
# What is the purpose of the beeper on the microwavawe?
# What is the purpose of the power-defrost feature on the microwavawe?
# What is the purpose of the reheat feature on the microwavawe?
# What is the purpose of the auto-defrost feature on the microwavawe?
# What is the purpose of the baking-feature on the microwavawe?
# What is the purpose of the self-clean feature on the microwavawe?
# What is the purpose of the timer on the microwavawe?
# What is the purpose of the smart-control feature on the microwavawe?
# What is the purpose of the lamp on the microwavawe?
# What is the purpose of the lightings on the microwavawe?
# What is the purpose of the clock-setting on the microwavawe?
# What is the purpose of the child-lock on the microwavawe?
# What is the purpose of the fan on the microwavawe?
# What is the purpose of the echo-mode on the microwavawe?
# What is the purpose of the delay-start feature on the microwavawe?
# What is the purpose of the left-rear on the microwavawe?
# What is the purpose of the right-rear on the microwavawe?
# What is the purpose of the left-front on the microwavawe?
# What is the purpose of the right-front on the microwavawe?
# What is the purpose of the heating-center on the microwavawe?
# What is the purpose of the surface-control on the microwavawe?
# What is the purpose of the warming-center on the microwavawe?
# What is the purpose of the vent-button on the microwavawe?
# two slots
# What is microwavawes cooking feature for?
# What is microwavawes boiling feature for?
# What is microwavawes melting feature for?
# What is microwavawes surface-cooking feature for?
# What is microwavawes softening feature for?
# What is microwavawes airfry feature for?
# What is microwavawes boil feature for?
# What is microwavawes keep-warm feature for?
# What is microwavawes dehydrate feature for?
# What is microwavawes autocook feature for?
# What is microwavawes grill feature for?
# What is microwavawes microwave-grill feature for?
# What is microwavawes defrost feature for?
# What is microwavawes beeper for?
# What is microwavawes power-defrost feature for?
# What is microwavawes reheat feature for?
# What is microwavawes auto-defrost feature for?
# What is microwavawes baking-feature for?
# What is microwavawes self-clean feature for?
# What is microwavawes timer for?
# What is microwavawes smart-control feature for?
# What is microwavawes lamp for?
# What is microwavawes lightings for?
# What is microwavawes clock-setting for?
# What is microwavawes child-lock for?
# What is microwavawes fan for?
# What is microwavawes echo-mode for?
# What is microwavawes delay-start feature for?
# What is microwavawes left-rear for?
# What is microwavawes right-rear for?
# What is microwavawes left-front for?
# What is microwavawes right-front for?
# What is microwavawes heating-center for?
# What is microwavawes surface-control for?
# What is microwavawes warming-center for?
# What is microwavawes vent-button for?
# two slots
# What does the cooking feature do on the microwavawe?
# What does the boiling feature do on the microwavawe?
# What does the melting feature do on the microwavawe?
# What does the surface-cooking feature do on the microwavawe?
# What does the softening feature do on the microwavawe?
# What does the airfry feature do on the microwavawe?
# What does the boil feature do on the microwavawe?
# What does the keep-warm feature do on the microwavawe?
# What does the dehydrate feature do on the microwavawe?
# What does the autocook feature do on the microwavawe?
# What does the grill feature do on the microwavawe?
# What does the microwave-grill feature do on the microwavawe?
# What does the defrost feature do on the microwavawe?
# What does the beeper do on the microwavawe?
# What does the power-defrost feature do on the microwavawe?
# What does the reheat feature do on the microwavawe?
# What does the auto-defrost feature do on the microwavawe?
# What does the baking-feature do on the microwavawe?
# What does the self-clean feature do on the microwavawe?
# What does the timer do on the microwavawe?
# What does the smart-control feature do on the microwavawe?
# What does the lamp do on the microwavawe?
# What does the lightings do on the microwavawe?
# What does the clock-setting do on the microwavawe?
# What does the child-lock do on the microwavawe?
# What does the fan do on the microwavawe?
# What does the echo-mode do on the microwavawe?
# What does the delay-start feature do on the microwavawe?
# What does the left-rear do on the microwavawe?
# What does the right-rear do on the microwavawe?
# What does the left-front do on the microwavawe?
# What does the right-front do on the microwavawe?
# What does the heating-center do on the microwavawe?
# What does the surface-control do on the microwavawe?
# What does the warming-center do on the microwavawe?
# What does the vent-button do on the microwavawe?
# -----------------------------------------------
# 2
# two slots
# What must I do to cook pizza with the microwavawe?
# What must I do to cook potatoes with the microwavawe?
# What must I do to cook popcorn with the microwavawe?
# What must I do to cook chicken with the microwavawe?
# What must I do to cook beef with the microwavawe?
# What must I do to cook frozen french fries with the microwavawe?
# What must I do to cook tater tots with the microwavawe?
# What must I do to cook egg plants with the microwavawe?
# What must I do to cook mushrooms with the microwavawe?
# What must I do to cook Vegetable Mix. with the microwavawe?
# What must I do to cook fresh chicken wings with the microwavawe?
# What must I do to cook chicken Breasts with the microwavawe?
# What must I do to cook drinks with the microwavawe?
# What must I do to cook french fries with the microwavawe?
# two slots
# How do I cook the pizza with the microwavawe?
# How do I cook the potatoes with the microwavawe?
# How do I cook the popcorn with the microwavawe?
# How do I cook the chicken with the microwavawe?
# How do I cook the beef with the microwavawe?
# How do I cook the frozen french fries with the microwavawe?
# How do I cook the tater tots with the microwavawe?
# How do I cook the egg plants with the microwavawe?
# How do I cook the mushrooms with the microwavawe?
# How do I cook the Vegetable Mix. with the microwavawe?
# How do I cook the fresh chicken wings with the microwavawe?
# How do I cook the chicken Breasts with the microwavawe?
# How do I cook the drinks with the microwavawe?
# How do I cook the french fries with the microwavawe?
# two slots
# How do I use the microwavawe to prepare the pizza
# How do I use the microwavawe to prepare the potatoes
# How do I use the microwavawe to prepare the popcorn
# How do I use the microwavawe to prepare the chicken
# How do I use the microwavawe to prepare the beef
# How do I use the microwavawe to prepare the frozen french fries
# How do I use the microwavawe to prepare the tater tots
# How do I use the microwavawe to prepare the egg plants
# How do I use the microwavawe to prepare the mushrooms
# How do I use the microwavawe to prepare the Vegetable Mix.
# How do I use the microwavawe to prepare the fresh chicken wings
# How do I use the microwavawe to prepare the chicken Breasts
# How do I use the microwavawe to prepare the drinks
# How do I use the microwavawe to prepare the french fries
# -----------------------------------------------
# 3
# three slots
# How can I cook the pizza with the microwavawe?
# How can I boil the pizza with the microwavawe?
# How can I melt the pizza with the microwavawe?
# How can I soften the pizza with the microwavawe?
# How can I surface cook the pizza with the microwavawe?
# How can I airfry the pizza with the microwavawe?
# How can I boil the pizza with the microwavawe?
# How can I warm the pizza with the microwavawe?
# How can I dehydrate the pizza with the microwavawe?
# How can I autocook the pizza with the microwavawe?
# How can I grill the pizza with the microwavawe?
# How can I microwave-grill the pizza with the microwavawe?
# How can I defrost the pizza with the microwavawe?
# How can I power defrost the pizza with the microwavawe?
# How can I reheat the pizza with the microwavawe?
# How can I bake the pizza with the microwavawe?
# How can I cook the potatoes with the microwavawe?
# How can I boil the potatoes with the microwavawe?
# How can I melt the potatoes with the microwavawe?
# How can I soften the potatoes with the microwavawe?
# How can I surface cook the potatoes with the microwavawe?
# How can I airfry the potatoes with the microwavawe?
# How can I boil the potatoes with the microwavawe?
# How can I warm the potatoes with the microwavawe?
# How can I dehydrate the potatoes with the microwavawe?
# How can I autocook the potatoes with the microwavawe?
# How can I grill the potatoes with the microwavawe?
# How can I microwave-grill the potatoes with the microwavawe?
# How can I defrost the potatoes with the microwavawe?
# How can I power defrost the potatoes with the microwavawe?
# How can I reheat the potatoes with the microwavawe?
# How can I bake the potatoes with the microwavawe?
# How can I cook the popcorn with the microwavawe?
# How can I boil the popcorn with the microwavawe?
# How can I melt the popcorn with the microwavawe?
# How can I soften the popcorn with the microwavawe?
# How can I surface cook the popcorn with the microwavawe?
# How can I airfry the popcorn with the microwavawe?
# How can I boil the popcorn with the microwavawe?
# How can I warm the popcorn with the microwavawe?
# How can I dehydrate the popcorn with the microwavawe?
# How can I autocook the popcorn with the microwavawe?
# How can I grill the popcorn with the microwavawe?
# How can I microwave-grill the popcorn with the microwavawe?
# How can I defrost the popcorn with the microwavawe?
# How can I power defrost the popcorn with the microwavawe?
# How can I reheat the popcorn with the microwavawe?
# How can I bake the popcorn with the microwavawe?
# How can I cook the chicken with the microwavawe?
# How can I boil the chicken with the microwavawe?
# How can I melt the chicken with the microwavawe?
# How can I soften the chicken with the microwavawe?
# How can I surface cook the chicken with the microwavawe?
# How can I airfry the chicken with the microwavawe?
# How can I boil the chicken with the microwavawe?
# How can I warm the chicken with the microwavawe?
# How can I dehydrate the chicken with the microwavawe?
# How can I autocook the chicken with the microwavawe?
# How can I grill the chicken with the microwavawe?
# How can I microwave-grill the chicken with the microwavawe?
# How can I defrost the chicken with the microwavawe?
# How can I power defrost the chicken with the microwavawe?
# How can I reheat the chicken with the microwavawe?
# How can I bake the chicken with the microwavawe?
# How can I cook the beef with the microwavawe?
# How can I boil the beef with the microwavawe?
# How can I melt the beef with the microwavawe?
# How can I soften the beef with the microwavawe?
# How can I surface cook the beef with the microwavawe?
# How can I airfry the beef with the microwavawe?
# How can I boil the beef with the microwavawe?
# How can I warm the beef with the microwavawe?
# How can I dehydrate the beef with the microwavawe?
# How can I autocook the beef with the microwavawe?
# How can I grill the beef with the microwavawe?
# How can I microwave-grill the beef with the microwavawe?
# How can I defrost the beef with the microwavawe?
# How can I power defrost the beef with the microwavawe?
# How can I reheat the beef with the microwavawe?
# How can I bake the beef with the microwavawe?
# How can I cook the frozen french fries with the microwavawe?
# How can I boil the frozen french fries with the microwavawe?
# How can I melt the frozen french fries with the microwavawe?
# How can I soften the frozen french fries with the microwavawe?
# How can I surface cook the frozen french fries with the microwavawe?
# How can I airfry the frozen french fries with the microwavawe?
# How can I boil the frozen french fries with the microwavawe?
# How can I warm the frozen french fries with the microwavawe?
# How can I dehydrate the frozen french fries with the microwavawe?
# How can I autocook the frozen french fries with the microwavawe?
# How can I grill the frozen french fries with the microwavawe?
# How can I microwave-grill the frozen french fries with the microwavawe?
# How can I defrost the frozen french fries with the microwavawe?
# How can I power defrost the frozen french fries with the microwavawe?
# How can I reheat the frozen french fries with the microwavawe?
# How can I bake the frozen french fries with the microwavawe?
# How can I cook the tater tots with the microwavawe?
# How can I boil the tater tots with the microwavawe?
# How can I melt the tater tots with the microwavawe?
# How can I soften the tater tots with the microwavawe?
# How can I surface cook the tater tots with the microwavawe?
# How can I airfry the tater tots with the microwavawe?
# How can I boil the tater tots with the microwavawe?
# How can I warm the tater tots with the microwavawe?
# How can I dehydrate the tater tots with the microwavawe?
# How can I autocook the tater tots with the microwavawe?
# How can I grill the tater tots with the microwavawe?
# How can I microwave-grill the tater tots with the microwavawe?
# How can I defrost the tater tots with the microwavawe?
# How can I power defrost the tater tots with the microwavawe?
# How can I reheat the tater tots with the microwavawe?
# How can I bake the tater tots with the microwavawe?
# How can I cook the egg plants with the microwavawe?
# How can I boil the egg plants with the microwavawe?
# How can I melt the egg plants with the microwavawe?
# How can I soften the egg plants with the microwavawe?
# How can I surface cook the egg plants with the microwavawe?
# How can I airfry the egg plants with the microwavawe?
# How can I boil the egg plants with the microwavawe?
# How can I warm the egg plants with the microwavawe?
# How can I dehydrate the egg plants with the microwavawe?
# How can I autocook the egg plants with the microwavawe?
# How can I grill the egg plants with the microwavawe?
# How can I microwave-grill the egg plants with the microwavawe?
# How can I defrost the egg plants with the microwavawe?
# How can I power defrost the egg plants with the microwavawe?
# How can I reheat the egg plants with the microwavawe?
# How can I bake the egg plants with the microwavawe?
# How can I cook the mushrooms with the microwavawe?
# How can I boil the mushrooms with the microwavawe?
# How can I melt the mushrooms with the microwavawe?
# How can I soften the mushrooms with the microwavawe?
# How can I surface cook the mushrooms with the microwavawe?
# How can I airfry the mushrooms with the microwavawe?
# How can I boil the mushrooms with the microwavawe?
# How can I warm the mushrooms with the microwavawe?
# How can I dehydrate the mushrooms with the microwavawe?
# How can I autocook the mushrooms with the microwavawe?
# How can I grill the mushrooms with the microwavawe?
# How can I microwave-grill the mushrooms with the microwavawe?
# How can I defrost the mushrooms with the microwavawe?
# How can I power defrost the mushrooms with the microwavawe?
# How can I reheat the mushrooms with the microwavawe?
# How can I bake the mushrooms with the microwavawe?
# How can I cook the Vegetable Mix. with the microwavawe?
# How can I boil the Vegetable Mix. with the microwavawe?
# How can I melt the Vegetable Mix. with the microwavawe?
# How can I soften the Vegetable Mix. with the microwavawe?
# How can I surface cook the Vegetable Mix. with the microwavawe?
# How can I airfry the Vegetable Mix. with the microwavawe?
# How can I boil the Vegetable Mix. with the microwavawe?
# How can I warm the Vegetable Mix. with the microwavawe?
# How can I dehydrate the Vegetable Mix. with the microwavawe?
# How can I autocook the Vegetable Mix. with the microwavawe?
# How can I grill the Vegetable Mix. with the microwavawe?
# How can I microwave-grill the Vegetable Mix. with the microwavawe?
# How can I defrost the Vegetable Mix. with the microwavawe?
# How can I power defrost the Vegetable Mix. with the microwavawe?
# How can I reheat the Vegetable Mix. with the microwavawe?
# How can I bake the Vegetable Mix. with the microwavawe?
# How can I cook the fresh chicken wings with the microwavawe?
# How can I boil the fresh chicken wings with the microwavawe?
# How can I melt the fresh chicken wings with the microwavawe?
# How can I soften the fresh chicken wings with the microwavawe?
# How can I surface cook the fresh chicken wings with the microwavawe?
# How can I airfry the fresh chicken wings with the microwavawe?
# How can I boil the fresh chicken wings with the microwavawe?
# How can I warm the fresh chicken wings with the microwavawe?
# How can I dehydrate the fresh chicken wings with the microwavawe?
# How can I autocook the fresh chicken wings with the microwavawe?
# How can I grill the fresh chicken wings with the microwavawe?
# How can I microwave-grill the fresh chicken wings with the microwavawe?
# How can I defrost the fresh chicken wings with the microwavawe?
# How can I power defrost the fresh chicken wings with the microwavawe?
# How can I reheat the fresh chicken wings with the microwavawe?
# How can I bake the fresh chicken wings with the microwavawe?
# How can I cook the chicken Breasts with the microwavawe?
# How can I boil the chicken Breasts with the microwavawe?
# How can I melt the chicken Breasts with the microwavawe?
# How can I soften the chicken Breasts with the microwavawe?
# How can I surface cook the chicken Breasts with the microwavawe?
# How can I airfry the chicken Breasts with the microwavawe?
# How can I boil the chicken Breasts with the microwavawe?
# How can I warm the chicken Breasts with the microwavawe?
# How can I dehydrate the chicken Breasts with the microwavawe?
# How can I autocook the chicken Breasts with the microwavawe?
# How can I grill the chicken Breasts with the microwavawe?
# How can I microwave-grill the chicken Breasts with the microwavawe?
# How can I defrost the chicken Breasts with the microwavawe?
# How can I power defrost the chicken Breasts with the microwavawe?
# How can I reheat the chicken Breasts with the microwavawe?
# How can I bake the chicken Breasts with the microwavawe?
# How can I cook the drinks with the microwavawe?
# How can I boil the drinks with the microwavawe?
# How can I melt the drinks with the microwavawe?
# How can I soften the drinks with the microwavawe?
# How can I surface cook the drinks with the microwavawe?
# How can I airfry the drinks with the microwavawe?
# How can I boil the drinks with the microwavawe?
# How can I warm the drinks with the microwavawe?
# How can I dehydrate the drinks with the microwavawe?
# How can I autocook the drinks with the microwavawe?
# How can I grill the drinks with the microwavawe?
# How can I microwave-grill the drinks with the microwavawe?
# How can I defrost the drinks with the microwavawe?
# How can I power defrost the drinks with the microwavawe?
# How can I reheat the drinks with the microwavawe?
# How can I bake the drinks with the microwavawe?
# How can I cook the french fries with the microwavawe?
# How can I boil the french fries with the microwavawe?
# How can I melt the french fries with the microwavawe?
# How can I soften the french fries with the microwavawe?
# How can I surface cook the french fries with the microwavawe?
# How can I airfry the french fries with the microwavawe?
# How can I boil the french fries with the microwavawe?
# How can I warm the french fries with the microwavawe?
# How can I dehydrate the french fries with the microwavawe?
# How can I autocook the french fries with the microwavawe?
# How can I grill the french fries with the microwavawe?
# How can I microwave-grill the french fries with the microwavawe?
# How can I defrost the french fries with the microwavawe?
# How can I power defrost the french fries with the microwavawe?
# How can I reheat the french fries with the microwavawe?
# How can I bake the french fries with the microwavawe?
# three slots
# How can I use the microwavawe to cook the pizza?
# How can I use the microwavawe to boil the pizza?
# How can I use the microwavawe to melt the pizza?
# How can I use the microwavawe to soften the pizza?
# How can I use the microwavawe to surface cook the pizza?
# How can I use the microwavawe to airfry the pizza?
# How can I use the microwavawe to boil the pizza?
# How can I use the microwavawe to warm the pizza?
# How can I use the microwavawe to dehydrate the pizza?
# How can I use the microwavawe to autocook the pizza?
# How can I use the microwavawe to grill the pizza?
# How can I use the microwavawe to microwave-grill the pizza?
# How can I use the microwavawe to defrost the pizza?
# How can I use the microwavawe to power defrost the pizza?
# How can I use the microwavawe to reheat the pizza?
# How can I use the microwavawe to bake the pizza?
# How can I use the microwavawe to cook the potatoes?
# How can I use the microwavawe to boil the potatoes?
# How can I use the microwavawe to melt the potatoes?
# How can I use the microwavawe to soften the potatoes?
# How can I use the microwavawe to surface cook the potatoes?
# How can I use the microwavawe to airfry the potatoes?
# How can I use the microwavawe to boil the potatoes?
# How can I use the microwavawe to warm the potatoes?
# How can I use the microwavawe to dehydrate the potatoes?
# How can I use the microwavawe to autocook the potatoes?
# How can I use the microwavawe to grill the potatoes?
# How can I use the microwavawe to microwave-grill the potatoes?
# How can I use the microwavawe to defrost the potatoes?
# How can I use the microwavawe to power defrost the potatoes?
# How can I use the microwavawe to reheat the potatoes?
# How can I use the microwavawe to bake the potatoes?
# How can I use the microwavawe to cook the popcorn?
# How can I use the microwavawe to boil the popcorn?
# How can I use the microwavawe to melt the popcorn?
# How can I use the microwavawe to soften the popcorn?
# How can I use the microwavawe to surface cook the popcorn?
# How can I use the microwavawe to airfry the popcorn?
# How can I use the microwavawe to boil the popcorn?
# How can I use the microwavawe to warm the popcorn?
# How can I use the microwavawe to dehydrate the popcorn?
# How can I use the microwavawe to autocook the popcorn?
# How can I use the microwavawe to grill the popcorn?
# How can I use the microwavawe to microwave-grill the popcorn?
# How can I use the microwavawe to defrost the popcorn?
# How can I use the microwavawe to power defrost the popcorn?
# How can I use the microwavawe to reheat the popcorn?
# How can I use the microwavawe to bake the popcorn?
# How can I use the microwavawe to cook the chicken?
# How can I use the microwavawe to boil the chicken?
# How can I use the microwavawe to melt the chicken?
# How can I use the microwavawe to soften the chicken?
# How can I use the microwavawe to surface cook the chicken?
# How can I use the microwavawe to airfry the chicken?
# How can I use the microwavawe to boil the chicken?
# How can I use the microwavawe to warm the chicken?
# How can I use the microwavawe to dehydrate the chicken?
# How can I use the microwavawe to autocook the chicken?
# How can I use the microwavawe to grill the chicken?
# How can I use the microwavawe to microwave-grill the chicken?
# How can I use the microwavawe to defrost the chicken?
# How can I use the microwavawe to power defrost the chicken?
# How can I use the microwavawe to reheat the chicken?
# How can I use the microwavawe to bake the chicken?
# How can I use the microwavawe to cook the beef?
# How can I use the microwavawe to boil the beef?
# How can I use the microwavawe to melt the beef?
# How can I use the microwavawe to soften the beef?
# How can I use the microwavawe to surface cook the beef?
# How can I use the microwavawe to airfry the beef?
# How can I use the microwavawe to boil the beef?
# How can I use the microwavawe to warm the beef?
# How can I use the microwavawe to dehydrate the beef?
# How can I use the microwavawe to autocook the beef?
# How can I use the microwavawe to grill the beef?
# How can I use the microwavawe to microwave-grill the beef?
# How can I use the microwavawe to defrost the beef?
# How can I use the microwavawe to power defrost the beef?
# How can I use the microwavawe to reheat the beef?
# How can I use the microwavawe to bake the beef?
# How can I use the microwavawe to cook the frozen french fries?
# How can I use the microwavawe to boil the frozen french fries?
# How can I use the microwavawe to melt the frozen french fries?
# How can I use the microwavawe to soften the frozen french fries?
# How can I use the microwavawe to surface cook the frozen french fries?
# How can I use the microwavawe to airfry the frozen french fries?
# How can I use the microwavawe to boil the frozen french fries?
# How can I use the microwavawe to warm the frozen french fries?
# How can I use the microwavawe to dehydrate the frozen french fries?
# How can I use the microwavawe to autocook the frozen french fries?
# How can I use the microwavawe to grill the frozen french fries?
# How can I use the microwavawe to microwave-grill the frozen french fries?
# How can I use the microwavawe to defrost the frozen french fries?
# How can I use the microwavawe to power defrost the frozen french fries?
# How can I use the microwavawe to reheat the frozen french fries?
# How can I use the microwavawe to bake the frozen french fries?
# How can I use the microwavawe to cook the tater tots?
# How can I use the microwavawe to boil the tater tots?
# How can I use the microwavawe to melt the tater tots?
# How can I use the microwavawe to soften the tater tots?
# How can I use the microwavawe to surface cook the tater tots?
# How can I use the microwavawe to airfry the tater tots?
# How can I use the microwavawe to boil the tater tots?
# How can I use the microwavawe to warm the tater tots?
# How can I use the microwavawe to dehydrate the tater tots?
# How can I use the microwavawe to autocook the tater tots?
# How can I use the microwavawe to grill the tater tots?
# How can I use the microwavawe to microwave-grill the tater tots?
# How can I use the microwavawe to defrost the tater tots?
# How can I use the microwavawe to power defrost the tater tots?
# How can I use the microwavawe to reheat the tater tots?
# How can I use the microwavawe to bake the tater tots?
# How can I use the microwavawe to cook the egg plants?
# How can I use the microwavawe to boil the egg plants?
# How can I use the microwavawe to melt the egg plants?
# How can I use the microwavawe to soften the egg plants?
# How can I use the microwavawe to surface cook the egg plants?
# How can I use the microwavawe to airfry the egg plants?
# How can I use the microwavawe to boil the egg plants?
# How can I use the microwavawe to warm the egg plants?
# How can I use the microwavawe to dehydrate the egg plants?
# How can I use the microwavawe to autocook the egg plants?
# How can I use the microwavawe to grill the egg plants?
# How can I use the microwavawe to microwave-grill the egg plants?
# How can I use the microwavawe to defrost the egg plants?
# How can I use the microwavawe to power defrost the egg plants?
# How can I use the microwavawe to reheat the egg plants?
# How can I use the microwavawe to bake the egg plants?
# How can I use the microwavawe to cook the mushrooms?
# How can I use the microwavawe to boil the mushrooms?
# How can I use the microwavawe to melt the mushrooms?
# How can I use the microwavawe to soften the mushrooms?
# How can I use the microwavawe to surface cook the mushrooms?
# How can I use the microwavawe to airfry the mushrooms?
# How can I use the microwavawe to boil the mushrooms?
# How can I use the microwavawe to warm the mushrooms?
# How can I use the microwavawe to dehydrate the mushrooms?
# How can I use the microwavawe to autocook the mushrooms?
# How can I use the microwavawe to grill the mushrooms?
# How can I use the microwavawe to microwave-grill the mushrooms?
# How can I use the microwavawe to defrost the mushrooms?
# How can I use the microwavawe to power defrost the mushrooms?
# How can I use the microwavawe to reheat the mushrooms?
# How can I use the microwavawe to bake the mushrooms?
# How can I use the microwavawe to cook the Vegetable Mix.?
# How can I use the microwavawe to boil the Vegetable Mix.?
# How can I use the microwavawe to melt the Vegetable Mix.?
# How can I use the microwavawe to soften the Vegetable Mix.?
# How can I use the microwavawe to surface cook the Vegetable Mix.?
# How can I use the microwavawe to airfry the Vegetable Mix.?
# How can I use the microwavawe to boil the Vegetable Mix.?
# How can I use the microwavawe to warm the Vegetable Mix.?
# How can I use the microwavawe to dehydrate the Vegetable Mix.?
# How can I use the microwavawe to autocook the Vegetable Mix.?
# How can I use the microwavawe to grill the Vegetable Mix.?
# How can I use the microwavawe to microwave-grill the Vegetable Mix.?
# How can I use the microwavawe to defrost the Vegetable Mix.?
# How can I use the microwavawe to power defrost the Vegetable Mix.?
# How can I use the microwavawe to reheat the Vegetable Mix.?
# How can I use the microwavawe to bake the Vegetable Mix.?
# How can I use the microwavawe to cook the fresh chicken wings?
# How can I use the microwavawe to boil the fresh chicken wings?
# How can I use the microwavawe to melt the fresh chicken wings?
# How can I use the microwavawe to soften the fresh chicken wings?
# How can I use the microwavawe to surface cook the fresh chicken wings?
# How can I use the microwavawe to airfry the fresh chicken wings?
# How can I use the microwavawe to boil the fresh chicken wings?
# How can I use the microwavawe to warm the fresh chicken wings?
# How can I use the microwavawe to dehydrate the fresh chicken wings?
# How can I use the microwavawe to autocook the fresh chicken wings?
# How can I use the microwavawe to grill the fresh chicken wings?
# How can I use the microwavawe to microwave-grill the fresh chicken wings?
# How can I use the microwavawe to defrost the fresh chicken wings?
# How can I use the microwavawe to power defrost the fresh chicken wings?
# How can I use the microwavawe to reheat the fresh chicken wings?
# How can I use the microwavawe to bake the fresh chicken wings?
# How can I use the microwavawe to cook the chicken Breasts?
# How can I use the microwavawe to boil the chicken Breasts?
# How can I use the microwavawe to melt the chicken Breasts?
# How can I use the microwavawe to soften the chicken Breasts?
# How can I use the microwavawe to surface cook the chicken Breasts?
# How can I use the microwavawe to airfry the chicken Breasts?
# How can I use the microwavawe to boil the chicken Breasts?
# How can I use the microwavawe to warm the chicken Breasts?
# How can I use the microwavawe to dehydrate the chicken Breasts?
# How can I use the microwavawe to autocook the chicken Breasts?
# How can I use the microwavawe to grill the chicken Breasts?
# How can I use the microwavawe to microwave-grill the chicken Breasts?
# How can I use the microwavawe to defrost the chicken Breasts?
# How can I use the microwavawe to power defrost the chicken Breasts?
# How can I use the microwavawe to reheat the chicken Breasts?
# How can I use the microwavawe to bake the chicken Breasts?
# How can I use the microwavawe to cook the drinks?
# How can I use the microwavawe to boil the drinks?
# How can I use the microwavawe to melt the drinks?
# How can I use the microwavawe to soften the drinks?
# How can I use the microwavawe to surface cook the drinks?
# How can I use the microwavawe to airfry the drinks?
# How can I use the microwavawe to boil the drinks?
# How can I use the microwavawe to warm the drinks?
# How can I use the microwavawe to dehydrate the drinks?
# How can I use the microwavawe to autocook the drinks?
# How can I use the microwavawe to grill the drinks?
# How can I use the microwavawe to microwave-grill the drinks?
# How can I use the microwavawe to defrost the drinks?
# How can I use the microwavawe to power defrost the drinks?
# How can I use the microwavawe to reheat the drinks?
# How can I use the microwavawe to bake the drinks?
# How can I use the microwavawe to cook the french fries?
# How can I use the microwavawe to boil the french fries?
# How can I use the microwavawe to melt the french fries?
# How can I use the microwavawe to soften the french fries?
# How can I use the microwavawe to surface cook the french fries?
# How can I use the microwavawe to airfry the french fries?
# How can I use the microwavawe to boil the french fries?
# How can I use the microwavawe to warm the french fries?
# How can I use the microwavawe to dehydrate the french fries?
# How can I use the microwavawe to autocook the french fries?
# How can I use the microwavawe to grill the french fries?
# How can I use the microwavawe to microwave-grill the french fries?
# How can I use the microwavawe to defrost the french fries?
# How can I use the microwavawe to power defrost the french fries?
# How can I use the microwavawe to reheat the french fries?
# How can I use the microwavawe to bake the french fries?
# three slots
# What is the recommended settings for cook -ing pizza on the microwavawe?
# What is the recommended settings for boil -ing pizza on the microwavawe?
# What is the recommended settings for melt -ing pizza on the microwavawe?
# What is the recommended settings for soften -ing pizza on the microwavawe?
# What is the recommended settings for surface cook -ing pizza on the microwavawe?
# What is the recommended settings for airfry -ing pizza on the microwavawe?
# What is the recommended settings for boil -ing pizza on the microwavawe?
# What is the recommended settings for warm -ing pizza on the microwavawe?
# What is the recommended settings for dehydrate -ing pizza on the microwavawe?
# What is the recommended settings for autocook -ing pizza on the microwavawe?
# What is the recommended settings for grill -ing pizza on the microwavawe?
# What is the recommended settings for microwave-grill -ing pizza on the microwavawe?
# What is the recommended settings for defrost -ing pizza on the microwavawe?
# What is the recommended settings for power defrost -ing pizza on the microwavawe?
# What is the recommended settings for reheat -ing pizza on the microwavawe?
# What is the recommended settings for bake -ing pizza on the microwavawe?
# What is the recommended settings for cook -ing potatoes on the microwavawe?
# What is the recommended settings for boil -ing potatoes on the microwavawe?
# What is the recommended settings for melt -ing potatoes on the microwavawe?
# What is the recommended settings for soften -ing potatoes on the microwavawe?
# What is the recommended settings for surface cook -ing potatoes on the microwavawe?
# What is the recommended settings for airfry -ing potatoes on the microwavawe?
# What is the recommended settings for boil -ing potatoes on the microwavawe?
# What is the recommended settings for warm -ing potatoes on the microwavawe?
# What is the recommended settings for dehydrate -ing potatoes on the microwavawe?
# What is the recommended settings for autocook -ing potatoes on the microwavawe?
# What is the recommended settings for grill -ing potatoes on the microwavawe?
# What is the recommended settings for microwave-grill -ing potatoes on the microwavawe?
# What is the recommended settings for defrost -ing potatoes on the microwavawe?
# What is the recommended settings for power defrost -ing potatoes on the microwavawe?
# What is the recommended settings for reheat -ing potatoes on the microwavawe?
# What is the recommended settings for bake -ing potatoes on the microwavawe?
# What is the recommended settings for cook -ing popcorn on the microwavawe?
# What is the recommended settings for boil -ing popcorn on the microwavawe?
# What is the recommended settings for melt -ing popcorn on the microwavawe?
# What is the recommended settings for soften -ing popcorn on the microwavawe?
# What is the recommended settings for surface cook -ing popcorn on the microwavawe?
# What is the recommended settings for airfry -ing popcorn on the microwavawe?
# What is the recommended settings for boil -ing popcorn on the microwavawe?
# What is the recommended settings for warm -ing popcorn on the microwavawe?
# What is the recommended settings for dehydrate -ing popcorn on the microwavawe?
# What is the recommended settings for autocook -ing popcorn on the microwavawe?
# What is the recommended settings for grill -ing popcorn on the microwavawe?
# What is the recommended settings for microwave-grill -ing popcorn on the microwavawe?
# ...
# How can I use the boil feature on the microwavawe?
# How can I use the keep-warm feature on the microwavawe?
# How can I use the dehydrate feature on the microwavawe?
# How can I use the autocook feature on the microwavawe?
# How can I use the grill feature on the microwavawe?
# How can I use the microwave-grill feature on the microwavawe?
# How can I use the defrost feature on the microwavawe?
# How can I use the beeper on the microwavawe?
# How can I use the power-defrost feature on the microwavawe?
# How can I use the reheat feature on the microwavawe?
# How can I use the auto-defrost feature on the microwavawe?
# How can I use the baking-feature on the microwavawe?
# How can I use the self-clean feature on the microwavawe?
# How can I use the timer on the microwavawe?
# How can I use the smart-control feature on the microwavawe?
# How can I use the lamp on the microwavawe?
# How can I use the lightings on the microwavawe?
# How can I use the clock-setting on the microwavawe?
# How can I use the child-lock on the microwavawe?
# How can I use the fan on the microwavawe?
# How can I use the echo-mode on the microwavawe?
# How can I use the delay-start feature on the microwavawe?
# How can I use the left-rear on the microwavawe?
# How can I use the right-rear on the microwavawe?
# How can I use the left-front on the microwavawe?
# How can I use the right-front on the microwavawe?
# How can I use the heating-center on the microwavawe?
# How can I use the surface-control on the microwavawe?
# How can I use the warming-center on the microwavawe?
# How can I use the vent-button on the microwavawe?
# two slots
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# What are the instructions in using the @feature_object on the microwavawe?
# two slots
# How do I set the cooking feature on my microwavawe?
# How do I set the boiling feature on my microwavawe?
# How do I set the melting feature on my microwavawe?
# How do I set the surface-cooking feature on my microwavawe?
# How do I set the softening feature on my microwavawe?
# How do I set the airfry feature on my microwavawe?
# How do I set the boil feature on my microwavawe?
# How do I set the keep-warm feature on my microwavawe?
# How do I set the dehydrate feature on my microwavawe?
# How do I set the autocook feature on my microwavawe?
# How do I set the grill feature on my microwavawe?
# How do I set the microwave-grill feature on my microwavawe?
# How do I set the defrost feature on my microwavawe?
# How do I set the beeper on my microwavawe?
# How do I set the power-defrost feature on my microwavawe?
# How do I set the reheat feature on my microwavawe?
# How do I set the auto-defrost feature on my microwavawe?
# How do I set the baking-feature on my microwavawe?
# How do I set the self-clean feature on my microwavawe?
# How do I set the timer on my microwavawe?
# How do I set the smart-control feature on my microwavawe?
# How do I set the lamp on my microwavawe?
# How do I set the lightings on my microwavawe?
# How do I set the clock-setting on my microwavawe?
# How do I set the child-lock on my microwavawe?
# How do I set the fan on my microwavawe?
# How do I set the echo-mode on my microwavawe?
# How do I set the delay-start feature on my microwavawe?
# How do I set the left-rear on my microwavawe?
# How do I set the right-rear on my microwavawe?
# How do I set the left-front on my microwavawe?
# How do I set the right-front on my microwavawe?
# How do I set the heating-center on my microwavawe?
# How do I set the surface-control on my microwavawe?
# How do I set the warming-center on my microwavawe?
# How do I set the vent-button on my microwavawe?
# -----------------------------------------------
# 2
# two slots
# How do I set the cooking feature on my microwavawe?
# How do I set the boiling feature on my microwavawe?
# How do I set the melting feature on my microwavawe?
# How do I set the surface-cooking feature on my microwavawe?
# How do I set the softening feature on my microwavawe?
# How do I set the airfry feature on my microwavawe?
# How do I set the boil feature on my microwavawe?
# How do I set the keep-warm feature on my microwavawe?
# How do I set the dehydrate feature on my microwavawe?
# How do I set the autocook feature on my microwavawe?
# How do I set the grill feature on my microwavawe?
# How do I set the microwave-grill feature on my microwavawe?
# How do I set the defrost feature on my microwavawe?
# How do I set the beeper on my microwavawe?
# How do I set the power-defrost feature on my microwavawe?
# How do I set the reheat feature on my microwavawe?
# How do I set the auto-defrost feature on my microwavawe?
# How do I set the baking-feature on my microwavawe?
# How do I set the self-clean feature on my microwavawe?
# How do I set the timer on my microwavawe?
# How do I set the smart-control feature on my microwavawe?
# How do I set the lamp on my microwavawe?
# How do I set the lightings on my microwavawe?
# How do I set the clock on my microwavawe?
# How do I set the child-lock on my microwavawe?
# How do I set the fan on my microwavawe?
# How do I set the echo-mode on my microwavawe?
# How do I set the surface-control feature on my microwavawe?
# How do I set the vent-button on my microwavawe?
# -----------------------------------------------
# 1
# one slot
# How do I change the time on the microwavawe
# -----------------------------------------------
# 2
# two slots
# How do I set the speed levels of the fan on my microwavawe?
# How do I set the speed levels of the vent on my microwavawe?
# -----------------------------------------------
# 2
# two slots
# How do I change the power levels of the cooking feature on the microwavawe?
# How do I change the power levels of the boiling feature on the microwavawe?
# How do I change the power levels of the melting feature on the microwavawe?
# How do I change the power levels of the surface-cooking feature on the microwavawe?
# How do I change the power levels of the softening feature on the microwavawe?
# How do I change the power levels of the airfry feature on the microwavawe?
# How do I change the power levels of the boil feature on the microwavawe?
# How do I change the power levels of the keep-warm feature on the microwavawe?
# How do I change the power levels of the dehydrate feature on the microwavawe?
# How do I change the power levels of the autocook feature on the microwavawe?
# How do I change the power levels of the grill feature on the microwavawe?
# How do I change the power levels of the microwave-grill feature on the microwavawe?
# How do I change the power levels of the defrost feature on the microwavawe?
# How do I change the power levels of the power-defrost feature on the microwavawe?
# How do I change the power levels of the reheat feature on the microwavawe?
# How do I change the power levels of the auto-defrost feature on the microwavawe?
# How do I change the power levels of the baking-feature feature on the microwavawe?
# -----------------------------------------------
# 2
# two slots
# How do I turn on the cooking feature on the microwavawe?
# How do I turn on the boiling feature on the microwavawe?
# How do I turn on the melting feature on the microwavawe?
# How do I turn on the surface-cooking feature on the microwavawe?
# How do I turn on the softening feature on the microwavawe?
# How do I turn on the airfry feature on the microwavawe?
# How do I turn on the boil feature on the microwavawe?
# How do I turn on the keep-warm feature on the microwavawe?
# How do I turn on the dehydrate feature on the microwavawe?
# How do I turn on the autocook feature on the microwavawe?
# How do I turn on the grill feature on the microwavawe?
# How do I turn on the microwave-grill feature on the microwavawe?
# How do I turn on the defrost feature on the microwavawe?
# How do I turn on the beeper on the microwavawe?
# How do I turn on the power-defrost feature on the microwavawe?
# How do I turn on the reheat feature on the microwavawe?
# How do I turn on the auto-defrost feature on the microwavawe?
# How do I turn on the baking-feature on the microwavawe?
# How do I turn on the self-clean feature on the microwavawe?
# How do I turn on the timer on the microwavawe?
# How do I turn on the smart-control feature on the microwavawe?
# How do I turn on the lamp on the microwavawe?
# How do I turn on the lightings on the microwavawe?
# How do I turn on the clock on the microwavawe?
# How do I turn on the child-lock on the microwavawe?
# How do I turn on the fan on the microwavawe?
# How do I turn on the echo-mode on the microwavawe?
# How do I turn on the surface-control feature on the microwavawe?
# How do I turn on the vent-button on the microwavawe?
# -----------------------------------------------
# 2
# two slots
# How do I switch the cooking feature off on the microwavawe?
# How do I switch the boiling feature off on the microwavawe?
# How do I switch the melting feature off on the microwavawe?
# How do I switch the surface-cooking feature off on the microwavawe?
# How do I switch the softening feature off on the microwavawe?
# How do I switch the airfry feature off on the microwavawe?
# How do I switch the boil feature off on the microwavawe?
# How do I switch the keep-warm feature off on the microwavawe?
# How do I switch the dehydrate feature off on the microwavawe?
# How do I switch the autocook feature off on the microwavawe?
# How do I switch the grill feature off on the microwavawe?
# How do I switch the microwave-grill feature off on the microwavawe?
# How do I switch the defrost feature off on the microwavawe?
# How do I switch the beeper off on the microwavawe?
# How do I switch the power-defrost feature off on the microwavawe?
# How do I switch the reheat feature off on the microwavawe?
# How do I switch the auto-defrost feature off on the microwavawe?
# How do I switch the baking-feature off on the microwavawe?
# How do I switch the self-clean feature off on the microwavawe?
# How do I switch the timer off on the microwavawe?
# How do I switch the smart-control feature off on the microwavawe?
# How do I switch the lamp off on the microwavawe?
# How do I switch the lightings off on the microwavawe?
# How do I switch the clock off on the microwavawe?
# How do I switch the child-lock off on the microwavawe?
# How do I switch the fan off on the microwavawe?
# How do I switch the echo-mode off on the microwavawe?
# How do I switch the surface-control feature off on the microwavawe?
# How do I switch the vent-button off on the microwavawe?
# two slots
# How do I cancel the cooking feature on the microwavawe?
# How do I cancel the boiling feature on the microwavawe?
# How do I cancel the melting feature on the microwavawe?
# How do I cancel the surface-cooking feature on the microwavawe?
# How do I cancel the softening feature on the microwavawe?
# How do I cancel the airfry feature on the microwavawe?
# How do I cancel the boil feature on the microwavawe?
# How do I cancel the keep-warm feature on the microwavawe?
# How do I cancel the dehydrate feature on the microwavawe?
# How do I cancel the autocook feature on the microwavawe?
# How do I cancel the grill feature on the microwavawe?
# How do I cancel the microwave-grill feature on the microwavawe?
# How do I cancel the defrost feature on the microwavawe?
# How do I cancel the beeper on the microwavawe?
# How do I cancel the power-defrost feature on the microwavawe?
# How do I cancel the reheat feature on the microwavawe?
# How do I cancel the auto-defrost feature on the microwavawe?
# How do I cancel the baking-feature on the microwavawe?
# How do I cancel the self-clean feature on the microwavawe?
# How do I cancel the timer on the microwavawe?
# How do I cancel the smart-control feature on the microwavawe?
# How do I cancel the lamp on the microwavawe?
# How do I cancel the lightings on the microwavawe?
# How do I cancel the clock on the microwavawe?
# How do I cancel the child-lock on the microwavawe?
# How do I cancel the fan on the microwavawe?
# How do I cancel the echo-mode on the microwavawe?
# How do I cancel the surface-control feature on the microwavawe?
# How do I cancel the vent-button on the microwavawe?
# two slots
# I need to stop the cooking feature on the microwavawe.
# I need to stop the boiling feature on the microwavawe.
# I need to stop the melting feature on the microwavawe.
# I need to stop the surface-cooking feature on the microwavawe.
# I need to stop the softening feature on the microwavawe.
# I need to stop the airfry feature on the microwavawe.
# I need to stop the boil feature on the microwavawe.
# I need to stop the keep-warm feature on the microwavawe.
# I need to stop the dehydrate feature on the microwavawe.
# I need to stop the autocook feature on the microwavawe.
# I need to stop the grill feature on the microwavawe.
# I need to stop the microwave-grill feature on the microwavawe.
# I need to stop the defrost feature on the microwavawe.
# I need to stop the beeper on the microwavawe.
# I need to stop the power-defrost feature on the microwavawe.
# I need to stop the reheat feature on the microwavawe.
# I need to stop the auto-defrost feature on the microwavawe.
# I need to stop the baking-feature on the microwavawe.
# I need to stop the self-clean feature on the microwavawe.
# I need to stop the timer on the microwavawe.
# I need to stop the smart-control feature on the microwavawe.
# I need to stop the lamp on the microwavawe.
# I need to stop the lightings on the microwavawe.
# I need to stop the clock on the microwavawe.
# I need to stop the child-lock on the microwavawe.
# I need to stop the fan on the microwavawe.
# I need to stop the echo-mode on the microwavawe.
# I need to stop the surface-control feature on the microwavawe.
# I need to stop the vent-button on the microwavawe.
# -----------------------------------------------
# 1621

# %%
def two_slots(s,j):
    p = 0
    for i in range(len(slot_dict[slots[s][0]])): #Slot 1
        for k in range(len(slot_dict[slots[s][1]])):#Slot 2
            x = target[s][j]
            x = re.sub(slots[s][0], slot_dict[slots[s][0]][i], x)
            x = re.sub(slots[s][1], slot_dict[slots[s][1]][k], x)
            p += 1
            print(x)    
    return p

# %%
def three_slots(s,j):
    p = 0
    for i in range(len(slot_dict[slots[s][0]])): #Slot 1
        for k in range(len(slot_dict[slots[s][1]])):#Slot 2
            for l in range(len(slot_dict[slots[s][2]])):#Slot 3
                x = target[s][j]
                x = re.sub(slots[s][0], slot_dict[slots[s][0]][i], x)
                x = re.sub(slots[s][1], slot_dict[slots[s][1]][k], x)
                x = re.sub(slots[s][2], slot_dict[slots[s][2]][l], x)
                p += 1
                print(x)   
    return p

# %%
def one_slot(s,j):
    p = 0
    for i in range(len(slot_dict[slots[s][0]])): #Slot 1
            x = target[s][j]
            x = re.sub(slots[s][0], slot_dict[slots[s][0]][i], x)
            p += 1
            print(x)    
    return p

# %%
intent_dict = df.QUESTION_LABEL.to_dict()

# %%
def print_all(intent_number = len(target), single = False):
    i = 0
    start = 0
    end = intent_number
    if (single == True):
        start = intent_number - 1
        end = intent_number
    for s in range(start,end): #Intent number
        print("-----------------------------------------------")
        print("Intent:",intent_dict[s],"|","number of slots:",len(slots[s]))
        for j in range(len(target[s])): #Sentence in the intent
            if (len(slots[s]) == 2):
                #print("two slots")
                i += two_slots(s,j)    
            elif (len(slots[s]) == 3):
                #print("three slots")
                i += three_slots(s,j)
            elif (len(slots[s]) == 1):
                #print("one slot")
                i += one_slot(s,j)
            print("-----------------------------------------------")
    print("-----------------------------------------------")

    print(i)

# %%
# print_all(single = False) # Print everything
print_all(15, single=True)
# Out:
# -----------------------------------------------
# Intent: set | number of slots: 2
# How do I set the cooking feature on my microwavawe?
# How do I set the boiling feature on my microwavawe?
# How do I set the melting feature on my microwavawe?
# How do I set the surface-cooking feature on my microwavawe?
# How do I set the softening feature on my microwavawe?
# How do I set the airfry feature on my microwavawe?
# How do I set the boil feature on my microwavawe?
# How do I set the keep-warm feature on my microwavawe?
# How do I set the dehydrate feature on my microwavawe?
# How do I set the autocook feature on my microwavawe?
# How do I set the grill feature on my microwavawe?
# How do I set the microwave-grill feature on my microwavawe?
# How do I set the defrost feature on my microwavawe?
# How do I set the beeper on my microwavawe?
# How do I set the power-defrost feature on my microwavawe?
# How do I set the reheat feature on my microwavawe?
# How do I set the auto-defrost feature on my microwavawe?
# How do I set the baking-feature on my microwavawe?
# How do I set the self-clean feature on my microwavawe?
# How do I set the timer on my microwavawe?
# How do I set the smart-control feature on my microwavawe?
# How do I set the lamp on my microwavawe?
# How do I set the lightings on my microwavawe?
# How do I set the clock on my microwavawe?
# How do I set the child-lock on my microwavawe?
# How do I set the fan on my microwavawe?
# How do I set the echo-mode on my microwavawe?
# How do I set the surface-control feature on my microwavawe?
# How do I set the vent-button on my microwavawe?
# -----------------------------------------------
# -----------------------------------------------
# 29

# %%
def print_all(intent_number = len(target), single = False):
    i = 0
    start = 0
    end = intent_number
    if (single == True):
        start = intent_number - 1
        end = intent_number
    for s in range(start,end): #Intent number
        print("-----------------------------------------------")
        print("Intent:",intent_dict[s],"|","number of slots:",len(slots[s]))
        for j in range(len(target[s])): #Sentence in the intent
            if (len(slots[s]) == 2):
                #print("two slots")
                i += two_slots(s,j)    
            elif (len(slots[s]) == 3):
                #print("three slots")
                i += three_slots(s,j)
            elif (len(slots[s]) == 1):
                #print("one slot")
                i += one_slot(s,j)
            print("-----------------------------------------------")
    print("-----------------------------------------------")

    print(i)

# %%
import os
if not os.path.exists('data_1'):
    open('data_1', 'w').close()

# %%
myFile = open('data_1','w')

# %%
def boi_one_slot(s,j):
    p = 0
    for i in range(len(slot_dict[slots[s][0]])): #Slot 1
            x = target[s][j]
            x = re.sub(slots[s][0], slot_dict[slots[s][0]][i], x)
            p += 1
            print(x)  
    return x, p

# %%
def boi_three_slots(s,j):
    p = 0
    for i in range(len(slot_dict[slots[s][0]])): #Slot 1
        for k in range(len(slot_dict[slots[s][1]])):#Slot 2
            for l in range(len(slot_dict[slots[s][2]])):#Slot 3
                x_original = target[s][j]
                x = re.sub(slots[s][0], slot_dict[slots[s][0]][i], x_original)
                x = re.sub(slots[s][1], slot_dict[slots[s][1]][k], x)
                x = re.sub(slots[s][2], slot_dict[slots[s][2]][l], x)
                x_boi = ""
                p += 1
                print(x)   
    return x, p

# %%
def boi(intent_number = len(target), single = False):
    line = ""
    start = 0
    end = intent_number
    if (single == True):
        start = intent_number - 1
        end = intent_number
    for s in range(start,end): #Intent number
        print("-----------------------------------------------")
        print("Intent:",intent_dict[s],"|","number of slots:",len(slots[s]))
        for j in range(len(target[s])): #Sentence in the intent
            if (len(slots[s]) == 2):
                line,_ = boi_two_slots(s,j)    
            elif (len(slots[s]) == 3):
                line,_ = boi_three_slots(s,j)
            elif (len(slots[s]) == 1):
                line,_ = boi_one_slot(s,j)
            print("-----------------------------------------------")
    print("-----------------------------------------------")

# %%
import copy
slot_dict_boi = copy.deepcopy(slot_dict)

# %%
slot_dict_boi
# Out:
# {'@parts': ['door',
#   'light',
#   'storage drawer',
#   'exhaust adaptor',
#   'grease filter',
#   'characol filter',
#   'wire rack',
#   'air fry tray',
#   'glass tray',
#   'grill rack',
#   'screw',
#   'bracket'],
#  '@appliance': ['microwavawe'],
#  '@object': ['door',
#   'light',
#   'storage-drawer',
#   'exhaust-adaptor',
#   'grease-filter',
#   'characol-filter',
#   'wire-rack',
#   'air-fry tray',
#   'glass-tray',
#   'grill-rack',
#   'cooking-button',
#   'melting-button',
#   'surface-cooking-button',
#   'softening-button',
#   'airfry-button',
#   'boiling-button',
#   'keep-warm-button',
#   'dehydrate-button',
#   'autocook-button',
#   'grill-button',
#   'microwave-grill-button',
#   'defrost-button',
#   'delay-start-button',
#   'fan-button',
#   'fan',
#   'power-defrost-button',
#   'reheat-button',
#   'auto-defrost-button',
#   'self-clean-button',
#   'timer-button',
#   'smart-control-button',
#   'lamp',
#   'lamp-button',
#   'lightings',
#   'clock-settings',
#   'child-lock',
#   'timer',
#   'echo-mode-button',
#   'child-lock-button',
#   'beeper',
#   'smart-controls',
#   'left-rear',
#   'right-rear',
#   'left-front',
#   'right-front',
#   'heating-center',
#   'surface-controls',
#   'warming-center',
#   'vent-button',
#   'model-number',
#   'vent',
#   'sorage-drawer',
#   'broil-oven-heater',
#   'convection-system',
#   'option-key',
#   'touch-pad',
#   'number-pad'],
#  '@feature': ['cooking',
#   'boiling',
#   'melting',
#   'surface-cooking',
#   'softening',
#   'airfry',
#   'boil',
#   'keep-warm',
#   'dehydrate',
#   'autocook',
#   'grill',
#   'microwave-grill',
#   'defrost',
#   'beeper',
#   'power-defrost',
#   'reheat',
#   'auto-defrost',
#   'baking-feature',
#   'self-clean',
#   'timer',
#   'smart-control',
#   'lamp',
#   'lightings',
#   'clock-setting',
#   'child-lock',
#   'fan',
#   'echo-mode',
#   'surface-control',
#   'vent-button'],
#  '@with_feature': ['cooking feature',
#   'boiling feature',
#   'melting feature',
#   'surface-cooking feature',
#   'softening feature',
#   'airfry feature',
#   'boil feature',
#   'keep-warm feature',
#   'dehydrate feature',
#   'autocook feature',
#   'grill feature',
#   'microwave-grill feature',
#   'defrost feature',
#   'beeper',
#   'power-defrost feature',
#   'reheat feature',
#   'auto-defrost feature',
#   'baking-feature',
#   'self-clean feature',
#   'timer',
#   'smart-control feature',
#   'lamp',
#   'lightings',
#   'clock',
#   'child-lock',
#   'fan',
#   'echo-mode',
#   'surface-control feature',
#   'vent-button'],
#  '@with_feature_object': ['cooking feature',
#   'boiling feature',
#   'melting feature',
#   'surface-cooking feature',
#   'softening feature',
#   'airfry feature',
#   'boil feature',
#   'keep-warm feature',
#   'dehydrate feature',
#   'autocook feature',
#   'grill feature',
#   'microwave-grill feature',
#   'defrost feature',
#   'beeper',
#   'power-defrost feature',
#   'reheat feature',
#   'auto-defrost feature',
#   'baking-feature',
#   'self-clean feature',
#   'timer',
#   'smart-control feature',
#   'lamp',
#   'lightings',
#   'clock-setting',
#   'child-lock',
#   'fan',
#   'echo-mode',
#   'delay-start feature',
#   'left-rear',
#   'right-rear',
#   'left-front',
#   'right-front',
#   'heating-center',
#   'surface-control',
#   'warming-center',
#   'vent-button'],
#  '@feature_object': ['cooking',
#   'boiling',
#   'melting',
#   'surface-cooking',
#   'softening',
#   'airfry',
#   'boil',
#   'keep-warm',
#   'dehydrate',
#   'autocook',
#   'grill',
#   'microwave-grill',
#   'defrost',
#   'beeper',
#   'power-defrost',
#   'reheat',
#   'auto-defrost',
#   'baking-feature',
#   'self-clean',
#   'timer',
#   'smart-control',
#   'lamp',
#   'lightings',
#   'clock-setting',
#   'child-lock',
#   'fan',
#   'echo-mode',
#   'delay-start',
#   'left-rear',
#   'right-rear',
#   'left-front',
#   'right-front',
#   'heating-center',
#   'surface-control',
#   'warming-center',
#   'vent-button'],
#  '@cooking_feature': ['cook',
#   'boil',
#   'melt',
#   'soften',
#   'surface cook',
#   'airfry',
#   'boil',
#   'warm',
#   'dehydrate',
#   'autocook',
#   'grill',
#   'microwave-grill',
#   'defrost',
#   'power defrost',
#   'reheat',
#   'bake'],
#  '@cookware': ['Glassware', 'Metal', 'Paper', 'Plasic', 'Aluminum Pan'],
#  '@food': ['pizza',
#   'potatoes',
#   'popcorn',
#   'chicken',
#   'beef',
#   'frozen french fries',
#   'tater tots',
#   'egg plants',
#   'mushrooms',
#   'Vegetable Mix.',
#   'fresh chicken wings',
#   'chicken Breasts',
#   'drinks',
#   'french fries'],
#  '@cleanable': ['glass cooktop', 'cooktop steal'],
#  '@removeable_parts': ['door',
#   'light',
#   'storage drawer',
#   'exhaust adaptor',
#   'grease filters',
#   'characol filter',
#   'wire racks',
#   'burned reside',
#   'waste'],
#  '@replaceable_parts': ['door',
#   'light',
#   'storage drawer',
#   'exhaust adaptor',
#   'grease filters',
#   'characol filter',
#   'wire racks'],
#  '@info_code': ['C-d0',
#   'C-d1',
#   'C-F0',
#   'C-F2',
#   'C-20',
#   'C-21',
#   'C-22',
#   'C-30',
#   'C-31',
#   'bAd LInE',
#   'C-A2'],
#  '@feature_speed_level': ['fan', 'vent'],
#  '@feature_power_level': ['cooking',
#   'boiling',
#   'melting',
#   'surface-cooking',
#   'softening',
#   'airfry',
#   'boil',
#   'keep-warm',
#   'dehydrate',
#   'autocook',
#   'grill',
#   'microwave-grill',
#   'defrost',
#   'power-defrost',
#   'reheat',
#   'auto-defrost',
#   'baking-feature'],
#  '@feature_on_off': ['cooking button',
#   'boiling button',
#   'melting button',
#   'surface-cooking button',
#   'softening button',
#   'airfry button',
#   'boil button',
#   'keep-warm button',
#   'dehydrate button',
#   'autocook button',
#   'grill button',
#   'microwave-grill button',
#   'defrost button',
#   'beeper button',
#   'power-defrost button',
#   'reheat button',
#   'auto-defrost button',
#   'baking-feature',
#   'self-clean button',
#   'timer button',
#   'smart-control button',
#   'lamp button',
#   'lightings button',
#   'clock-setting',
#   'child-lock',
#   'fan',
#   'echo-mode',
#   'delay-start',
#   'left-rear',
#   'right-rear',
#   'left-front',
#   'right-front',
#   'heating-center',
#   'surface-control',
#   'warming-center',
#   'vent-button'],
#  '@feature_cancel': ['cooking',
#   'boiling',
#   'melting',
#   'surface-cooking',
#   'softening',
#   'airfry',
#   'boil',
#   'keep-warm',
#   'dehydrate',
#   'autocook',
#   'grill',
#   'microwave-grill',
#   'defrost',
#   'beeper',
#   'power-defrost',
#   'reheat',
#   'auto-defrost',
#   'baking-feature',
#   'self-clean',
#   'timer',
#   'smart-control',
#   'lamp',
#   'lightings',
#   'clock-setting',
#   'child-lock',
#   'fan',
#   'echo-mode',
#   'surface-control',
#   ' vent']}

# %%
for key,value in slot_dict.items():
    print(key)
    list_slot = []
    for i in value:
        s = i.split()
        for j in range(len(s)):
            print(s[j])
            if j == 0:
                s[j] = s[j] + ":B-" + key[1:]
            else:
                s[j] = s[j] + ":I-" + key[1:]
        i = ' '.join(s)
        list_slot.append(i)
    slot_dict_boi[key] = list_slot
                
print(slot_dict_boi)
# Out:
# @parts
# door
# light
# storage
# drawer
# exhaust
# adaptor
# grease
# filter
# characol
# filter
# wire
# rack
# air
# fry
# tray
# glass
# tray
# grill
# rack
# screw
# bracket
# @appliance
# microwavawe
# @object
# door
# light
# storage-drawer
# exhaust-adaptor
# grease-filter
# characol-filter
# wire-rack
# air-fry
# tray
# glass-tray
# grill-rack
# cooking-button
# melting-button
# surface-cooking-button
# softening-button
# airfry-button
# boiling-button
# keep-warm-button
# dehydrate-button
# autocook-button
# grill-button
# microwave-grill-button
# defrost-button
# delay-start-button
# fan-button
# fan
# power-defrost-button
# reheat-button
# auto-defrost-button
# self-clean-button
# timer-button
# smart-control-button
# lamp
# lamp-button
# lightings
# clock-settings
# child-lock
# timer
# echo-mode-button
# child-lock-button
# beeper
# smart-controls
# left-rear
# right-rear
# left-front
# right-front
# heating-center
# surface-controls
# warming-center
# vent-button
# model-number
# vent
# sorage-drawer
# broil-oven-heater
# convection-system
# option-key
# touch-pad
# number-pad
# @feature
# cooking
# boiling
# melting
# surface-cooking
# softening
# airfry
# boil
# keep-warm
# dehydrate
# autocook
# grill
# microwave-grill
# defrost
# beeper
# power-defrost
# reheat
# auto-defrost
# baking-feature
# self-clean
# timer
# smart-control
# lamp
# lightings
# clock-setting
# child-lock
# fan
# echo-mode
# surface-control
# vent-button
# @with_feature
# cooking
# feature
# boiling
# feature
# melting
# feature
# surface-cooking
# feature
# softening
# feature
# airfry
# feature
# boil
# feature
# keep-warm
# feature
# dehydrate
# feature
# autocook
# feature
# grill
# feature
# microwave-grill
# feature
# defrost
# feature
# beeper
# power-defrost
# feature
# reheat
# feature
# auto-defrost
# feature
# baking-feature
# self-clean
# feature
# timer
# smart-control
# feature
# lamp
# lightings
# clock
# child-lock
# fan
# echo-mode
# surface-control
# feature
# vent-button
# @with_feature_object
# cooking
# feature
# boiling
# feature
# melting
# feature
# surface-cooking
# feature
# softening
# feature
# airfry
# feature
# boil
# feature
# keep-warm
# feature
# dehydrate
# feature
# autocook
# feature
# grill
# feature
# microwave-grill
# feature
# defrost
# feature
# beeper
# power-defrost
# feature
# reheat
# feature
# auto-defrost
# feature
# baking-feature
# self-clean
# feature
# timer
# smart-control
# feature
# lamp
# lightings
# clock-setting
# child-lock
# fan
# echo-mode
# delay-start
# feature
# left-rear
# right-rear
# left-front
# right-front
# heating-center
# surface-control
# warming-center
# vent-button
# @feature_object
# cooking
# boiling
# melting
# surface-cooking
# softening
# airfry
# boil
# keep-warm
# dehydrate
# autocook
# grill
# microwave-grill
# defrost
# beeper
# power-defrost
# reheat
# auto-defrost
# baking-feature
# self-clean
# timer
# smart-control
# lamp
# lightings
# clock-setting
# child-lock
# fan
# echo-mode
# delay-start
# left-rear
# right-rear
# left-front
# right-front
# heating-center
# surface-control
# warming-center
# vent-button
# @cooking_feature
# cook
# boil
# melt
# soften
# surface
# cook
# airfry
# boil
# warm
# dehydrate
# autocook
# grill
# microwave-grill
# defrost
# power
# defrost
# reheat
# bake
# @cookware
# Glassware
# Metal
# Paper
# Plasic
# Aluminum
# Pan
# @food
# pizza
# potatoes
# popcorn
# chicken
# beef
# frozen
# french
# fries
# tater
# tots
# egg
# plants
# mushrooms
# Vegetable
# Mix.
# fresh
# chicken
# wings
# chicken
# Breasts
# drinks
# french
# fries
# @cleanable
# glass
# cooktop
# cooktop
# steal
# @removeable_parts
# door
# light
# storage
# drawer
# exhaust
# adaptor
# grease
# filters
# characol
# filter
# wire
# racks
# burned
# reside
# waste
# @replaceable_parts
# door
# light
# storage
# drawer
# exhaust
# adaptor
# grease
# filters
# characol
# filter
# wire
# racks
# @info_code
# C-d0
# C-d1
# C-F0
# C-F2
# C-20
# C-21
# C-22
# C-30
# C-31
# bAd
# LInE
# C-A2
# @feature_speed_level
# fan
# vent
# @feature_power_level
# cooking
# boiling
# melting
# surface-cooking
# softening
# airfry
# boil
# keep-warm
# dehydrate
# autocook
# grill
# microwave-grill
# defrost
# power-defrost
# reheat
# auto-defrost
# baking-feature
# @feature_on_off
# cooking
# button
# boiling
# button
# melting
# button
# surface-cooking
# button
# softening
# button
# airfry
# button
# boil
# button
# keep-warm
# button
# dehydrate
# button
# autocook
# button
# grill
# button
# microwave-grill
# button
# defrost
# button
# beeper
# button
# power-defrost
# button
# reheat
# button
# auto-defrost
# button
# baking-feature
# self-clean
# button
# timer
# button
# smart-control
# button
# lamp
# button
# lightings
# button
# clock-setting
# child-lock
# fan
# echo-mode
# delay-start
# left-rear
# right-rear
# left-front
# right-front
# heating-center
# surface-control
# warming-center
# vent-button
# @feature_cancel
# cooking
# boiling
# melting
# surface-cooking
# softening
# airfry
# boil
# keep-warm
# dehydrate
# autocook
# grill
# microwave-grill
# defrost
# beeper
# power-defrost
# reheat
# auto-defrost
# baking-feature
# self-clean
# timer
# smart-control
# lamp
# lightings
# clock-setting
# child-lock
# fan
# echo-mode
# surface-control
# vent
# {'@parts': ['door:B-parts', 'light:B-parts', 'storage:B-parts drawer:I-parts', 'exhaust:B-parts adaptor:I-parts', 'grease:B-parts filter:I-parts', 'characol:B-parts filter:I-parts', 'wire:B-parts rack:I-parts', 'air:B-parts fry:I-parts tray:I-parts', 'glass:B-parts tray:I-parts', 'grill:B-parts rack:I-parts', 'screw:B-parts', 'bracket:B-parts'], '@appliance': ['microwavawe:B-appliance'], '@object': ['door:B-object', 'light:B-object', 'storage-drawer:B-object', 'exhaust-adaptor:B-object', 'grease-filter:B-object', 'characol-filter:B-object', 'wire-rack:B-object', 'air-fry:B-object tray:I-object', 'glass-tray:B-object', 'grill-rack:B-object', 'cooking-button:B-object', 'melting-button:B-object', 'surface-cooking-button:B-object', 'softening-button:B-object', 'airfry-button:B-object', 'boiling-button:B-object', 'keep-warm-button:B-object', 'dehydrate-button:B-object', 'autocook-button:B-object', 'grill-button:B-object', 'microwave-grill-button:B-object', 'defrost-button:B-object', 'delay-start-button:B-object', 'fan-button:B-object', 'fan:B-object', 'power-defrost-button:B-object', 'reheat-button:B-object', 'auto-defrost-button:B-object', 'self-clean-button:B-object', 'timer-button:B-object', 'smart-control-button:B-object', 'lamp:B-object', 'lamp-button:B-object', 'lightings:B-object', 'clock-settings:B-object', 'child-lock:B-object', 'timer:B-object', 'echo-mode-button:B-object', 'child-lock-button:B-object', 'beeper:B-object', 'smart-controls:B-object', 'left-rear:B-object', 'right-rear:B-object', 'left-front:B-object', 'right-front:B-object', 'heating-center:B-object', 'surface-controls:B-object', 'warming-center:B-object', 'vent-button:B-object', 'model-number:B-object', 'vent:B-object', 'sorage-drawer:B-object', 'broil-oven-heater:B-object', 'convection-system:B-object', 'option-key:B-object', 'touch-pad:B-object', 'number-pad:B-object'], '@feature': ['cooking:B-feature', 'boiling:B-feature', 'melting:B-feature', 'surface-cooking:B-feature', 'softening:B-feature', 'airfry:B-feature', 'boil:B-feature', 'keep-warm:B-feature', 'dehydrate:B-feature', 'autocook:B-feature', 'grill:B-feature', 'microwave-grill:B-feature', 'defrost:B-feature', 'beeper:B-feature', 'power-defrost:B-feature', 'reheat:B-feature', 'auto-defrost:B-feature', 'baking-feature:B-feature', 'self-clean:B-feature', 'timer:B-feature', 'smart-control:B-feature', 'lamp:B-feature', 'lightings:B-feature', 'clock-setting:B-feature', 'child-lock:B-feature', 'fan:B-feature', 'echo-mode:B-feature', 'surface-control:B-feature', 'vent-button:B-feature'], '@with_feature': ['cooking:B-with_feature feature:I-with_feature', 'boiling:B-with_feature feature:I-with_feature', 'melting:B-with_feature feature:I-with_feature', 'surface-cooking:B-with_feature feature:I-with_feature', 'softening:B-with_feature feature:I-with_feature', 'airfry:B-with_feature feature:I-with_feature', 'boil:B-with_feature feature:I-with_feature', 'keep-warm:B-with_feature feature:I-with_feature', 'dehydrate:B-with_feature feature:I-with_feature', 'autocook:B-with_feature feature:I-with_feature', 'grill:B-with_feature feature:I-with_feature', 'microwave-grill:B-with_feature feature:I-with_feature', 'defrost:B-with_feature feature:I-with_feature', 'beeper:B-with_feature', 'power-defrost:B-with_feature feature:I-with_feature', 'reheat:B-with_feature feature:I-with_feature', 'auto-defrost:B-with_feature feature:I-with_feature', 'baking-feature:B-with_feature', 'self-clean:B-with_feature feature:I-with_feature', 'timer:B-with_feature', 'smart-control:B-with_feature feature:I-with_feature', 'lamp:B-with_feature', 'lightings:B-with_feature', 'clock:B-with_feature', 'child-lock:B-with_feature', 'fan:B-with_feature', 'echo-mode:B-with_feature', 'surface-control:B-with_feature feature:I-with_feature', 'vent-button:B-with_feature'], '@with_feature_object': ['cooking:B-with_feature_object feature:I-with_feature_object', 'boiling:B-with_feature_object feature:I-with_feature_object', 'melting:B-with_feature_object fea ...

# %%
def boi_two_slots(s,j):
    p = 0
    x_boi = ""
    for i in range(len(slot_dict_boi[slots[s][0]])): #Slot 1
        for k in range(len(slot_dict_boi[slots[s][1]])):#Slot 2
            x_original = target[s][j]
            x = re.sub(slots[s][0], slot_dict_boi[slots[s][0]][i], x_original)
            x = re.sub(slots[s][1], slot_dict_boi[slots[s][1]][k], x)
#             x_boi = re.sub(slots[s][0], slot_dict[slots[s][0]][i] + ":B-"+slots[s][0][1:], x_original)
#             x_boi = re.sub(slots[s][1], slot_dict[slots[s][1]][k] + ":B-"+slots[s][1][1:], x_boi)
            x_boi = re.sub(r'((?:^|(?<= ))[a-zA-Z0-9]+(?= |$))', r'\1:o', x) 
            #print(re.findall(r'((?:^|(?<= ))[a-zA-Z0-9]+(?= |$))', r'\1:o', x_boi))
            #print(re.findall(r'\w+',x_boi))
            #print(slots[s][0], slot_dict[slots[s][0]][i])
            p += 1
            print(x_boi)
           # print(x_boi)
           # print(x_boi_2)
    return x, p

# %%
boi(1,single=True)
# Out:
# -----------------------------------------------
# Intent: buy | number of slots: 2
# Where:o can:o I:o buy:o a:o door:B-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o light:B-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o storage:B-parts drawer:I-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o exhaust:B-parts adaptor:I-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o grease:B-parts filter:I-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o characol:B-parts filter:I-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o wire:B-parts rack:I-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o air:B-parts fry:I-parts tray:I-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o glass:B-parts tray:I-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o grill:B-parts rack:I-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o screw:B-parts for:o my:o microwavawe:B-appliance?
# Where:o can:o I:o buy:o a:o bracket:B-parts for:o my:o microwavawe:B-appliance?
# -----------------------------------------------
# I:o want:o to:o get:o a:o new:o door:B-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o light:B-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o storage:B-parts drawer:I-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o exhaust:B-parts adaptor:I-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o grease:B-parts filter:I-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o characol:B-parts filter:I-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o wire:B-parts rack:I-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o air:B-parts fry:I-parts tray:I-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o glass:B-parts tray:I-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o grill:B-parts rack:I-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o screw:B-parts for:o my:o microwavawe:B-appliance.
# I:o want:o to:o get:o a:o new:o bracket:B-parts for:o my:o microwavawe:B-appliance.
# -----------------------------------------------
# How:o can:o I:o purchase:o a:o door:B-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o light:B-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o storage:B-parts drawer:I-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o exhaust:B-parts adaptor:I-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o grease:B-parts filter:I-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o characol:B-parts filter:I-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o wire:B-parts rack:I-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o air:B-parts fry:I-parts tray:I-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o glass:B-parts tray:I-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o grill:B-parts rack:I-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o screw:B-parts for:o my:o microwavawe:B-appliance?
# How:o can:o I:o purchase:o a:o bracket:B-parts for:o my:o microwavawe:B-appliance?
# -----------------------------------------------
# -----------------------------------------------

# %%
Regex.Replace(input, @"[abc]", m => string.Format(@"\{0}", m.Value))
# Out:
#   File "<ipython-input-677-b4a4e1cbe5ec>", line 1
#     Regex.Replace(input, @"[abc]", m => string.Format(@"\{0}", m.Value))
#                          ^
# SyntaxError: invalid syntax

# %%
import re
text = 'Do you get it yet?'
re.sub(r'(\w+)', r'\1:o', text)
# Out:
# 'Do:o you:o get:o it:o yet:o?'
