# %%
import pandas as pd
import numpy as np 
import re
import random
import copy

# %%
# The file that includes the slot and intent information.
df = pd.read_excel("appliance-data-2.xlsx",encoding = "ISO-8859-1", sheet_name="appliance-data-2",header=None)

# %%
df.head(20)
# Out:
#     0                                                  1          2   \
# 0    0                                               oven  microwave
# 1    1                                                buy       oven
# 2    2                           Please call 000-0000-000  No Button
# 3    1                                                buy       oven
# 4    2                           Please call 000-0000-001  No Button
# 5    1                                                buy       oven
# 6    2  You can buy it from the Samsung Contact Center...  No Button
# 7    1                                                buy       oven
# 8    2  You can buy it from the Samsung Contact Center...  No Button
# 9    1                                                buy       oven
# 10   2  You can buy it from the Samsung Contact Center...  No Button
# 11   1                                                buy       oven
# 12   2  You can buy it from the Samsung Contact Center...  No Button
# ...

# %%
try:
    f = open("appliance-data-2.txt", "r")
    f.readline().strip().split("\t")
finally:
    f.close()
# Out:
# ['0', 'oven', 'microwave']

# %%
try:
    for line in open("appliance-data-2.txt", "r"):
        line.strip.split('\t')
finally:
    f.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-fab4225e68bf> in <module>
#       1 try:
#       2     for line in open("appliance-data-2.txt", "r"):
# ----> 3         line.strip.split('\t')
#       4 finally:
#       5     f.close()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'split'

# %%
with open("appliance-data-2.txt") as fp:
    for line in fp:
        temp = line.strip().split("\t")
        if(temp[0] == '0'):
            for i in range(1,len(temp)):
                print(temp[i])
                dict_name = temp[i]
                str(temp[i]) = {}
                
        if(temp[0] == '1'):
            print(temp)

oven
# Out:
#   File "<ipython-input-31-6b8d125e7fef>", line 8
#     str(temp[i]) = {}
#     ^
# SyntaxError: can't assign to function call
