# %%
import pandas as pd

# %%
file_name = 'appliance_utterances_test.xlsx'

# %%
df_1 = pd.read_excel("Appen\\appliance_utterances_test_custom_processed.xlsx")
df_2 = pd.read_excel("Appen\\appliance_utterances_test_l3_processed.xlsx")

# %%
df_3 = pd.read_csv("Appen\\appliance_utterances_test_custom_processed.tsv",sep="\t")
df_4 = pd.read_csv("Appen\\appliance_utterances_test_l3_processed.tsv",sep="\t")

# %%
df_1.head()
# Out:
#    Unnamed: 0  _worker_id                     edge  \
# 0           0    43844929  buy parts for appliance
# 1           1    43844929  buy parts for appliance
# 2           2    43844929  buy parts for appliance
# 3           3    38202325  buy parts for appliance
# 4           4    38202325  buy parts for appliance
#
#                                          template question_should_contain  \
# 0  Where can I buy a @partType for my @appliance?    @partType @appliance
# 1  Where can I buy a @partType for my @appliance?    @partType @appliance
# 2  Where can I buy a @partType for my @appliance?    @partType @appliance
# 3  Where can I buy a @partType for my @appliance?    @partType @appliance
# 4  Where can I buy a @partType for my @appliance?    @partType @appliance
#
#                                             question
# 0  Can you tell me which stores I can buy a @part...
# 1  What store carried @partType so I can buy it f...
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               126 non-null    int64
#  1   _worker_id               126 non-null    int64
#  2   edge                     126 non-null    object
#  3   template                 126 non-null    object
#  4   question_should_contain  126 non-null    object
#  5   question                 126 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 6.0+ KB

# %%
df = pd.concat([df_1, df_2], axis=0)

# %%
df["question"] = df['question'].str.replace('[\.\?]','')

# %%
df = df.sort_values(by=['edge','Unnamed: 0'])

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      Unnamed: 0  _worker_id                                 edge  \
# 0           109    43844929        Does a certain feature exist?
# 1           110    43844929        Does a certain feature exist?
# 2           111    43844929        Does a certain feature exist?
# 3           112    38202325        Does a certain feature exist?
# 4           113    38202325        Does a certain feature exist?
# ..          ...         ...                                  ...
# 239          67    38202325  the purpose of an appliance feature
# 240          68    38202325  the purpose of an appliance feature
# 241          69     6367365  the purpose of an appliance feature
# 242          70     6367365  the purpose of an appliance feature
# 243          71     6367365  the purpose of an appliance feature
#
#                                               template  \
# 0         Is there an @existFeature in the @appliance?
# 1         Is there an @existFeature in the @appliance?
# ...

# %%
df.to_excel(f"{file_name.replace('.xlsx', '')}.xlsx")
df.to_csv(f"{file_name.replace('.xlsx', '')}.tsv", sep="\t")
