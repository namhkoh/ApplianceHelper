# %%
import pandas as pd
import numpy as np 
import re
import random
import copy

# %%
# The file that includes the slot and intent information.
df = pd.read_excel("Appliance Slot-Intent Manual.xlsx",encoding = "ISO-8859-1", sheet_name="Sheet1")
# The file that includes the types of values inside that slot. 
slot_df = pd.read_excel("Appliance Slot-Intent Manual.xlsx",encoding = "ISO-8859-1", sheet_name="Sheet3")
df['QUESTION_SHOULD_CONTAIN']= df['QUESTION_SHOULD_CONTAIN'].str.lower()
slot_df['Slot']= slot_df['Slot'].str.lower()
df['TARGET_QUESTION']= df['TARGET_QUESTION'].str.lower()
df["TARGET_QUESTION"] = df['TARGET_QUESTION'].str.replace('[\.\?\']','')

# %%
## Preprocessing slot_df dataframe
# Slot dataframe trimmed so that the Description is removed. 
slot_df_clean = slot_df.iloc[:,[0,2]]
# replace the Example column with an array of the values separated by a comma
slot_df_clean = slot_df_clean[slot_df_clean['Examples'].notnull()].copy()
slot_df_clean.loc[:,'Examples'] = slot_df_clean.loc[:,"Examples"].apply(lambda x: x.split(', '))
# dictionary of the slots. Key: slot value: possible vallues of the slot. 
slot_dict = dict(zip(slot_df_clean.Slot, slot_df_clean.Examples))
# Split the TARGET_QUESTION column and make it into an array of questions
df.iloc[:,1] = df.iloc[:,1].apply(lambda x: x.split('\n'))
#Temporary extract the TARGET_QUESTION column that was processed above. 
target = df.iloc[:,1]
# A Series of arrays representing the respective slots
slots = df.iloc[:,4].apply(lambda x: x.split(' '))
# The dictionary where key:Intent value:Question
target_dic = df.iloc[:,[0,1]]
# A dictionary of intents key: int value: intent
intent_dict = df.QUESTION_LABEL.to_dict()
slot_dict_boi = copy.deepcopy(slot_dict)
for key,value in slot_dict.items():
    list_slot = []
    for i in value:
        s = i.split()
        for j in range(len(s)):
            if j == 0:
                s[j] = s[j] + ":B-" + key[1:]
            else:
                s[j] = s[j] + ":I-" + key[1:]
        i = ' '.join(s)
        list_slot.append(i)
    slot_dict_boi[key] = list_slot

# %%
train_file_name = 'appliance_data_reverse\\appliance_utterances_train.xlsx'
test_file_name = 'appliance_data_reverse\\appliance_utterances_test2.xlsx'
valid_file_name = 'appliance_data_reverse\\appliance_utterances_valid2.xlsx'

# %%
df_train = pd.read_excel(train_file_name)
df_test = pd.read_excel(test_file_name)
df_valid = pd.read_excel(valid_file_name)

# %%
df_train.drop([114,144,146,175,173,177,194,223,230,231,281,330,331,446,451,459,517,522,529,532,585,612,613,614,615,617,626,627,626,641,652,658,659,663,677,684,685,717,732,743,742,800,806,819,826,828,827,850,851,866,872,873,875,880,886,914,928,929,949,964,988,1016,1017,1103,1013,1021,1025,1031,1048,1065,1066,1124,1126,1148,1194,1195],axis=0,inplace=True)
df_train.reset_index(drop=True,inplace=True)

# %%
df_train.to_excel('Application Files\\appliance_utterances_train.xlsx')

# %%
data_train = pd.concat([df_test, df_valid], axis=0)
data_train.reset_index(drop=True,inplace=True)

# %%
data_train.to_excel('appliance_data_reverse\\appliance_utterances_train_reverse.xlsx')

# %%
data = df_train

# %%
test = {"edge": [], "question_should_contain": [], "question": [], "intent":[]}
valid = {"edge": [], "question_should_contain": [], "question": [], "intent":[]}
for i in range(data.shape[0]):
    if ((i % 2 == 0)):
        test['edge'].append(data.loc[i,'edge'])
        test['question_should_contain'].append(data.loc[i,'question_should_contain'])
        test['question'].append(data.loc[i,'question'])
        test['intent'].append(data.loc[i,'intent'])
    else:
        valid['edge'].append(data.loc[i,'edge'])
        valid['question_should_contain'].append(data.loc[i,'question_should_contain'])
        valid['question'].append(data.loc[i,'question'])
        valid['intent'].append(data.loc[i,'intent'])

# %%
data_test = pd.DataFrame.from_dict(test)
data_valid = pd.DataFrame.from_dict(valid)

# %%
df_valid.reset_index(drop=True,inplace=True)
df_test.reset_index(drop=True,inplace=True)

# %%
data_test.to_excel('appliance_data_reverse\\appliance_utterances_test_reverse.xlsx')
data_valid.to_excel('appliance_data_reverse\\appliance_utterances_vaild_reverse.xlsx')

# %%
def create_data_file(f,df):
    for i in range(df.shape[0]):
        for j in range(3):
            slots = df.loc[i,'question_should_contain'].split(' ')
            x = df.loc[i,'question']
            x = re.sub(slots[0], random_slot(slots[0]), x)
            x = re.sub(slots[1], random_slot(slots[1]), x)
            x = x.lstrip()
            x = re.sub(r'((?:^|(?<= ))[a-zA-Z0-9]+(?= |$))', r'\1:O', x) 
            x = ' '.join(x.split())
            f.write(x + " <=> " + df.loc[i,'intent'] + "\n")
            print(x + " <=> " + df.loc[i,'intent'] + "\n")
    f.close()

# %%
def random_slot(slot):
    random_slot = random.randint(0, len(slot_dict[slot])-1)
#     print(slot_dict[slot])
#     print(slot_dict[slot][random_slot])
    return slot_dict_boi[slot][random_slot]

# %%
f_train = open('C:\\Users\\l.kwon\\slot_filling_and_intent_detection_of_SLU\\data\\appliance6\\train','w')
f_test = open('C:\\Users\\l.kwon\\slot_filling_and_intent_detection_of_SLU\\data\\appliance6\\test','w')
f_valid = open('C:\\Users\\l.kwon\\slot_filling_and_intent_detection_of_SLU\\data\\appliance6\\valid','w')

# %%
create_data_file(f_train,data_train)
# Out:
# is:O glassware:B-cookware appropriate:O to:O use:O in:O the:O oven:B-appliance <=> appropriate
#
# is:O ceramic:B-cookware appropriate:O to:O use:O in:O the:O oven:B-appliance <=> appropriate
#
# is:O straw:B-cookware appropriate:O to:O use:O in:O the:O microwavawe:B-appliance <=> appropriate
#
# should:O i:O use:O the:O browning:B-cookware plate:I-cookware in:O my:O oven:B-appliance <=> appropriate
#
# should:O i:O use:O the:O ceramic:B-cookware in:O my:O oven:B-appliance <=> appropriate
#
# should:O i:O use:O the:O metal:B-cookware trimes:I-cookware in:O my:O oven:B-appliance <=> appropriate
#
# is:O the:O polyester:B-cookware cup:I-cookware safe:O for:O use:O with:O the:O oven:B-appliance <=> appropriate
#
# is:O the:O wood:B-cookware safe:O for:O use:O with:O the:O oven:B-appliance <=> appropriate
#
# is:O the:O paper:B-cookware safe:O for:O use:O with:O the:O microwavawe:B-appliance <=> appropriate
#
# is:O the:O thermometer:B-cookware safe:O for:O use:O with:O the:O microwavawe:B-appliance <=> appropriate
#
# is:O the:O thermometer:B-cookware safe:O for:O use:O with:O the:O microwavawe:B-appliance <=> appropriate
#
# is:O the:O porcelain:B-cookware safe:O for:O use:O with:O the:O microwavawe:B-appliance <=> appropriate
#
# how:O do:O i:O buy:O a:O new:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O buy:O a:O new:O grease:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O buy:O a:O new:O charcoal:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O has:O an:O exhaust:B-parttype filter:I-parttype for:O an:O oven:B-appliance <=> buy
#
# who:O has:O an:O hardware:B-parttype kit:I-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# who:O has:O an:O screws:B-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O gain:O a:O door:B-parttype from:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O gain:O a:O wirerack:B-parttype from:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O gain:O a:O exhaust:B-parttype filter:I-parttype from:O my:O microwavawe:B-appliance <=> buy
#
# show:O me:O where:O to:O purchase:O an:O door:B-parttype for:O an:O oven:B-appliance <=> buy
#
# show:O me:O where:O to:O purchase:O an:O glass:B-parttype tray:I-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# show:O me:O where:O to:O purchase:O an:O charcoal:B-parttype filter:I-parttype for:O an:O oven:B-appliance <=> buy
#
# display:O places:O that:O sell:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# display:O places:O that:O sell:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# display:O places:O that:O sell:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# how:O can:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O is:O the:O best:O way:O to:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O is:O the:O best:O way:O to:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O is:O the:O best:O way:O to:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O may:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O may:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O may:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O many:O ways:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O many:O ways:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O many:O ways:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# would:O you:O mind:O telling:O me:O how:O to:O clean:O the:O melted-plastic:B-cleanobject on:O this:O oven:B-appliance please:O <=> clean
#
# would:O you:O mind:O telling:O me:O how:O to:O clean:O the:O melted-plastic:B-cleanobject on:O this:O oven:B-appliance please:O <=> clean
#
# would:O you:O mind:O telling:O me:O how:O to:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O this:O oven:B-appliance please:O <=> clean
#
# i:O want:O to:O know:O what:O the:O c-A2:B-infocode code:O means:O on:O my:O microwavawe:B-appliance <=> code
#
# i:O want:O to:O know:O what:O the:O c-d0:B-infocode code:O means:O on:O my:O microwavawe:B-appliance <=> code
#
# i:O want:O to:O know:O what:O the:O c-21:B-infocode code:O means:O on:O my:O oven:B-appliance <=> code
#
# can:O you:O tell:O me:O what:O c-F0:B-infocode means:O it:O keeps:O popping:O up:O on:O my:O oven:B-appliance <=> code
#
# can:O you:O tell:O me:O what:O c-A2:B-infocode means:O it:O keeps:O popping:O up:O on:O my:O microwavawe:B-appliance <=> code
#
# can:O you:O tell:O me:O what:O c-d1:B-infocode means:O it:O keeps:O popping:O up:O on:O my:O oven:B-appliance <=> code
#
# display:O the:O c-30:B-infocode meaning:O presented:O on:O my:O oven:B-appliance <=> code
#
# display:O the:O c-22:B-infocode meaning:O presented:O on:O my:O microwavawe:B-appliance <=> code
#
# display:O the:O c-31:B-infocode meaning:O presented:O on:O my:O oven:B-appliance <=> code
#
# what:O does:O c-22:B-infocode mean:O on:O my:O oven:B-appliance <=> code
#
# what:O does:O c-20:B-infocode mean:O on:O my:O microwavawe:B-appliance <=> code
#
# what:O does:O c-d1:B-infocode mean:O on:O my:O oven:B-appliance <=> code
#
# what:O does:O the:O c-30:B-infocode on:O the:O microwavawe:B-appliance mean:O <=> code
#
# what:O does:O the:O bAd-LInE:B-infocode on:O the:O oven:B-appliance mean:O <=> code
#
# what:O does:O the:O c-31:B-infocode on:O the:O oven:B-appliance mean:O <=> code
#
# how:O do:O i:O cook:O the:O frozen:B-foodtype onion:I-foodtype rings:I-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# how:O do:O i:O cook:O the:O frozen:B-foodtype churros:I-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# how:O do:O i:O cook:O the:O frozen:B-foodtype fish:I-foodtype fingers:I-foodtype with:O the:O oven:B-appliance <=> cook
#
# could:O you:O explain:O how:O to:O cook:O breaded:B-foodtype vegetable:I-foodtype mix:I-foodtype using:O this:O oven:B-appliance <=> cook
#
# could:O you:O explain:O how:O to:O cook:O beverage:B-foodtype using:O this:O oven:B-appliance <=> cook
#
# could:O you:O explain:O how:O to:O cook:O potato:B-foodtype using:O this:O oven:B-appliance <=> cook
#
# how:O can:O i:O cook:O lamb:B-foodtype chops:I-foodtype on:O the:O microwavawe:B-appliance <=> cook
#
# how:O can:O i:O cook:O salmon:B-foodtype steak:I-foodtype on:O the:O microwavawe:B-appliance <=> cook
#
# how:O can:O i:O cook:O breaded:B-foodtype cauliflower:I-foodtype on:O the:O oven:B-appliance <=> cook
#
# show:O me:O how:O to:O cook:O tuna:B-foodtype steak:I-foodtype using:O the:O oven:B-appliance <=> cook
#
# show:O me:O how:O to:O cook:O frozen:B-foodtype dinner:I-foodtype using:O the:O oven:B-appliance <=> cook
#
# show:O me:O how:O to:O cook:O breaded:B-foodtype cauliflower:I-foodtype using:O the:O microwavawe:B-appliance <=> cook
#
# tell:O me:O how:O to:O go:O about:O removing:O door:B-removeobject from:O the:O oven:B-appliance please:O <=> remove
#
# tell:O me:O how:O to:O go:O about:O removing:O stains:B-removeobject from:O the:O oven:B-appliance please:O <=> remove
#
# tell:O me:O how:O to:O go:O about:O removing:O rack:B-removeobject from:O the:O microwavawe:B-appliance please:O <=> remove
#
# what:O is:O the:O safest:O way:O to:O detach:O the:O door:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# what:O is:O the:O safest:O way:O to:O detach:O the:O drawer:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# what:O is:O the:O safest:O way:O to:O detach:O the:O drawer:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# what:O are:O ways:O to:O remove:O lights:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# what:O are:O ways:O to:O remove:O rack:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# what:O are:O ways:O to:O remove:O stains:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# can:O you:O show:O me:O how:O to:O remove:O rack:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# can:O you:O show:O me:O how:O to:O remove:O rack:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# can:O you:O show:O me:O how:O to:O remove:O residue:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# i:O wanna:O remove:O rack:B-removeobject from:O the:O microwavawe:B-appliance but:O <=> remove
#
# i:O wanna:O remove:O rack:B-removeobject from:O the:O microwavawe:B-appliance but:O <=> remove
#
# i:O wanna:O remove:O lights:B-removeobject from:O the:O microwavawe:B-appliance but:O <=> remove
#
# tell:O me:O how:O i:O can:O replace:O rack:B-replaceobject from:O the:O microwavawe:B-appliance please:O <=> replace
#
# tell:O me:O how:O i:O can:O replace:O door:B-replaceobject from:O the:O microwavawe:B-appliance please:O <=> replace
#
# tell:O me:O how:O i:O can:O replace:O oven:B-replaceobject light:I-replaceobject from:O the:O microwavawe:B-appliance please:O <=> replace
#
# can:O you:O please:O tell:O me:O how:O i:O reinstall:O drawer:B-replaceobject from:O this:O microwavawe:B-appliance <=> replace
#
# can:O you:O please:O tell:O me:O how:O i:O reinstall:O drawer:B-replaceobject from:O this:O microwavawe:B-appliance <=> replace
#
# can:O you:O please:O tell:O me:O how:O i:O reinstall:O drawer:B-replaceobject from:O this:O oven:B-appliance <=> replace
#
# what:O is:O the:O safe:O way:O to:O reattach:O the:O door:B-replaceobject from:O the:O oven:B-appliance <=> replace
#
# what:O is:O the:O safe:O way:O to:O reattach:O the:O oven:B-replaceobject light:I-replaceobject from:O the:O oven:B-appliance <=> replace
#
# what:O is:O the:O safe:O way:O to:O reattach:O the:O rack:B-replaceobject from:O the:O oven:B-appliance <=> replace
#
# how:O do:O i:O replace:O the:O oven:B-replaceobject light:I-replaceobject in:O my:O oven:B-appliance <=> replace
#
# how:O do:O i:O replace:O the:O door:B-replaceobject in:O my:O oven:B-appliance <=> replace
#
# how:O do:O i:O replace:O the:O charcoal:B-replaceobject filter:I-replaceobject in:O my:O oven:B-appliance <=> replace
#
# would:O you:O tell:O me:O how:O to:O reinstall:O the:O rack:B-replaceobject for:O the:O oven:B-appliance <=> replace
#
# would:O you:O tell:O me:O how:O to:O reinstall:O the:O drawer:B-replaceobject for:O the:O microwavawe:B-appliance <=> replace
#
# would:O you:O tell:O me:O how:O to:O reinstall:O the:O rack:B-replaceobject for:O the:O microwavawe:B-appliance <=> replace
#
# i:O would:O like:O to:O set:O the:O timed:B-setfeature cooking:I-setfeature on:O my:O oven:B-appliance <=> set
#
# i:O would:O like:O to:O set:O the:O clock:B-setfeature on:O my:O oven:B-appliance <=> set
#
# i:O would:O like:O to:O set:O the:O baking:B-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# how:O do:O i:O set:O the:O kitchen:B-setfeature timer:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# how:O do:O i:O set:O the:O clock:B-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# how:O do:O i:O set:O the:O clock:B-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# i:O need:O to:O set:O the:O delay:B-setfeature start:I-setfeature on:O my:O oven:B-appliance <=> set
#
# i:O need:O to:O set:O the:O convection:B-setfeature roast:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# i:O need:O to:O set:O the:O power:B-setfeature level:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# how:O do:O i:O set:O the:O power:B-setfeature level:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# how:O do:O i:O set:O the:O kitchen:B-setfeature timer:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# how:O do:O i:O set:O the:O broiling:B-setfeature on:O my:O oven:B-appliance <=> set
#
# i:O just:O got:O a:O new:O oven:B-appliance can:O you:O please:O tell:O me:O how:O to:O set:O the:O air:B-setfeature fry:I-setfeature on:O it:O <=> set
#
# i:O just:O got:O a:O new:O microwavawe:B-appliance can:O you:O please:O tell:O me:O how:O to:O set:O the:O convection:B-setfeature roast:I-setfeature on:O it:O <=> set
#
# i:O just:O got:O a:O new:O microwavawe:B-appliance can:O you:O please:O tell:O me:O how:O to:O set:O the:O steam:B-setfeature clean:I-setfeature on:O it:O <=> set
#
# could:O you:O show:O me:O how:O to:O use:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature to:O turn:O off:O the:O microwavawe:B-appliance <=> on_off
#
# could:O you:O show:O me:O how:O to:O use:O the:O wifi:B-onofffeature to:O turn:O off:O the:O microwavawe:B-appliance <=> on_off
#
# could:O you:O show:O me:O how:O to:O use:O the:O sound:B-onofffeature to:O turn:O off:O the:O oven:B-appliance <=> on_off
#
# why:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance but:O <=> on_off
#
# why:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance but:O <=> on_off
#
# why:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance but:O <=> on_off
#
# how:O do:O i:O turn:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O turn:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O turn:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O turn:O off:O the:O sound:B-onofffeature off:O on:O this:O microwavawe:B-appliance please:O <=> on_off
#
# how:O do:O turn:O off:O the:O sound:B-onofffeature off:O on:O this:O oven:B-appliance please:O <=> on_off
#
# how:O do:O turn:O off:O the:O sound:B-onofffeature off:O on:O this:O microwavawe:B-appliance please:O <=> on_off
#
# how:O do:O i:O cancel:O the:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O cancel:O the:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O cancel:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O shut:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O shut:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O shut:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O proper:O way:O to:O utilize:O the:O temp:B-usefeature unit:I-usefeature on:O my:O oven:B-appliance <=> use
#
# what:O is:O the:O proper:O way:O to:O utilize:O the:O vent:B-usefeature buttons:I-usefeature on:O my:O microwavawe:B-appliance <=> use
#
# what:O is:O the:O proper:O way:O to:O utilize:O the:O vent:B-usefeature buttons:I-usefeature on:O my:O microwavawe:B-appliance <=> use
#
# what:O is:O the:O proper:O way:O to:O use:O the:O bread:B-usefeature proof:I-usefeature on:O my:O oven:B-appliance <=> use
#
# what:O is:O the:O proper:O way:O to:O use:O the:O demo:B-usefeature mode:I-usefeature on:O my:O microwavawe:B-appliance <=> use
#
# what:O is:O the:O proper:O way:O to:O use:O the:O add:B-usefeature 30:I-usefeature sec:I-usefeature on:O my:O microwavawe:B-appliance <=> use
#
# how:O do:O i:O use:O the:O temp:B-usefeature unit:I-usefeature feature:O on:O my:O oven:B-appliance <=> use
#
# how:O do:O i:O use:O the:O demo:B-usefeature mode:I-usefeature feature:O on:O my:O microwavawe:B-appliance <=> use
#
# how:O do:O i:O use:O the:O kitchen:B-usefeature timer:I-usefeature button:I-usefeature feature:O on:O my:O oven:B-appliance <=> use
#
# i:O need:O to:O use:O the:O reheat:B-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# i:O need:O to:O use:O the:O demo:B-usefeature mode:I-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# i:O need:O to:O use:O the:O auto:B-usefeature conversion:I-usefeature on:O the:O oven:B-appliance <=> use
#
# could:O you:O explain:O the:O purpose:O of:O the:O lamp:B-purposefeature on:O the:O oven:B-appliance <=> purpose
#
# could:O you:O explain:O the:O purpose:O of:O the:O hot:B-purposefeature surface:I-purposefeature indicator:I-purposefeature on:O the:O oven:B-appliance <=> purpose
#
# could:O you:O explain:O the:O purpose:O of:O the:O timer:B-purposefeature on:O the:O microwavawe:B-appliance <=> purpose
#
# what:O does:O the:O convention:B-purposefeature bake:I-purposefeature on:O the:O microwavawe:B-appliance do:O <=> purpose
#
# what:O does:O the:O air:B-purposefeature fry:I-purposefeature on:O the:O microwavawe:B-appliance do:O <=> purpose
#
# what:O does:O the:O dehydrate:B-purposefeature on:O the:O microwavawe:B-appliance do:O <=> purpose
#
# what:O is:O the:O convention:B-purposefeature bake:I-purposefeature on:O the:O microwavawe:B-appliance suppose:O to:O do:O <=> purpose
#
# what:O is:O the:O off:B-purposefeature clear:I-purposefeature on:O the:O microwavawe:B-appliance suppose:O to:O do:O <=> purpose
#
# what:O is:O the:O lamp:B-purposefeature on:O the:O oven:B-appliance suppose:O to:O do:O <=> purpose
#
# tell:O me:O the:O cook:B-purposefeature time:I-purposefeature function:O on:O the:O microwavawe:B-appliance <=> purpose
#
# tell:O me:O the:O number:B-purposefeature pad:I-purposefeature function:O on:O the:O oven:B-appliance <=> purpose
#
# tell:O me:O the:O oven:B-purposefeature clock:I-purposefeature function:O on:O the:O microwavawe:B-appliance <=> purpose
#
# yes:O sir:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# yes:O sir:O where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# yes:O sir:O where:O can:O i:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# looking:O for:O a:O exhaust:B-parttype filter:I-parttype and:O microwavawe:B-appliance <=> buy
#
# looking:O for:O a:O roller:B-parttype guide:I-parttype ring:I-parttype and:O microwavawe:B-appliance <=> buy
#
# looking:O for:O a:O charcoal:B-parttype filter:I-parttype and:O microwavawe:B-appliance <=> buy
#
# can:O my:O light:B-parttype for:O the:O oven:B-appliance be:O bought:O <=> buy
#
# can:O my:O grease:B-parttype filter:I-parttype for:O the:O microwavawe:B-appliance be:O bought:O <=> buy
#
# can:O my:O hardware:B-parttype kit:I-parttype for:O the:O microwavawe:B-appliance be:O bought:O <=> buy
#
# where:O can:O you:O get:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O you:O get:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O you:O get:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# can:O i:O buy:O a:O grease:B-parttype filter:I-parttype on:O an:O oven:B-appliance <=> buy
#
# can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype on:O an:O microwavawe:B-appliance <=> buy
#
# can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype on:O an:O microwavawe:B-appliance <=> buy
#
# i:O will:O buy:O it:O when:O i:O decide:O glass:B-parttype tray:I-parttype oven:B-appliance <=> buy
#
# i:O will:O buy:O it:O when:O i:O decide:O grease:B-parttype filter:I-parttype microwavawe:B-appliance <=> buy
#
# i:O will:O buy:O it:O when:O i:O decide:O storage:B-parttype drawer:I-parttype oven:B-appliance <=> buy
#
# what:O is:O the:O closest:O store:O to:O buy:O storage:B-parttype drawer:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# what:O is:O the:O closest:O store:O to:O buy:O brackets:B-parttype for:O the:O oven:B-appliance <=> buy
#
# what:O is:O the:O closest:O store:O to:O buy:O brackets:B-parttype for:O the:O oven:B-appliance <=> buy
#
# help:O me:O to:O find:O a:O brackets:B-parttype for:O my:O oven:B-appliance <=> buy
#
# help:O me:O to:O find:O a:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# help:O me:O to:O find:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O get:O this:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O get:O this:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O get:O this:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O have:O not:O managed:O to:O get:O light:B-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# i:O have:O not:O managed:O to:O get:O storage:B-parttype drawer:I-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# i:O have:O not:O managed:O to:O get:O storage:B-parttype drawer:I-parttype for:O an:O oven:B-appliance <=> buy
#
# i:O dont:O know:O where:O to:O buy:O roller:B-parttype guide:I-parttype ring:I-parttype for:O an:O oven:B-appliance <=> buy
#
# i:O dont:O know:O where:O to:O buy:O light:B-parttype for:O an:O oven:B-appliance <=> buy
#
# i:O dont:O know:O where:O to:O buy:O roller:B-parttype guide:I-parttype ring:I-parttype for:O an:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O light:B-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype oven:B-appliance <=> buy
#
# the:O power:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# the:O power:O a:O light:B-parttype for:O my:O oven:B-appliance <=> buy
#
# the:O power:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance nice:O <=> buy
#
# where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance nice:O <=> buy
#
# where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O oven:B-appliance nice:O <=> buy
#
# i:O need:O to:O know:O please:O soon:O where:O can:O i:O buy:O a:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O need:O to:O know:O please:O soon:O where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O need:O to:O know:O please:O soon:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance topic:O <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance topic:O <=> buy
#
# where:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance topic:O <=> buy
#
# where:O do:O i:O look:O to:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O do:O i:O look:O to:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O do:O i:O look:O to:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O door:B-parttype for:O my:O microwavawe:B-appliance please:O <=> buy
#
# where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance please:O <=> buy
#
# where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance please:O <=> buy
#
# please:O where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O oven:B-appliance <=> buy
#
# please:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# please:O where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# show:O me:O a:O place:O to:O boy:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# show:O me:O a:O place:O to:O boy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# show:O me:O a:O place:O to:O boy:O a:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# now:O sir:O where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# now:O sir:O where:O can:O i:O buy:O a:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# now:O sir:O where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O want:O to:O buy:O screws:B-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O want:O to:O buy:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O want:O to:O buy:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# did:O you:O get:O my:O air:B-parttype fry:I-parttype tray:I-parttype for:O the:O oven:B-appliance <=> buy
#
# did:O you:O get:O my:O glass:B-parttype tray:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# did:O you:O get:O my:O storage:B-parttype drawer:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# where:O is:O grease:B-parttype filter:I-parttype purchased:O for:O my:O oven:B-appliance <=> buy
#
# where:O is:O charcoal:B-parttype filter:I-parttype purchased:O for:O my:O oven:B-appliance <=> buy
#
# where:O is:O graphite:B-parttype lubricant:I-parttype purchased:O for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance dear:O <=> buy
#
# where:O can:O i:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance dear:O <=> buy
#
# where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O oven:B-appliance dear:O <=> buy
#
# how:O do:O i:O find:O how:O to:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O find:O how:O to:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# how:O do:O i:O find:O how:O to:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# show:O a:O store:O to:O graphite:B-parttype lubricant:I-parttype i:O need:O one:O to:O my:O microwavawe:B-appliance <=> buy
#
# show:O a:O store:O to:O exhaust:B-parttype filter:I-parttype i:O need:O one:O to:O my:O microwavawe:B-appliance <=> buy
#
# show:O a:O store:O to:O brackets:B-parttype i:O need:O one:O to:O my:O microwavawe:B-appliance <=> buy
#
# is:O there:O any:O place:O for:O some:O air:B-parttype fry:I-parttype tray:I-parttype microwavawe:B-appliance <=> buy
#
# is:O there:O any:O place:O for:O some:O storage:B-parttype drawer:I-parttype microwavawe:B-appliance <=> buy
#
# is:O there:O any:O place:O for:O some:O light:B-parttype microwavawe:B-appliance <=> buy
#
# how:O can:O i:O buy:O the:O screws:B-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# how:O can:O i:O buy:O the:O charcoal:B-parttype filter:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# how:O can:O i:O buy:O the:O screws:B-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# how:O buy:O one:O exhaust:B-parttype filter:I-parttype to:O my:O oven:B-appliance <=> buy
#
# how:O buy:O one:O roller:B-parttype guide:I-parttype ring:I-parttype to:O my:O microwavawe:B-appliance <=> buy
#
# how:O buy:O one:O graphite:B-parttype lubricant:I-parttype to:O my:O oven:B-appliance <=> buy
#
# where:O can:O buy:O a:O exhaust:B-parttype filter:I-parttype oven:B-appliance please:O 3:O <=> buy
#
# where:O can:O buy:O a:O hardware:B-parttype kit:I-parttype microwavawe:B-appliance please:O 3:O <=> buy
#
# where:O can:O buy:O a:O graphite:B-parttype lubricant:I-parttype microwavawe:B-appliance please:O 3:O <=> buy
#
# how:O can:O i:O get:O a:O screws:B-parttype in:O the:O oven:B-appliance <=> buy
#
# how:O can:O i:O get:O a:O exhaust:B-parttype filter:I-parttype in:O the:O oven:B-appliance <=> buy
#
# how:O can:O i:O get:O a:O screws:B-parttype in:O the:O microwavawe:B-appliance <=> buy
#
# can:O you:O tell:O me:O how:O to:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# can:O you:O tell:O me:O how:O to:O buy:O a:O wirerack:B-parttype for:O the:O oven:B-appliance <=> buy
#
# can:O you:O tell:O me:O how:O to:O buy:O a:O grease:B-parttype filter:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O pizza:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O pizza:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O pizza:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O is:O it:O possible:O to:O buy:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O is:O it:O possible:O to:O buy:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O is:O it:O possible:O to:O buy:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# should:O i:O buy:O grease:B-parttype filter:I-parttype parts:O for:O my:O microwavawe:B-appliance <=> buy
#
# should:O i:O buy:O grease:B-parttype filter:I-parttype parts:O for:O my:O microwavawe:B-appliance <=> buy
#
# should:O i:O buy:O light:B-parttype parts:O for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O kitchen:O wirerack:B-parttype microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O kitchen:O exhaust:B-parttype filter:I-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O kitchen:O brackets:B-parttype oven:B-appliance <=> buy
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O where:O can:O i:O buy:O a:O screws:B-parttype for:O my:O oven:B-appliance <=> buy
#
# what:O the:O where:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# what:O the:O where:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# what:O the:O where:O can:O i:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O parts:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O parts:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O parts:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# tell:O me:O where:O can:O i:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# tell:O me:O where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# tell:O me:O where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# hi:O assistant:O where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# hi:O assistant:O where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# hi:O assistant:O where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# can:O you:O tell:O me:O a:O place:O where:O i:O can:O find:O a:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# can:O you:O tell:O me:O a:O place:O where:O i:O can:O find:O a:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# can:O you:O tell:O me:O a:O place:O where:O i:O can:O find:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# you:O can:O tell:O me:O buy:O graphite:B-parttype lubricant:I-parttype for:O me:O microwavawe:B-appliance <=> buy
#
# you:O can:O tell:O me:O buy:O wirerack:B-parttype for:O me:O oven:B-appliance <=> buy
#
# you:O can:O tell:O me:O buy:O screws:B-parttype for:O me:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O oven:B-appliance please:O is:O urgent:O <=> buy
#
# where:O can:O i:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance please:O is:O urgent:O <=> buy
#
# where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance please:O is:O urgent:O <=> buy
#
# i:O would:O like:O to:O buy:O some:O screws:B-parttype for:O me:O oven:B-appliance <=> buy
#
# i:O would:O like:O to:O buy:O some:O air:B-parttype fry:I-parttype tray:I-parttype for:O me:O microwavawe:B-appliance <=> buy
#
# i:O would:O like:O to:O buy:O some:O roller:B-parttype guide:I-parttype ring:I-parttype for:O me:O oven:B-appliance <=> buy
#
# show:O me:O where:O to:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# show:O me:O where:O to:O buy:O a:O screws:B-parttype for:O my:O oven:B-appliance <=> buy
#
# show:O me:O where:O to:O buy:O a:O screws:B-parttype for:O my:O oven:B-appliance <=> buy
#
# please:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# please:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# please:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# why:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# why:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# why:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O wash:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O wash:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O wash:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O be:O cleaned:O today:O cooktop:B-cleanobject seal:I-cleanobject microwavawe:B-appliance <=> clean
#
# can:O be:O cleaned:O today:O glass:B-cleanobject cooktop:I-cleanobject microwavawe:B-appliance <=> clean
#
# can:O be:O cleaned:O today:O melted-plastic:B-cleanobject oven:B-appliance <=> clean
#
# im:O not:O sure:O about:O cleaning:O my:O cooktop:B-cleanobject with:O the:O oven:B-appliance what:O do:O you:O recommend:O <=> clean
#
# im:O not:O sure:O about:O cleaning:O my:O sugary-spills:B-cleanobject with:O the:O oven:B-appliance what:O do:O you:O recommend:O <=> clean
#
# im:O not:O sure:O about:O cleaning:O my:O cooktop:B-cleanobject with:O the:O microwavawe:B-appliance what:O do:O you:O recommend:O <=> clean
#
# now:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# now:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# now:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# can:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O cooktop:B-cleanobject of:O the:O oven:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject of:O the:O oven:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject of:O the:O microwavawe:B-appliance <=> clean
#
# how:O often:O should:O the:O sugary-spills:B-cleanobject be:O cleaned:O in:O oven:B-appliance <=> clean
#
# how:O often:O should:O the:O cooktop:B-cleanobject seal:I-cleanobject be:O cleaned:O in:O microwavawe:B-appliance <=> clean
#
# how:O often:O should:O the:O glass:B-cleanobject cooktop:I-cleanobject be:O cleaned:O in:O microwavawe:B-appliance <=> clean
#
# please:O teach:O me:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# please:O teach:O me:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# please:O teach:O me:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O safely:O clean:O the:O cooktop:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O safely:O clean:O the:O sugary-spills:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O safely:O clean:O the:O cooktop:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O soon:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O soon:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O soon:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O my:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O my:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O my:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance wass:O <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance wass:O <=> clean
#
# how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance wass:O <=> clean
#
# how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance yes:O <=> clean
#
# how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance yes:O <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance yes:O <=> clean
#
# how:O can:O i:O set:O clean:O my:O glass:B-cleanobject cooktop:I-cleanobject microwavawe:B-appliance <=> clean
#
# how:O can:O i:O set:O clean:O my:O cooktop:B-cleanobject microwavawe:B-appliance <=> clean
#
# how:O can:O i:O set:O clean:O my:O cooktop:B-cleanobject oven:B-appliance <=> clean
#
# how:O to:O always:O clean:O the:O melted-plastic:B-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O to:O always:O clean:O the:O melted-plastic:B-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O to:O always:O clean:O the:O grease:B-cleanobject filter:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# who:O the:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# who:O the:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# who:O the:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O review:O than:O clean:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O review:O than:O clean:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O review:O than:O clean:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O in:O a:O minute:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O in:O a:O minute:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O to:O know:O please:O in:O a:O minute:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O erase:O completely:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O erase:O completely:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O can:O i:O erase:O completely:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O make:O my:O cooktop:B-cleanobject seal:I-cleanobject oven:B-appliance billiant:O <=> clean
#
# how:O can:O i:O make:O my:O grease:B-cleanobject filter:I-cleanobject microwavawe:B-appliance billiant:O <=> clean
#
# how:O can:O i:O make:O my:O melted-plastic:B-cleanobject microwavawe:B-appliance billiant:O <=> clean
#
# how:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# its:O possible:O clean:O the:O melted-plastic:B-cleanobject in:O the:O oven:B-appliance <=> clean
#
# its:O possible:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# its:O possible:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O on:O my:O device:O in:O glass:B-cleanobject cooktop:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O on:O my:O device:O in:O glass:B-cleanobject cooktop:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O to:O clean:O the:O on:O my:O device:O in:O glass:B-cleanobject cooktop:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# i:O cant:O clean:O the:O sugary-spills:B-cleanobject from:O the:O oven:B-appliance <=> clean
#
# i:O cant:O clean:O the:O sugary-spills:B-cleanobject from:O the:O microwavawe:B-appliance <=> clean
#
# i:O cant:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject from:O the:O microwavawe:B-appliance <=> clean
#
# hi:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# hi:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# hi:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# can:O you:O say:O to:O me:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O you:O say:O to:O me:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# can:O you:O say:O to:O me:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject oven:B-appliance please:O <=> clean
#
# how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject microwavawe:B-appliance please:O <=> clean
#
# how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject microwavawe:B-appliance please:O <=> clean
#
# my:O dear:O darling:O please:O show:O me:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# my:O dear:O darling:O please:O show:O me:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# my:O dear:O darling:O please:O show:O me:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance normally:O <=> clean
#
# how:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance normally:O <=> clean
#
# how:O to:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject in:O the:O oven:B-appliance normally:O <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O to:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O the:O informationhow:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O the:O informationhow:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O need:O the:O informationhow:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject microwavawe:B-appliance please:O please:O please:O people:O <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject microwavawe:B-appliance please:O please:O please:O people:O <=> clean
#
# how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject microwavawe:B-appliance please:O please:O please:O people:O <=> clean
#
# with:O which:O can:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance be:O cleaned:O <=> clean
#
# with:O which:O can:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance be:O cleaned:O <=> clean
#
# with:O which:O can:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance be:O cleaned:O <=> clean
#
# cant:O damage:O the:O stainless:B-cleanobject steel:I-cleanobject if:O i:O clean:O it:O in:O the:O microwavawe:B-appliance <=> clean
#
# cant:O damage:O the:O door:B-cleanobject gasket:I-cleanobject if:O i:O clean:O it:O in:O the:O microwavawe:B-appliance <=> clean
#
# cant:O damage:O the:O cooktop:B-cleanobject if:O i:O clean:O it:O in:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O quickly:O clean:O the:O cooktop:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O quickly:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O quickly:O clean:O the:O sugary-spills:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# im:O asking:O myself:O now:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# im:O asking:O myself:O now:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# im:O asking:O myself:O now:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# do:O we:O have:O to:O clean:O the:O melted-plastic:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# ...
#
# i:O dont:O know:O much:O about:O those:O things:O i:O will:O tell:O my:O friend:O to:O activate:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature microwavawe:B-appliance <=> on_off
#
# i:O dont:O know:O much:O about:O those:O things:O i:O will:O tell:O my:O friend:O to:O activate:O wifi:B-onofffeature oven:B-appliance <=> on_off
#
# can:O i:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# can:O i:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# can:O i:O turn:O off:O the:O sound:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# what:O button:O do:O i:O press:O to:O turn:O off:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# what:O button:O do:O i:O press:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# what:O button:O do:O i:O press:O to:O turn:O off:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O o:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O o:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O o:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# com:O i:O put:O out:O of:O service:O wifi:B-onofffeature and:O microwavawe:B-appliance <=> on_off
#
# com:O i:O put:O out:O of:O service:O sound:B-onofffeature and:O microwavawe:B-appliance <=> on_off
#
# com:O i:O put:O out:O of:O service:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature and:O oven:B-appliance <=> on_off
#
# what:O should:O i:O do:O to:O turn:O off:O the:O wifi:B-onofffeature in:O my:O oven:B-appliance <=> on_off
#
# what:O should:O i:O do:O to:O turn:O off:O the:O wifi:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# what:O should:O i:O do:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O this:O oven:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O this:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O this:O microwavawe:B-appliance <=> on_off
#
# how:O to:O undo:O the:O wifi:B-onofffeature in:O my:O oven:B-appliance <=> on_off
#
# how:O to:O undo:O the:O wifi:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O to:O undo:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O my:O oven:B-appliance <=> on_off
#
# what:O do:O i:O for:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature the:O oven:B-appliance <=> on_off
#
# what:O do:O i:O for:O sound:B-onofffeature the:O oven:B-appliance <=> on_off
#
# what:O do:O i:O for:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature the:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O wifi:B-onofffeature oven:B-appliance morning:O <=> on_off
#
# how:O to:O turn:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature microwavawe:B-appliance morning:O <=> on_off
#
# how:O to:O turn:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature oven:B-appliance morning:O <=> on_off
#
# can:O i:O swich:O the:O sound:B-onofffeature on:O on:O the:O microwavawe:B-appliance <=> on_off
#
# can:O i:O swich:O the:O sound:B-onofffeature on:O on:O the:O oven:B-appliance <=> on_off
#
# can:O i:O swich:O the:O wifi:B-onofffeature on:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O turn:O wifi:B-onofffeature play:O in:O the:O radio:O oven:B-appliance <=> on_off
#
# how:O turn:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature play:O in:O the:O radio:O oven:B-appliance <=> on_off
#
# how:O turn:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature play:O in:O the:O radio:O microwavawe:B-appliance <=> on_off
#
# please:O explain:O to:O me:O how:O to:O turn:O off:O the:O sound:B-onofffeature of:O the:O oven:B-appliance <=> on_off
#
# please:O explain:O to:O me:O how:O to:O turn:O off:O the:O sound:B-onofffeature of:O the:O microwavawe:B-appliance <=> on_off
#
# please:O explain:O to:O me:O how:O to:O turn:O off:O the:O wifi:B-onofffeature of:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O use:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O use:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O use:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O off:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O sound:B-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O wifi:B-onofffeature oven:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O sound:B-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O off:O the:O sound:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# you:O are:O the:O on:O 15:O minutes:O the:O how:O a:O feature:O off:O sound:B-onofffeature oven:B-appliance <=> on_off
#
# you:O are:O the:O on:O 15:O minutes:O the:O how:O a:O feature:O off:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature microwavawe:B-appliance <=> on_off
#
# you:O are:O the:O on:O 15:O minutes:O the:O how:O a:O feature:O off:O sound:B-onofffeature oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O fan:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O fan:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O fan:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O way:O to:O turn:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# what:O is:O the:O way:O to:O turn:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O way:O to:O turn:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# tell:O me:O how:O to:O fix:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# tell:O me:O how:O to:O fix:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# tell:O me:O how:O to:O fix:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O turn:O off:O the:O tv:O wifi:B-onofffeature microwavawe:B-appliance <=> on_off
#
# i:O turn:O off:O the:O tv:O wifi:B-onofffeature microwavawe:B-appliance <=> on_off
#
# i:O turn:O off:O the:O tv:O wifi:B-onofffeature microwavawe:B-appliance <=> on_off
#
# efe:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# efe:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# efe:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O easily:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O easily:O turn:O off:O the:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O easily:O turn:O off:O the:O sound:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# please:O sir:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# please:O sir:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# please:O sir:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# i:O need:O to:O know:O please:O soon:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O need:O to:O know:O please:O soon:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# i:O need:O to:O know:O please:O soon:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# i:O cant:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O cant:O turn:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# i:O cant:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# could:O you:O check:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# could:O you:O check:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# could:O you:O check:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance dear:O <=> on_off
#
# how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance dear:O <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance dear:O <=> on_off
#
# the:O house:O is:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# the:O house:O is:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# the:O house:O is:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# where:O to:O turn:O a:O feature:O on:O an:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature oven:B-appliance 1:O <=> on_off
#
# where:O to:O turn:O a:O feature:O on:O an:O sound:B-onofffeature oven:B-appliance 1:O <=> on_off
#
# where:O to:O turn:O a:O feature:O on:O an:O wifi:B-onofffeature microwavawe:B-appliance 1:O <=> on_off
#
# what:O was:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# what:O was:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# what:O was:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# please:O tell:O because:O i:O need:O to:O know:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# please:O tell:O because:O i:O need:O to:O know:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# please:O tell:O because:O i:O need:O to:O know:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O is:O it:O sound:B-onofffeature oven:B-appliance <=> on_off
#
# how:O is:O it:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O is:O it:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature microwavawe:B-appliance <=> on_off
#
# hi:O can:O you:O tell:O me:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# hi:O can:O you:O tell:O me:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# hi:O can:O you:O tell:O me:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O change:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O change:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O change:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O to:O disable:O sound:B-onofffeature in:O microwavawe:B-appliance <=> on_off
#
# how:O to:O disable:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O microwavawe:B-appliance <=> on_off
#
# how:O to:O disable:O sound:B-onofffeature in:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance sound:B-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance sound:B-onofffeature microwavawe:B-appliance <=> on_off
#
# i:O could:O stay:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# i:O could:O stay:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# i:O could:O stay:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O sound:B-onofffeature on:O on:O the:O microwavawe:B-appliance <=> on_off
#
# what:O should:O i:O do:O to:O switch:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# what:O should:O i:O do:O to:O switch:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# what:O should:O i:O do:O to:O switch:O off:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off

# %%
create_data_file(f_test,data_test)
# Out:
# will:O i:O be:O able:O to:O use:O porcelain:B-cookware in:O the:O microwavawe:B-appliance <=> appropriate
#
# will:O i:O be:O able:O to:O use:O polyester:B-cookware cardboard:I-cookware in:O the:O microwavawe:B-appliance <=> appropriate
#
# will:O i:O be:O able:O to:O use:O metal:B-cookware trimes:I-cookware in:O the:O microwavawe:B-appliance <=> appropriate
#
# can:O i:O use:O the:O straw:B-cookware for:O the:O oven:B-appliance <=> appropriate
#
# can:O i:O use:O the:O paper:B-cookware for:O the:O microwavawe:B-appliance <=> appropriate
#
# can:O i:O use:O the:O stoneware:B-cookware for:O the:O oven:B-appliance <=> appropriate
#
# can:O you:O tell:O me:O if:O browning:B-cookware plate:I-cookware is:O safe:O to:O use:O when:O cooking:O something:O in:O microwavawe:B-appliance <=> appropriate
#
# can:O you:O tell:O me:O if:O paper:B-cookware bags:I-cookware is:O safe:O to:O use:O when:O cooking:O something:O in:O microwavawe:B-appliance <=> appropriate
#
# can:O you:O tell:O me:O if:O plastic:B-cookware is:O safe:O to:O use:O when:O cooking:O something:O in:O microwavawe:B-appliance <=> appropriate
#
# can:O i:O use:O the:O polyester:B-cookware cup:I-cookware for:O my:O oven:B-appliance <=> appropriate
#
# can:O i:O use:O the:O ceramic:B-cookware for:O my:O oven:B-appliance <=> appropriate
#
# can:O i:O use:O the:O stoneware:B-cookware for:O my:O oven:B-appliance <=> appropriate
#
# how:O can:O i:O purchase:O a:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O can:O i:O purchase:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# how:O can:O i:O purchase:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# who:O has:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# who:O has:O a:O glass:B-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O has:O a:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O purchase:O glass:B-parttype tray:I-parttype from:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O purchase:O hardware:B-parttype kit:I-parttype from:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O purchase:O roller:B-parttype guide:I-parttype ring:I-parttype from:O my:O oven:B-appliance <=> buy
#
# can:O you:O tell:O me:O which:O stores:O i:O can:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance are:O located:O nearby:O <=> buy
#
# can:O you:O tell:O me:O which:O stores:O i:O can:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance are:O located:O nearby:O <=> buy
#
# can:O you:O tell:O me:O which:O stores:O i:O can:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O oven:B-appliance are:O located:O nearby:O <=> buy
#
# i:O need:O to:O light:B-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O need:O to:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O need:O to:O brackets:B-parttype for:O my:O oven:B-appliance <=> buy
#
# can:O you:O please:O tell:O me:O how:O to:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O this:O microwavawe:B-appliance correctly:O <=> clean
#
# can:O you:O please:O tell:O me:O how:O to:O clean:O the:O melted-plastic:B-cleanobject on:O this:O microwavawe:B-appliance correctly:O <=> clean
#
# can:O you:O please:O tell:O me:O how:O to:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O this:O microwavawe:B-appliance correctly:O <=> clean
#
# how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O make:O cooktop:B-cleanobject spotless:O on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O make:O cooktop:B-cleanobject spotless:O on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O make:O sugary-spills:B-cleanobject spotless:O on:O the:O oven:B-appliance <=> clean
#
# what:O are:O some:O ways:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# what:O are:O some:O ways:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# what:O are:O some:O ways:O to:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O handle:O the:O c-d1:B-infocode message:O that:O is:O showing:O on:O my:O oven:B-appliance <=> code
#
# how:O do:O i:O handle:O the:O c-F0:B-infocode message:O that:O is:O showing:O on:O my:O oven:B-appliance <=> code
#
# how:O do:O i:O handle:O the:O bAd-LInE:B-infocode message:O that:O is:O showing:O on:O my:O microwavawe:B-appliance <=> code
#
# tell:O me:O the:O error:O code:O meaning:O of:O the:O oven:B-appliance c-21:B-infocode <=> code
#
# tell:O me:O the:O error:O code:O meaning:O of:O the:O microwavawe:B-appliance c-20:B-infocode <=> code
#
# tell:O me:O the:O error:O code:O meaning:O of:O the:O oven:B-appliance c-21:B-infocode <=> code
#
# what:O is:O the:O meaning:O of:O the:O c-21:B-infocode on:O the:O oven:B-appliance <=> code
#
# what:O is:O the:O meaning:O of:O the:O c-A2:B-infocode on:O the:O microwavawe:B-appliance <=> code
#
# what:O is:O the:O meaning:O of:O the:O c-31:B-infocode on:O the:O microwavawe:B-appliance <=> code
#
# i:O have:O an:O error:O called:O c-20:B-infocode which:O appears:O on:O oven:B-appliance and:O there:O is:O there:O <=> code
#
# i:O have:O an:O error:O called:O c-20:B-infocode which:O appears:O on:O oven:B-appliance and:O there:O is:O there:O <=> code
#
# i:O have:O an:O error:O called:O c-A2:B-infocode which:O appears:O on:O microwavawe:B-appliance and:O there:O is:O there:O <=> code
#
# what:O is:O the:O meaning:O for:O the:O c-d1:B-infocode on:O the:O oven:B-appliance <=> code
#
# what:O is:O the:O meaning:O for:O the:O c-22:B-infocode on:O the:O microwavawe:B-appliance <=> code
#
# what:O is:O the:O meaning:O for:O the:O c-21:B-infocode on:O the:O microwavawe:B-appliance <=> code
#
# what:O must:O i:O do:O to:O cook:O pork:B-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# what:O must:O i:O do:O to:O cook:O frozen:B-foodtype potato:I-foodtype wedges:I-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# what:O must:O i:O do:O to:O cook:O roast:B-foodtype beef:I-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# must:O i:O do:O to:O cook:O pork:B-foodtype chops:I-foodtype with:O the:O oven:B-appliance <=> cook
#
# must:O i:O do:O to:O cook:O breaded:B-foodtype mushroom:I-foodtype with:O the:O oven:B-appliance <=> cook
#
# must:O i:O do:O to:O cook:O roast:B-foodtype beef:I-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# how:O must:O i:O do:O to:O cook:O roast:B-foodtype beef:I-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# how:O must:O i:O do:O to:O cook:O chicken:B-foodtype pieces:I-foodtype with:O the:O oven:B-appliance <=> cook
#
# how:O must:O i:O do:O to:O cook:O whole:B-foodtype chicken:I-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# how:O do:O i:O cook:O an:O frozen:B-foodtype potato:I-foodtype wedges:I-foodtype on:O the:O oven:B-appliance <=> cook
#
# how:O do:O i:O cook:O an:O homemade:B-foodtype french:I-foodtype fries:I-foodtype on:O the:O oven:B-appliance <=> cook
#
# how:O do:O i:O cook:O an:O breaded:B-foodtype onions:I-foodtype on:O the:O microwavawe:B-appliance <=> cook
#
# can:O you:O tell:O me:O what:O i:O need:O to:O do:O to:O cook:O frozen:B-foodtype breakfast:I-foodtype on:O the:O oven:B-appliance please:O <=> cook
#
# can:O you:O tell:O me:O what:O i:O need:O to:O do:O to:O cook:O hamburger:B-foodtype on:O the:O microwavawe:B-appliance please:O <=> cook
#
# can:O you:O tell:O me:O what:O i:O need:O to:O do:O to:O cook:O breaded:B-foodtype onions:I-foodtype on:O the:O oven:B-appliance please:O <=> cook
#
# i:O would:O like:O to:O remove:O the:O stains:B-removeobject form:O the:O oven:B-appliance <=> remove
#
# i:O would:O like:O to:O remove:O the:O residue:B-removeobject form:O the:O microwavawe:B-appliance <=> remove
#
# i:O would:O like:O to:O remove:O the:O stains:B-removeobject form:O the:O oven:B-appliance <=> remove
#
# tell:O me:O how:O i:O remove:O door:B-removeobject from:O this:O microwavawe:B-appliance correctly:O please:O <=> remove
#
# tell:O me:O how:O i:O remove:O lights:B-removeobject from:O this:O microwavawe:B-appliance correctly:O please:O <=> remove
#
# tell:O me:O how:O i:O remove:O stains:B-removeobject from:O this:O microwavawe:B-appliance correctly:O please:O <=> remove
#
# how:O do:O i:O take:O away:O residue:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# how:O do:O i:O take:O away:O lights:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# how:O do:O i:O take:O away:O door:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# how:O do:O i:O remove:O door:B-removeobject from:O the:O microwavawe:B-appliance but:O <=> remove
#
# how:O do:O i:O remove:O lights:B-removeobject from:O the:O oven:B-appliance but:O <=> remove
#
# how:O do:O i:O remove:O residue:B-removeobject from:O the:O oven:B-appliance but:O <=> remove
#
# is:O there:O a:O way:O to:O remove:O the:O rack:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# is:O there:O a:O way:O to:O remove:O the:O door:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# is:O there:O a:O way:O to:O remove:O the:O lights:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# show:O me:O how:O to:O replace:O the:O lights:B-replaceobject on:O the:O oven:B-appliance <=> replace
#
# show:O me:O how:O to:O replace:O the:O cooktop:B-replaceobject on:O the:O oven:B-appliance <=> replace
#
# show:O me:O how:O to:O replace:O the:O rack:B-replaceobject on:O the:O oven:B-appliance <=> replace
#
# how:O do:O i:O reinstall:O lights:B-replaceobject from:O the:O oven:B-appliance <=> replace
#
# how:O do:O i:O reinstall:O door:B-replaceobject from:O the:O oven:B-appliance <=> replace
#
# how:O do:O i:O reinstall:O night:B-replaceobject light:I-replaceobject from:O the:O microwavawe:B-appliance <=> replace
#
# how:O do:O i:O replace:O the:O drawer:B-replaceobject on:O my:O oven:B-appliance <=> replace
#
# how:O do:O i:O replace:O the:O oven:B-replaceobject light:I-replaceobject on:O my:O microwavawe:B-appliance <=> replace
#
# how:O do:O i:O replace:O the:O charcoal:B-replaceobject filter:I-replaceobject on:O my:O microwavawe:B-appliance <=> replace
#
# do:O i:O reinstall:O oven:B-replaceobject light:I-replaceobject from:O the:O microwavawe:B-appliance <=> replace
#
# do:O i:O reinstall:O door:B-replaceobject from:O the:O microwavawe:B-appliance <=> replace
#
# do:O i:O reinstall:O door:B-replaceobject from:O the:O microwavawe:B-appliance <=> replace
#
# is:O is:O possible:O to:O the:O the:O power:B-setfeature level:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# is:O is:O possible:O to:O the:O the:O clock:B-setfeature on:O my:O oven:B-appliance <=> set
#
# is:O is:O possible:O to:O the:O the:O smart:B-setfeature control:I-setfeature on:O my:O oven:B-appliance <=> set
#
# how:O do:O i:O set:O the:O broiling:B-setfeature feature:O on:O my:O oven:B-appliance but:O <=> set
#
# how:O do:O i:O set:O the:O delay:B-setfeature start:I-setfeature feature:O on:O my:O oven:B-appliance but:O <=> set
#
# how:O do:O i:O set:O the:O baking:B-setfeature feature:O on:O my:O oven:B-appliance but:O <=> set
#
# i:O wanna:O set:O the:O baking:B-setfeature feature:O on:O my:O oven:B-appliance but:O <=> set
#
# i:O wanna:O set:O the:O convection:B-setfeature roast:I-setfeature feature:O on:O my:O microwavawe:B-appliance but:O <=> set
#
# i:O wanna:O set:O the:O air:B-setfeature fry:I-setfeature feature:O on:O my:O oven:B-appliance but:O <=> set
#
# how:O do:O i:O set:O the:O kitchen:B-setfeature timer:I-setfeature on:O my:O oven:B-appliance <=> set
#
# how:O do:O i:O set:O the:O air:B-setfeature fry:I-setfeature on:O my:O oven:B-appliance <=> set
#
# how:O do:O i:O set:O the:O timed:B-setfeature cooking:I-setfeature on:O my:O oven:B-appliance <=> set
#
# what:O is:O the:O proper:O way:O to:O set:O the:O delay:B-setfeature start:I-setfeature on:O the:O microwavawe:B-appliance <=> set
#
# what:O is:O the:O proper:O way:O to:O set:O the:O convection:B-setfeature roast:I-setfeature on:O the:O oven:B-appliance <=> set
#
# what:O is:O the:O proper:O way:O to:O set:O the:O convection:B-setfeature roast:I-setfeature on:O the:O oven:B-appliance <=> set
#
# show:O me:O instructions:O for:O setting:O the:O baking:B-setfeature on:O the:O oven:B-appliance <=> set
#
# show:O me:O instructions:O for:O setting:O the:O smart:B-setfeature control:I-setfeature on:O the:O oven:B-appliance <=> set
#
# show:O me:O instructions:O for:O setting:O the:O delay:B-setfeature start:I-setfeature on:O the:O oven:B-appliance <=> set
#
# do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance but:O <=> on_off
#
# do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance but:O <=> on_off
#
# do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance but:O <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance but:O <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance but:O <=> on_off
#
# how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance but:O <=> on_off
#
# tell:O me:O how:O i:O switch:O off:O the:O wifi:B-onofffeature on:O this:O new:O oven:B-appliance please:O <=> on_off
#
# tell:O me:O how:O i:O switch:O off:O the:O sound:B-onofffeature on:O this:O new:O microwavawe:B-appliance please:O <=> on_off
#
# tell:O me:O how:O i:O switch:O off:O the:O sound:B-onofffeature on:O this:O new:O microwavawe:B-appliance please:O <=> on_off
#
# i:O need:O to:O stop:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# i:O need:O to:O stop:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# i:O need:O to:O stop:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# what:O do:O i:O do:O to:O switch:O on:O the:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# what:O do:O i:O do:O to:O switch:O on:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# what:O do:O i:O do:O to:O switch:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# can:O i:O use:O the:O eco:B-usefeature mode:I-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# can:O i:O use:O the:O light:B-usefeature buttons:I-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# can:O i:O use:O the:O eco:B-usefeature mode:I-usefeature on:O the:O oven:B-appliance <=> use
#
# what:O can:O i:O use:O the:O soften:B-usefeature on:O the:O oven:B-appliance <=> use
#
# what:O can:O i:O use:O the:O melt:B-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# what:O can:O i:O use:O the:O eco:B-usefeature mode:I-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# can:O you:O please:O let:O me:O know:O how:O to:O temp:B-usefeature adjust:I-usefeature on:O this:O oven:B-appliance <=> use
#
# can:O you:O please:O let:O me:O know:O how:O to:O sabbath:B-usefeature on:O this:O microwavawe:B-appliance <=> use
#
# can:O you:O please:O let:O me:O know:O how:O to:O add:B-usefeature 30:I-usefeature sec:I-usefeature on:O this:O oven:B-appliance <=> use
#
# how:O can:O i:O operate:O the:O vent:B-usefeature buttons:I-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# how:O can:O i:O operate:O the:O vent:B-usefeature buttons:I-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# how:O can:O i:O operate:O the:O dehydrate:B-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# what:O is:O the:O bread:B-purposefeature proof:I-purposefeature function:O for:O on:O my:O oven:B-appliance <=> purpose
#
# what:O is:O the:O hot:B-purposefeature surface:I-purposefeature indicator:I-purposefeature function:O for:O on:O my:O oven:B-appliance <=> purpose
#
# what:O is:O the:O keep:B-purposefeature warm:I-purposefeature function:O for:O on:O my:O microwavawe:B-appliance <=> purpose
#
# what:O is:O the:O delay:B-purposefeature start:I-purposefeature function:O on:O the:O microwavawe:B-appliance <=> purpose
#
# what:O is:O the:O broil:B-purposefeature function:O on:O the:O microwavawe:B-appliance <=> purpose
#
# what:O is:O the:O oven:B-purposefeature clock:I-purposefeature function:O on:O the:O microwavawe:B-appliance <=> purpose
#
# the:O purpose:O of:O the:O bread:B-purposefeature proof:I-purposefeature on:O the:O oven:B-appliance <=> purpose
#
# the:O purpose:O of:O the:O bake:B-purposefeature on:O the:O microwavawe:B-appliance <=> purpose
#
# the:O purpose:O of:O the:O convention:B-purposefeature roast:I-purposefeature on:O the:O microwavawe:B-appliance <=> purpose
#
# what:O is:O clock:B-purposefeature the:O microwavawe:B-appliance for:O <=> purpose
#
# what:O is:O bake:B-purposefeature the:O microwavawe:B-appliance for:O <=> purpose
#
# what:O is:O off:B-purposefeature clear:I-purposefeature the:O microwavawe:B-appliance for:O <=> purpose
#
# can:O you:O tell:O me:O what:O the:O purposes:O of:O keep:B-purposefeature warm:I-purposefeature are:O on:O this:O microwavawe:B-appliance <=> purpose
#
# can:O you:O tell:O me:O what:O the:O purposes:O of:O cooktop:B-purposefeature lamp:I-purposefeature are:O on:O this:O microwavawe:B-appliance <=> purpose
#
# can:O you:O tell:O me:O what:O the:O purposes:O of:O off:B-purposefeature clear:I-purposefeature are:O on:O this:O microwavawe:B-appliance <=> purpose
#
# now:O where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# now:O where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# now:O where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O grease:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O grease:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O how:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O how:O i:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O how:O i:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# how:O to:O buy:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# how:O to:O buy:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance <=> buy
#
# how:O to:O buy:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# in:O the:O rent:O of:O my:O house:O they:O sell:O grease:B-parttype filter:I-parttype microwavawe:B-appliance <=> buy
#
# in:O the:O rent:O of:O my:O house:O they:O sell:O air:B-parttype fry:I-parttype tray:I-parttype oven:B-appliance <=> buy
#
# in:O the:O rent:O of:O my:O house:O they:O sell:O screws:B-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O my:O charcoal:B-parttype filter:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O my:O hardware:B-parttype kit:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O my:O exhaust:B-parttype filter:I-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# is:O there:O any:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance <=> buy
#
# is:O there:O any:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# is:O there:O any:O screws:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O am:O interested:O in:O purchasing:O an:O hardware:B-parttype kit:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O am:O interested:O in:O purchasing:O an:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O am:O interested:O in:O purchasing:O an:O light:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O do:O i:O buy:O a:O light:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O do:O i:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O do:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O want:O to:O buy:O door:B-parttype from:O oven:B-appliance <=> buy
#
# i:O want:O to:O buy:O graphite:B-parttype lubricant:I-parttype from:O oven:B-appliance <=> buy
#
# i:O want:O to:O buy:O brackets:B-parttype from:O microwavawe:B-appliance <=> buy
#
# where:O you:O buy:O charcoal:B-parttype filter:I-parttype for:O an:O oven:B-appliance <=> buy
#
# where:O you:O buy:O hardware:B-parttype kit:I-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# where:O you:O buy:O light:B-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# the:O house:O is:O beautiful:O glass:B-parttype tray:I-parttype oven:B-appliance <=> buy
#
# the:O house:O is:O beautiful:O roller:B-parttype guide:I-parttype ring:I-parttype microwavawe:B-appliance <=> buy
#
# the:O house:O is:O beautiful:O wirerack:B-parttype microwavawe:B-appliance <=> buy
#
# the:O house:O the:O screws:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# the:O house:O the:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# the:O house:O the:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance play:O <=> buy
#
# where:O can:O i:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance play:O <=> buy
#
# where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance play:O <=> buy
#
# how:O can:O i:O bring:O some:O of:O my:O hardware:B-parttype kit:I-parttype oven:B-appliance <=> buy
#
# how:O can:O i:O bring:O some:O of:O my:O grease:B-parttype filter:I-parttype microwavawe:B-appliance <=> buy
#
# how:O can:O i:O bring:O some:O of:O my:O wirerack:B-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O missing:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O missing:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O missing:O hardware:B-parttype kit:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O look:O a:O screws:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O look:O a:O glass:B-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O look:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# it:O is:O neccesary:O know:O where:O can:O i:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# it:O is:O neccesary:O know:O where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# it:O is:O neccesary:O know:O where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# yes:O sir:O please:O where:O can:O i:O buy:O a:O light:B-parttype for:O my:O oven:B-appliance <=> buy
#
# yes:O sir:O please:O where:O can:O i:O buy:O a:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# yes:O sir:O please:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O easily:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance please:O <=> buy
#
# where:O can:O i:O easily:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance please:O <=> buy
#
# where:O can:O i:O easily:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance please:O <=> buy
#
# yes:O sir:O now:O where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# yes:O sir:O now:O where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# yes:O sir:O now:O where:O can:O i:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# who:O tells:O me:O where:O to:O get:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O tells:O me:O where:O to:O get:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O tells:O me:O where:O to:O get:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance fair:O <=> buy
#
# where:O can:O i:O buy:O a:O light:B-parttype for:O my:O oven:B-appliance fair:O <=> buy
#
# where:O can:O i:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance fair:O <=> buy
#
# where:O do:O i:O get:O a:O glass:B-parttype tray:I-parttype purchase:O for:O an:O microwavawe:B-appliance <=> buy
#
# where:O do:O i:O get:O a:O light:B-parttype purchase:O for:O an:O microwavawe:B-appliance <=> buy
#
# where:O do:O i:O get:O a:O air:B-parttype fry:I-parttype tray:I-parttype purchase:O for:O an:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance wass:O <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance wass:O <=> buy
#
# where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O oven:B-appliance wass:O <=> buy
#
# what:O is:O the:O price:O range:O for:O roller:B-parttype guide:I-parttype ring:I-parttype in:O oven:B-appliance <=> buy
#
# what:O is:O the:O price:O range:O for:O exhaust:B-parttype filter:I-parttype in:O oven:B-appliance <=> buy
#
# what:O is:O the:O price:O range:O for:O wirerack:B-parttype in:O oven:B-appliance <=> buy
#
# where:O sell:O the:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O sell:O the:O door:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O sell:O the:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O find:O some:O light:B-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O find:O some:O charcoal:B-parttype filter:I-parttype microwavawe:B-appliance <=> buy
#
# where:O can:O i:O find:O some:O door:B-parttype oven:B-appliance <=> buy
#
# is:O it:O very:O expensive:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# is:O it:O very:O expensive:O screws:B-parttype for:O my:O oven:B-appliance <=> buy
#
# is:O it:O very:O expensive:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O shop:O this:O grease:B-parttype filter:I-parttype on:O my:O oven:B-appliance <=> buy
#
# how:O shop:O this:O wirerack:B-parttype on:O my:O microwavawe:B-appliance <=> buy
#
# how:O shop:O this:O charcoal:B-parttype filter:I-parttype on:O my:O oven:B-appliance <=> buy
#
# where:O can:O buy:O a:O graphite:B-parttype lubricant:I-parttype microwavawe:B-appliance please:O 2:O <=> buy
#
# where:O can:O buy:O a:O graphite:B-parttype lubricant:I-parttype microwavawe:B-appliance please:O 2:O <=> buy
#
# where:O can:O buy:O a:O brackets:B-parttype microwavawe:B-appliance please:O 2:O <=> buy
#
# i:O want:O know:O where:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype to:O my:O oven:B-appliance <=> buy
#
# i:O want:O know:O where:O buy:O a:O brackets:B-parttype to:O my:O oven:B-appliance <=> buy
#
# i:O want:O know:O where:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype to:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O screws:B-parttype part:O for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype part:O for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype part:O for:O my:O oven:B-appliance <=> buy
#
# are:O there:O any:O places:O i:O can:O buy:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# are:O there:O any:O places:O i:O can:O buy:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# are:O there:O any:O places:O i:O can:O buy:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O lapto:O screws:B-parttype microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O lapto:O exhaust:B-parttype filter:I-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O lapto:O glass:B-parttype tray:I-parttype microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O small:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O small:O hardware:B-parttype kit:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O small:O door:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O grease:B-parttype filter:I-parttype oven:B-appliance <=> buy
#
# the:O why:O where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O oven:B-appliance <=> buy
#
# the:O why:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# the:O why:O where:O can:O i:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O was:O where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O was:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O was:O where:O can:O i:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# what:O are:O the:O places:O to:O buy:O charcoal:B-parttype filter:I-parttype that:O they:O serve:O microwavawe:B-appliance <=> buy
#
# what:O are:O the:O places:O to:O buy:O grease:B-parttype filter:I-parttype that:O they:O serve:O microwavawe:B-appliance <=> buy
#
# what:O are:O the:O places:O to:O buy:O roller:B-parttype guide:I-parttype ring:I-parttype that:O they:O serve:O microwavawe:B-appliance <=> buy
#
# hey:O mate:O where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# hey:O mate:O where:O can:O i:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# hey:O mate:O where:O can:O i:O buy:O a:O door:B-parttype for:O my:O oven:B-appliance <=> buy
#
# how:O much:O the:O cost:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O much:O the:O cost:O a:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O much:O the:O cost:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O the:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O the:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O the:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O oven:B-appliance yes:O <=> buy
#
# where:O can:O i:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance yes:O <=> buy
#
# where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance yes:O <=> buy
#
# i:O need:O to:O buy:O a:O spare:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O need:O to:O buy:O a:O spare:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O need:O to:O buy:O a:O spare:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# do:O i:O need:O to:O buy:O an:O charcoal:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# do:O i:O need:O to:O buy:O an:O screws:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# do:O i:O need:O to:O buy:O an:O light:B-parttype for:O my:O oven:B-appliance <=> buy
#
# now:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# now:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# now:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# cleaning:O my:O door:B-cleanobject gasket:I-cleanobject microwavawe:B-appliance <=> clean
#
# cleaning:O my:O cooktop:B-cleanobject oven:B-appliance <=> clean
#
# cleaning:O my:O cooktop:B-cleanobject seal:I-cleanobject oven:B-appliance <=> clean
#
# what:O can:O i:O us:O to:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O my:O microwavawe:B-appliance <=> clean
#
# what:O can:O i:O us:O to:O clean:O the:O melted-plastic:B-cleanobject on:O my:O oven:B-appliance <=> clean
#
# what:O can:O i:O us:O to:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O my:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O some:O of:O the:O melted-plastic:B-cleanobject microwavawe:B-appliance <=> clean
#
# how:O to:O clean:O some:O of:O the:O melted-plastic:B-cleanobject oven:B-appliance <=> clean
#
# how:O to:O clean:O some:O of:O the:O cooktop:B-cleanobject seal:I-cleanobject oven:B-appliance <=> clean
#
# is:O it:O recommended:O to:O clean:O my:O cooktop:B-cleanobject seal:I-cleanobject with:O the:O oven:B-appliance <=> clean
#
# is:O it:O recommended:O to:O clean:O my:O sugary-spills:B-cleanobject with:O the:O oven:B-appliance <=> clean
#
# is:O it:O recommended:O to:O clean:O my:O door:B-cleanobject gasket:I-cleanobject with:O the:O microwavawe:B-appliance <=> clean
#
# sir:O please:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# sir:O please:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# sir:O please:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O can:O i:O set:O clean:O some:O of:O my:O grease:B-cleanobject filter:I-cleanobject microwavawe:B-appliance <=> clean
#
# how:O can:O i:O set:O clean:O some:O of:O my:O cooktop:B-cleanobject microwavawe:B-appliance <=> clean
#
# how:O can:O i:O set:O clean:O some:O of:O my:O cooktop:B-cleanobject seal:I-cleanobject oven:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject of:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject of:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject of:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O want:O to:O know:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O want:O to:O know:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O want:O to:O know:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# please:O tell:O beacause:O i:O need:O to:O know:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# please:O tell:O beacause:O i:O need:O to:O know:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# please:O tell:O beacause:O i:O need:O to:O know:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance topic:O <=> clean
#
# how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance topic:O <=> clean
#
# how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance topic:O <=> clean
#
# where:O should:O i:O clean:O my:O grease:B-cleanobject filter:I-cleanobject inside:O oven:B-appliance <=> clean
#
# where:O should:O i:O clean:O my:O cooktop:B-cleanobject seal:I-cleanobject inside:O microwavawe:B-appliance <=> clean
#
# where:O should:O i:O clean:O my:O glass:B-cleanobject cooktop:I-cleanobject inside:O microwavawe:B-appliance <=> clean
#
# what:O is:O the:O purpose:O of:O the:O steam:B-purposefeature clean:I-purposefeature in:O the:O microwavawe:B-appliance <=> purpose
#
# what:O is:O the:O purpose:O of:O the:O air:B-purposefeature fry:I-purposefeature in:O the:O microwavawe:B-appliance <=> purpose
#
# what:O is:O the:O purpose:O of:O the:O bake:B-purposefeature in:O the:O microwavawe:B-appliance <=> purpose
#
# how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O to:O do:O to:O clean:O a:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance please:O <=> clean
#
# what:O to:O do:O to:O clean:O a:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance please:O <=> clean
#
# what:O to:O do:O to:O clean:O a:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance please:O <=> clean
#
# how:O should:O the:O glass:B-cleanobject cooktop:I-cleanobject be:O cleaned:O in:O the:O microwavawe:B-appliance <=> clean
#
# how:O should:O the:O cooktop:B-cleanobject seal:I-cleanobject be:O cleaned:O in:O the:O oven:B-appliance <=> clean
#
# how:O should:O the:O grease:B-cleanobject filter:I-cleanobject be:O cleaned:O in:O the:O oven:B-appliance <=> clean
#
# who:O was:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# who:O was:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# who:O was:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O many:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O many:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O many:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O clean:O this:O smal:O partl:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O clean:O this:O smal:O partl:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O clean:O this:O smal:O partl:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# clean:O part:O of:O sugary-spills:B-cleanobject microwavawe:B-appliance 1:O <=> clean
#
# clean:O part:O of:O cooktop:B-cleanobject seal:I-cleanobject microwavawe:B-appliance 1:O <=> clean
#
# clean:O part:O of:O stainless:B-cleanobject steel:I-cleanobject oven:B-appliance 1:O <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
# how:O can:O i:O make:O my:O melted-plastic:B-cleanobject microwavawe:B-appliance clean:O <=> clean
#
# how:O can:O i:O make:O my:O cooktop:B-cleanobject oven:B-appliance clean:O <=> clean
#
# how:O can:O i:O make:O my:O door:B-cleanobject gasket:I-cleanobject oven:B-appliance clean:O <=> clean
#
# can:O the:O stainless:B-cleanobject steel:I-cleanobject be:O cleaned:O on:O the:O microwavawe:B-appliance <=> clean
#
# can:O the:O melted-plastic:B-cleanobject be:O cleaned:O on:O the:O microwavawe:B-appliance <=> clean
#
# can:O the:O cooktop:B-cleanobject seal:I-cleanobject be:O cleaned:O on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O kitchen:O door:B-cleanobject gasket:I-cleanobject and:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O kitchen:O melted-plastic:B-cleanobject and:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O kitchen:O glass:B-cleanobject cooktop:I-cleanobject and:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O power:O part:O in:O stainless:B-cleanobject steel:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O power:O part:O in:O door:B-cleanobject gasket:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O to:O clean:O the:O power:O part:O in:O grease:B-cleanobject filter:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# is:O there:O any:O way:O to:O clean:O the:O grease:B-cleanobject filter:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# is:O there:O any:O way:O to:O clean:O the:O grease:B-cleanobject filter:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# is:O there:O any:O way:O to:O clean:O the:O grease:B-cleanobject filter:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# help:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject of:O the:O microwavawe:B-appliance <=> clean
#
# help:O to:O clean:O the:O door:B-cleanobject gasket:I-cleanobject of:O the:O oven:B-appliance <=> clean
#
# help:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject of:O the:O oven:B-appliance <=> clean
#
# i:O need:O to:O know:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O need:O to:O know:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O need:O to:O know:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# its:O possible:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O my:O oven:B-appliance <=> clean
#
# its:O possible:O clean:O the:O cooktop:B-cleanobject on:O my:O oven:B-appliance <=> clean
#
# its:O possible:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O my:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject oven:B-appliance please:O people:O 1:O <=> clean
#
# how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject microwavawe:B-appliance please:O people:O 1:O <=> clean
#
# how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject microwavawe:B-appliance please:O people:O 1:O <=> clean
#
# how:O do:O you:O clean:O the:O door:B-cleanobject gasket:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O do:O you:O clean:O the:O grease:B-cleanobject filter:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O do:O you:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance i:O need:O the:O information:O <=> clean
#
# how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance i:O need:O the:O information:O <=> clean
#
# how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance i:O need:O the:O information:O <=> clean
#
# tell:O me:O how:O should:O i:O wash:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# tell:O me:O how:O should:O i:O wash:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# tell:O me:O how:O should:O i:O wash:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# can:O the:O grease:B-cleanobject filter:I-cleanobject be:O cleaned:O on:O the:O oven:B-appliance <=> clean
#
# can:O the:O grease:B-cleanobject filter:I-cleanobject be:O cleaned:O on:O the:O oven:B-appliance <=> clean
#
# can:O the:O door:B-cleanobject gasket:I-cleanobject be:O cleaned:O on:O the:O microwavawe:B-appliance <=> clean
#
# do:O i:O have:O to:O remove:O parts:O to:O clean:O the:O sugary-spills:B-cleanobject in:O the:O oven:B-appliance <=> clean
#
# do:O i:O have:O to:O remove:O parts:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# do:O i:O have:O to:O remove:O parts:O to:O clean:O the:O sugary-spills:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# what:O are:O the:O steps:O to:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# what:O are:O the:O steps:O to:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O are:O the:O steps:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# do:O i:O need:O to:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# do:O i:O need:O to:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# ...
#
# how:O do:O i:O deactivate:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O deactivate:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O deactivate:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O off:O wifi:B-onofffeature on:O my:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O off:O wifi:B-onofffeature on:O my:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O off:O wifi:B-onofffeature on:O my:O oven:B-appliance <=> on_off
#
# the:O way:O to:O turn:O off:O the:O sound:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# the:O way:O to:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# the:O way:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# where:O is:O the:O button:O to:O turn:O off:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# where:O is:O the:O button:O to:O turn:O off:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# where:O is:O the:O button:O to:O turn:O off:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# help:O me:O to:O use:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O my:O microwavawe:B-appliance <=> on_off
#
# help:O me:O to:O use:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O my:O microwavawe:B-appliance <=> on_off
#
# help:O me:O to:O use:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O my:O microwavawe:B-appliance <=> on_off
#
# turn:O off:O now:O wifi:B-onofffeature and:O microwavawe:B-appliance <=> on_off
#
# turn:O off:O now:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature and:O oven:B-appliance <=> on_off
#
# turn:O off:O now:O wifi:B-onofffeature and:O oven:B-appliance <=> on_off
#
# how:O can:O i:O disable:O my:O sound:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O can:O i:O disable:O my:O sound:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O can:O i:O disable:O my:O wifi:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# what:O is:O the:O best:O way:O to:O turn:O off:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# what:O is:O the:O best:O way:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# what:O is:O the:O best:O way:O to:O turn:O off:O the:O sound:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O install:O the:O sound:B-onofffeature on:O my:O oven:B-appliance <=> on_off
#
# how:O do:O i:O install:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O my:O oven:B-appliance <=> on_off
#
# how:O do:O i:O install:O the:O wifi:B-onofffeature on:O my:O oven:B-appliance <=> on_off
#
# what:O is:O the:O form:O for:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature the:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O form:O for:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature the:O oven:B-appliance <=> on_off
#
# what:O is:O the:O form:O for:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature the:O oven:B-appliance <=> on_off
#
# what:O is:O the:O procedure:O to:O turn:O on:O the:O wifi:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O procedure:O to:O turn:O on:O the:O wifi:B-onofffeature in:O my:O oven:B-appliance <=> on_off
#
# what:O is:O the:O procedure:O to:O turn:O on:O the:O sound:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# it:O is:O to:O switch:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# it:O is:O to:O switch:O on:O the:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# it:O is:O to:O switch:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# can:O you:O teach:O me:O how:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# can:O you:O teach:O me:O how:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# can:O you:O teach:O me:O how:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# wheres:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# wheres:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# wheres:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O still:O dont:O know:O how:O to:O turn:O off:O this:O sound:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# i:O still:O dont:O know:O how:O to:O turn:O off:O this:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# i:O still:O dont:O know:O how:O to:O turn:O off:O this:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O adjust:O the:O wifi:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O adjust:O the:O sound:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O adjust:O the:O sound:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# where:O i:O learn:O to:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# where:O i:O learn:O to:O turn:O off:O the:O sound:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# where:O i:O learn:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# im:O market:O off:O the:O appleance:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature oven:B-appliance <=> on_off
#
# im:O market:O off:O the:O appleance:O sound:B-onofffeature oven:B-appliance <=> on_off
#
# im:O market:O off:O the:O appleance:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature oven:B-appliance <=> on_off
#
# how:O do:O i:O can:O turn:O on:O sound:B-onofffeature on:O the:O new:O oven:B-appliance <=> on_off
#
# how:O do:O i:O can:O turn:O on:O wifi:B-onofffeature on:O the:O new:O oven:B-appliance <=> on_off
#
# how:O do:O i:O can:O turn:O on:O wifi:B-onofffeature on:O the:O new:O oven:B-appliance <=> on_off
#
# could:O you:O help:O me:O to:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# could:O you:O help:O me:O to:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# could:O you:O help:O me:O to:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# i:O want:O to:O fix:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O want:O to:O fix:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O want:O to:O fix:O the:O sound:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O acctivate:O the:O sound:B-onofffeature in:O the:O oven:B-appliance app:O <=> on_off
#
# how:O can:O i:O acctivate:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance app:O <=> on_off
#
# how:O can:O i:O acctivate:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance app:O <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance please:O <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance please:O <=> on_off
#
# how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance please:O <=> on_off
#
# please:O turn:O off:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# please:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# please:O turn:O off:O the:O sound:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O safely:O turn:O off:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O safely:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O safely:O turn:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O on:O my:O wifi:B-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O on:O my:O sound:B-onofffeature oven:B-appliance <=> on_off
#
# how:O can:O i:O turn:O on:O my:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature oven:B-appliance <=> on_off
#
# how:O can:O i:O disconnect:O sound:B-onofffeature with:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O disconnect:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature with:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O disconnect:O wifi:B-onofffeature with:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance wen:O <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance wen:O <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance wen:O <=> on_off
#
# hello:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# hello:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# hello:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# the:O dog:O is:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# the:O dog:O is:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# the:O dog:O is:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# why:O was:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# why:O was:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# why:O was:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# who:O the:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# who:O the:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# who:O the:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O would:O like:O to:O clarify:O the:O doubt:O soon:O about:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# hello:O please:O tell:O me:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# hello:O please:O tell:O me:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# hello:O please:O tell:O me:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# dude:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# dude:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# dude:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# show:O me:O the:O off:O sound:B-onofffeature for:O the:O microwavawe:B-appliance <=> on_off
#
# show:O me:O the:O off:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature for:O the:O microwavawe:B-appliance <=> on_off
#
# show:O me:O the:O off:O sound:B-onofffeature for:O the:O oven:B-appliance <=> on_off
#
# how:O to:O start:O wifi:B-onofffeature in:O microwavawe:B-appliance <=> on_off
#
# how:O to:O start:O sound:B-onofffeature in:O microwavawe:B-appliance <=> on_off
#
# how:O to:O start:O sound:B-onofffeature in:O microwavawe:B-appliance <=> on_off
#
# in:O which:O way:O do:O i:O switch:O on:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature of:O my:O oven:B-appliance <=> on_off
#
# in:O which:O way:O do:O i:O switch:O on:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature of:O my:O microwavawe:B-appliance <=> on_off
#
# in:O which:O way:O do:O i:O switch:O on:O sound:B-onofffeature of:O my:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O deactivate:O and:O activate:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O can:O i:O deactivate:O and:O activate:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O deactivate:O and:O activate:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O sound:B-onofffeature on:O an:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O sound:B-onofffeature on:O an:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O sound:B-onofffeature on:O an:O oven:B-appliance <=> on_off
#
# how:O i:O open:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature for:O the:O microwavawe:B-appliance <=> on_off
#
# how:O i:O open:O sound:B-onofffeature for:O the:O oven:B-appliance <=> on_off
#
# how:O i:O open:O sound:B-onofffeature for:O the:O oven:B-appliance <=> on_off
#
# to:O turn:O on:O a:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# to:O turn:O on:O a:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# to:O turn:O on:O a:O sound:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O need:O to:O realize:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O need:O to:O realize:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# i:O need:O to:O realize:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off

# %%
create_data_file(f_valid,data_valid)
# Out:
# is:O the:O oven:B-appliance ceramic:B-cookware safe:O <=> appropriate
#
# is:O the:O microwavawe:B-appliance paper:B-cookware safe:O <=> appropriate
#
# is:O the:O oven:B-appliance polyester:B-cookware cup:I-cookware safe:O <=> appropriate
#
# will:O it:O be:O safe:O to:O use:O the:O plastic:B-cookware on:O the:O microwavawe:B-appliance <=> appropriate
#
# will:O it:O be:O safe:O to:O use:O the:O metal:B-cookware trimes:I-cookware on:O the:O microwavawe:B-appliance <=> appropriate
#
# will:O it:O be:O safe:O to:O use:O the:O browning:B-cookware plate:I-cookware on:O the:O microwavawe:B-appliance <=> appropriate
#
# can:O i:O safely:O use:O wicker:B-cookware on:O my:O microwavawe:B-appliance <=> appropriate
#
# can:O i:O safely:O use:O polyester:B-cookware cardboard:I-cookware on:O my:O oven:B-appliance <=> appropriate
#
# can:O i:O safely:O use:O thermometer:B-cookware on:O my:O microwavawe:B-appliance <=> appropriate
#
# is:O there:O any:O type:O of:O wood:B-cookware i:O should:O avoid:O using:O when:O cooking:O on:O oven:B-appliance <=> appropriate
#
# is:O there:O any:O type:O of:O porcelain:B-cookware i:O should:O avoid:O using:O when:O cooking:O on:O microwavawe:B-appliance <=> appropriate
#
# is:O there:O any:O type:O of:O stoneware:B-cookware i:O should:O avoid:O using:O when:O cooking:O on:O microwavawe:B-appliance <=> appropriate
#
# where:O can:O i:O find:O a:O new:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O find:O a:O new:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O find:O a:O new:O charcoal:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# looking:O to:O buy:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# looking:O to:O buy:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance <=> buy
#
# looking:O to:O buy:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# what:O store:O carried:O graphite:B-parttype lubricant:I-parttype so:O i:O can:O buy:O it:O for:O my:O microwavawe:B-appliance <=> buy
#
# what:O store:O carried:O air:B-parttype fry:I-parttype tray:I-parttype so:O i:O can:O buy:O it:O for:O my:O oven:B-appliance <=> buy
#
# what:O store:O carried:O light:B-parttype so:O i:O can:O buy:O it:O for:O my:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O buy:O a:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O need:O to:O purchase:O an:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O need:O to:O purchase:O an:O charcoal:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O need:O to:O purchase:O an:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# tell:O me:O how:O to:O polish:O the:O stainless:B-cleanobject steel:I-cleanobject with:O the:O oven:B-appliance <=> clean
#
# tell:O me:O how:O to:O polish:O the:O door:B-cleanobject gasket:I-cleanobject with:O the:O microwavawe:B-appliance <=> clean
#
# tell:O me:O how:O to:O polish:O the:O glass:B-cleanobject cooktop:I-cleanobject with:O the:O oven:B-appliance <=> clean
#
# would:O you:O please:O tell:O me:O how:O to:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# would:O you:O please:O tell:O me:O how:O to:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# would:O you:O please:O tell:O me:O how:O to:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O you:O show:O me:O some:O ways:O to:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O you:O show:O me:O some:O ways:O to:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# can:O you:O show:O me:O some:O ways:O to:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O want:O to:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O want:O to:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O want:O to:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O is:O the:O meaning:O of:O the:O c-30:B-infocode message:O on:O my:O microwavawe:B-appliance <=> code
#
# what:O is:O the:O meaning:O of:O the:O c-d0:B-infocode message:O on:O my:O microwavawe:B-appliance <=> code
#
# what:O is:O the:O meaning:O of:O the:O c-21:B-infocode message:O on:O my:O microwavawe:B-appliance <=> code
#
# what:O does:O this:O c-22:B-infocode mean:O that:O is:O popping:O up:O on:O microwavawe:B-appliance <=> code
#
# what:O does:O this:O c-d0:B-infocode mean:O that:O is:O popping:O up:O on:O oven:B-appliance <=> code
#
# what:O does:O this:O c-31:B-infocode mean:O that:O is:O popping:O up:O on:O microwavawe:B-appliance <=> code
#
# what:O does:O it:O mean:O if:O my:O microwavawe:B-appliance has:O an:O c-d0:B-infocode error:O <=> code
#
# what:O does:O it:O mean:O if:O my:O microwavawe:B-appliance has:O an:O c-d1:B-infocode error:O <=> code
#
# what:O does:O it:O mean:O if:O my:O microwavawe:B-appliance has:O an:O c-20:B-infocode error:O <=> code
#
# what:O does:O code:O c-22:B-infocode mean:O on:O my:O microwavawe:B-appliance <=> code
#
# what:O does:O code:O c-21:B-infocode mean:O on:O my:O microwavawe:B-appliance <=> code
#
# what:O does:O code:O c-d1:B-infocode mean:O on:O my:O oven:B-appliance <=> code
#
# i:O have:O an:O error:O called:O c-d1:B-infocode on:O my:O microwavawe:B-appliance and:O there:O is:O <=> code
#
# i:O have:O an:O error:O called:O c-d0:B-infocode on:O my:O oven:B-appliance and:O there:O is:O <=> code
#
# i:O have:O an:O error:O called:O c-22:B-infocode on:O my:O oven:B-appliance and:O there:O is:O <=> code
#
# how:O do:O i:O use:O the:O oven:B-appliance to:O prepare:O the:O breaded:B-foodtype egg:I-foodtype plants:I-foodtype <=> cook
#
# how:O do:O i:O use:O the:O oven:B-appliance to:O prepare:O the:O frozen:B-foodtype churros:I-foodtype <=> cook
#
# how:O do:O i:O use:O the:O microwavawe:B-appliance to:O prepare:O the:O pork:B-foodtype chops:I-foodtype <=> cook
#
# can:O you:O tell:O me:O how:O i:O can:O use:O oven:B-appliance to:O cook:O frozen:B-foodtype tater:I-foodtype tots:I-foodtype <=> cook
#
# can:O you:O tell:O me:O how:O i:O can:O use:O oven:B-appliance to:O cook:O frozen:B-foodtype dinner:I-foodtype <=> cook
#
# can:O you:O tell:O me:O how:O i:O can:O use:O microwavawe:B-appliance to:O cook:O frozen:B-foodtype breakfast:I-foodtype <=> cook
#
# what:O must:O i:O do:O to:O cook:O salmon:B-foodtype steak:I-foodtype with:O the:O oven:B-appliance <=> cook
#
# what:O must:O i:O do:O to:O cook:O roast:B-foodtype beef:I-foodtype with:O the:O oven:B-appliance <=> cook
#
# what:O must:O i:O do:O to:O cook:O eggs:B-foodtype with:O the:O microwavawe:B-appliance <=> cook
#
# what:O do:O i:O do:O to:O cook:O frozen:B-foodtype fish:I-foodtype fingers:I-foodtype on:O the:O oven:B-appliance <=> cook
#
# what:O do:O i:O do:O to:O cook:O frozen:B-foodtype potato:I-foodtype wedges:I-foodtype on:O the:O microwavawe:B-appliance <=> cook
#
# what:O do:O i:O do:O to:O cook:O whole:B-foodtype chicken:I-foodtype on:O the:O microwavawe:B-appliance <=> cook
#
# how:O do:O i:O bake:O a:O frozen:B-foodtype chicken:I-foodtype wings:I-foodtype in:O the:O microwavawe:B-appliance <=> cook
#
# how:O do:O i:O bake:O a:O frozen:B-foodtype onion:I-foodtype rings:I-foodtype in:O the:O microwavawe:B-appliance <=> cook
#
# how:O do:O i:O bake:O a:O frozen:B-foodtype fish:I-foodtype fingers:I-foodtype in:O the:O microwavawe:B-appliance <=> cook
#
# can:O you:O help:O me:O find:O ways:O to:O remove:O rack:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# can:O you:O help:O me:O find:O ways:O to:O remove:O rack:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# can:O you:O help:O me:O find:O ways:O to:O remove:O stains:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# can:O i:O remove:O the:O drawer:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# can:O i:O remove:O the:O residue:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# can:O i:O remove:O the:O door:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# find:O me:O instructions:O for:O removing:O an:O lights:B-removeobject from:O oven:B-appliance <=> remove
#
# find:O me:O instructions:O for:O removing:O an:O rack:B-removeobject from:O oven:B-appliance <=> remove
#
# find:O me:O instructions:O for:O removing:O an:O lights:B-removeobject from:O microwavawe:B-appliance <=> remove
#
# why:O do:O i:O remove:O rack:B-removeobject from:O the:O oven:B-appliance but:O <=> remove
#
# why:O do:O i:O remove:O lights:B-removeobject from:O the:O oven:B-appliance but:O <=> remove
#
# why:O do:O i:O remove:O lights:B-removeobject from:O the:O oven:B-appliance but:O <=> remove
#
# is:O it:O possible:O to:O remove:O the:O rack:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# is:O it:O possible:O to:O remove:O the:O rack:B-removeobject from:O the:O oven:B-appliance <=> remove
#
# is:O it:O possible:O to:O remove:O the:O residue:B-removeobject from:O the:O microwavawe:B-appliance <=> remove
#
# what:O is:O the:O proper:O way:O to:O reinstall:O the:O door:B-replaceobject on:O the:O oven:B-appliance <=> replace
#
# what:O is:O the:O proper:O way:O to:O reinstall:O the:O cooktop:B-replaceobject on:O the:O oven:B-appliance <=> replace
#
# what:O is:O the:O proper:O way:O to:O reinstall:O the:O oven:B-replaceobject light:I-replaceobject on:O the:O microwavawe:B-appliance <=> replace
#
# i:O would:O like:O to:O replace:O the:O charcoal:B-replaceobject filter:I-replaceobject from:O the:O microwavawe:B-appliance <=> replace
#
# i:O would:O like:O to:O replace:O the:O oven:B-replaceobject light:I-replaceobject from:O the:O oven:B-appliance <=> replace
#
# i:O would:O like:O to:O replace:O the:O cooktop:B-replaceobject from:O the:O microwavawe:B-appliance <=> replace
#
# how:O do:O i:O reinstall:O the:O drawer:B-replaceobject in:O my:O oven:B-appliance <=> replace
#
# how:O do:O i:O reinstall:O the:O oven:B-replaceobject light:I-replaceobject in:O my:O oven:B-appliance <=> replace
#
# how:O do:O i:O reinstall:O the:O oven:B-replaceobject light:I-replaceobject in:O my:O microwavawe:B-appliance <=> replace
#
# can:O you:O show:O me:O how:O to:O reinstall:O the:O night:B-replaceobject light:I-replaceobject for:O the:O microwavawe:B-appliance <=> replace
#
# can:O you:O show:O me:O how:O to:O reinstall:O the:O charcoal:B-replaceobject filter:I-replaceobject for:O the:O oven:B-appliance <=> replace
#
# can:O you:O show:O me:O how:O to:O reinstall:O the:O cooktop:B-replaceobject for:O the:O microwavawe:B-appliance <=> replace
#
# how:O do:O i:O set:O the:O baking:B-setfeature feature:O on:O my:O oven:B-appliance <=> set
#
# how:O do:O i:O set:O the:O convection:B-setfeature baking:I-setfeature feature:O on:O my:O oven:B-appliance <=> set
#
# how:O do:O i:O set:O the:O steam:B-setfeature clean:I-setfeature feature:O on:O my:O microwavawe:B-appliance <=> set
#
# could:O you:O tell:O me:O how:O do:O i:O set:O the:O smart:B-setfeature control:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# could:O you:O tell:O me:O how:O do:O i:O set:O the:O broiling:B-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# could:O you:O tell:O me:O how:O do:O i:O set:O the:O baking:B-setfeature on:O my:O oven:B-appliance <=> set
#
# why:O do:O i:O set:O the:O convection:B-setfeature baking:I-setfeature feature:O on:O my:O microwavawe:B-appliance but:O <=> set
#
# why:O do:O i:O set:O the:O timed:B-setfeature cooking:I-setfeature feature:O on:O my:O oven:B-appliance but:O <=> set
#
# why:O do:O i:O set:O the:O smart:B-setfeature control:I-setfeature feature:O on:O my:O oven:B-appliance but:O <=> set
#
# what:O is:O the:O proper:O way:O to:O set:O the:O air:B-setfeature fry:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# what:O is:O the:O proper:O way:O to:O set:O the:O broiling:B-setfeature on:O my:O oven:B-appliance <=> set
#
# what:O is:O the:O proper:O way:O to:O set:O the:O convection:B-setfeature roast:I-setfeature on:O my:O microwavawe:B-appliance <=> set
#
# i:O need:O you:O to:O tell:O me:O how:O to:O set:O steam:B-setfeature clean:I-setfeature on:O my:O microwavawe:B-appliance please:O <=> set
#
# i:O need:O you:O to:O tell:O me:O how:O to:O set:O timed:B-setfeature cooking:I-setfeature on:O my:O microwavawe:B-appliance please:O <=> set
#
# i:O need:O you:O to:O tell:O me:O how:O to:O set:O convection:B-setfeature baking:I-setfeature on:O my:O microwavawe:B-appliance please:O <=> set
#
# show:O me:O how:O to:O setup:O the:O power:B-setfeature level:I-setfeature on:O the:O oven:B-appliance <=> set
#
# show:O me:O how:O to:O setup:O the:O baking:B-setfeature on:O the:O microwavawe:B-appliance <=> set
#
# show:O me:O how:O to:O setup:O the:O steam:B-setfeature clean:I-setfeature on:O the:O oven:B-appliance <=> set
#
# how:O do:O i:O turn:O off:O the:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O turn:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O turn:O off:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# show:O how:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature turns:O off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# show:O how:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature turns:O off:O on:O the:O oven:B-appliance <=> on_off
#
# show:O how:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature turns:O off:O on:O the:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O i:O can:O switch:O off:O the:O sound:B-onofffeature on:O this:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O i:O can:O switch:O off:O the:O sound:B-onofffeature on:O this:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O i:O can:O switch:O off:O the:O sound:B-onofffeature on:O this:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O wifi:B-onofffeature the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O turn:O on:O the:O wifi:B-onofffeature the:O microwavawe:B-appliance <=> on_off
#
# show:O me:O how:O the:O melt:B-usefeature works:O on:O the:O oven:B-appliance <=> use
#
# show:O me:O how:O the:O reheat:B-usefeature works:O on:O the:O oven:B-appliance <=> use
#
# show:O me:O how:O the:O bread:B-usefeature proof:I-usefeature works:O on:O the:O oven:B-appliance <=> use
#
# how:O can:O i:O use:O the:O 12:B-usefeature hour:I-usefeature energy:I-usefeature saving:I-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# how:O can:O i:O use:O the:O add:B-usefeature 30:I-usefeature sec:I-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# how:O can:O i:O use:O the:O add:B-usefeature 30:I-usefeature sec:I-usefeature on:O the:O oven:B-appliance <=> use
#
# i:O need:O to:O know:O how:O to:O use:O the:O child:B-usefeature lock:I-usefeature on:O this:O microwavawe:B-appliance can:O you:O tell:O me:O <=> use
#
# i:O need:O to:O know:O how:O to:O use:O the:O demo:B-usefeature mode:I-usefeature on:O this:O oven:B-appliance can:O you:O tell:O me:O <=> use
#
# i:O need:O to:O know:O how:O to:O use:O the:O soften:B-usefeature on:O this:O oven:B-appliance can:O you:O tell:O me:O <=> use
#
# what:O are:O the:O instructions:O in:O using:O the:O demo:B-usefeature mode:I-usefeature on:O the:O oven:B-appliance <=> use
#
# what:O are:O the:O instructions:O in:O using:O the:O add:B-usefeature 30:I-usefeature sec:I-usefeature on:O the:O oven:B-appliance <=> use
#
# what:O are:O the:O instructions:O in:O using:O the:O dehydrate:B-usefeature on:O the:O microwavawe:B-appliance <=> use
#
# what:O is:O the:O convention:B-purposefeature roast:I-purposefeature for:O on:O my:O oven:B-appliance <=> purpose
#
# what:O is:O the:O convention:B-purposefeature roast:I-purposefeature for:O on:O my:O oven:B-appliance <=> purpose
#
# what:O is:O the:O display:B-purposefeature for:O on:O my:O oven:B-appliance <=> purpose
#
# tell:O me:O what:O the:O clock:B-purposefeature do:O on:O the:O microwavawe:B-appliance <=> purpose
#
# tell:O me:O what:O the:O dehydrate:B-purposefeature do:O on:O the:O microwavawe:B-appliance <=> purpose
#
# tell:O me:O what:O the:O off:B-purposefeature clear:I-purposefeature do:O on:O the:O oven:B-appliance <=> purpose
#
# what:O is:O the:O purpose:O of:O the:O broil:B-purposefeature on:O the:O microwavawe:B-appliance <=> purpose
#
# what:O is:O the:O purpose:O of:O the:O bread:B-purposefeature proof:I-purposefeature on:O the:O oven:B-appliance <=> purpose
#
# what:O is:O the:O purpose:O of:O the:O keep:B-purposefeature warm:I-purposefeature on:O the:O oven:B-appliance <=> purpose
#
# what:O is:O the:O purpose:O of:O the:O steam:B-purposefeature clean:I-purposefeature on:O the:O oven:B-appliance <=> purpose
#
# what:O is:O the:O purpose:O of:O the:O convention:B-purposefeature roast:I-purposefeature on:O the:O microwavawe:B-appliance <=> purpose
#
# what:O is:O the:O purpose:O of:O the:O smart:B-purposefeature control:I-purposefeature on:O the:O oven:B-appliance <=> purpose
#
# what:O exactly:O is:O the:O purpose:O of:O broil:B-purposefeature on:O this:O microwavawe:B-appliance <=> purpose
#
# what:O exactly:O is:O the:O purpose:O of:O setting:B-purposefeature on:O this:O microwavawe:B-appliance <=> purpose
#
# what:O exactly:O is:O the:O purpose:O of:O dehydrate:B-purposefeature on:O this:O oven:B-appliance <=> purpose
#
# want:O to:O bye:O a:O graphite:B-parttype lubricant:I-parttype and:O microwavawe:B-appliance <=> buy
#
# want:O to:O bye:O a:O light:B-parttype and:O oven:B-appliance <=> buy
#
# want:O to:O bye:O a:O charcoal:B-parttype filter:I-parttype and:O microwavawe:B-appliance <=> buy
#
# where:O is:O it:O possible:O to:O get:O charcoal:B-parttype filter:I-parttype to:O get:O my:O oven:B-appliance working:O <=> buy
#
# where:O is:O it:O possible:O to:O get:O charcoal:B-parttype filter:I-parttype to:O get:O my:O microwavawe:B-appliance working:O <=> buy
#
# where:O is:O it:O possible:O to:O get:O storage:B-parttype drawer:I-parttype to:O get:O my:O oven:B-appliance working:O <=> buy
#
# where:O how:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O how:O i:O buy:O a:O light:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O how:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# could:O i:O buy:O an:O brackets:B-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# could:O i:O buy:O an:O light:B-parttype for:O an:O oven:B-appliance <=> buy
#
# could:O i:O buy:O an:O brackets:B-parttype for:O an:O oven:B-appliance <=> buy
#
# where:O can:O i:O purchase:O a:O storage:B-parttype drawer:I-parttype from:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O purchase:O a:O grease:B-parttype filter:I-parttype from:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O purchase:O a:O graphite:B-parttype lubricant:I-parttype from:O my:O oven:B-appliance <=> buy
#
# how:O do:O i:O buy:O the:O light:B-parttype of:O the:O oven:B-appliance <=> buy
#
# how:O do:O i:O buy:O the:O screws:B-parttype of:O the:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O buy:O the:O light:B-parttype of:O the:O oven:B-appliance <=> buy
#
# i:O want:O to:O buy:O an:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O want:O to:O buy:O an:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O want:O to:O buy:O an:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O do:O i:O buy:O an:O grease:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O do:O i:O buy:O an:O charcoal:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O do:O i:O buy:O an:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# it:O would:O be:O great:O to:O be:O able:O to:O buy:O a:O door:B-parttype for:O an:O oven:B-appliance <=> buy
#
# it:O would:O be:O great:O to:O be:O able:O to:O buy:O a:O light:B-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# it:O would:O be:O great:O to:O be:O able:O to:O buy:O a:O glass:B-parttype tray:I-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# where:O is:O that:O you:O can:O buy:O these:O graphite:B-parttype lubricant:I-parttype for:O an:O microwavawe:B-appliance <=> buy
#
# where:O is:O that:O you:O can:O buy:O these:O light:B-parttype for:O an:O oven:B-appliance <=> buy
#
# where:O is:O that:O you:O can:O buy:O these:O hardware:B-parttype kit:I-parttype for:O an:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# hello:O where:O can:O i:O place:O them:O hello:O friends:O of:O charcoal:B-parttype filter:I-parttype microwavawe:B-appliance <=> buy
#
# hello:O where:O can:O i:O place:O them:O hello:O friends:O of:O door:B-parttype oven:B-appliance <=> buy
#
# hello:O where:O can:O i:O place:O them:O hello:O friends:O of:O charcoal:B-parttype filter:I-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O oven:B-appliance today:O <=> buy
#
# where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance today:O <=> buy
#
# where:O can:O i:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance today:O <=> buy
#
# how:O can:O i:O get:O some:O of:O my:O exhaust:B-parttype filter:I-parttype microwavawe:B-appliance <=> buy
#
# how:O can:O i:O get:O some:O of:O my:O storage:B-parttype drawer:I-parttype oven:B-appliance <=> buy
#
# how:O can:O i:O get:O some:O of:O my:O screws:B-parttype microwavawe:B-appliance <=> buy
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O where:O can:O i:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O get:O a:O screws:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O get:O a:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O get:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O want:O to:O know:O where:O can:O i:O buy:O a:O screws:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O want:O to:O know:O where:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O want:O to:O know:O where:O can:O i:O buy:O a:O screws:B-parttype for:O my:O oven:B-appliance <=> buy
#
# no:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance yes:O <=> buy
#
# no:O where:O can:O i:O buy:O a:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance yes:O <=> buy
#
# no:O where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance yes:O <=> buy
#
# you:O are:O the:O on:O 15:O minutes:O the:O how:O a:O feature:O off:O air:B-parttype fry:I-parttype tray:I-parttype microwavawe:B-appliance <=> buy
#
# you:O are:O the:O on:O 15:O minutes:O the:O how:O a:O feature:O off:O hardware:B-parttype kit:I-parttype oven:B-appliance <=> buy
#
# you:O are:O the:O on:O 15:O minutes:O the:O how:O a:O feature:O off:O charcoal:B-parttype filter:I-parttype oven:B-appliance <=> buy
#
# please:O help:O me:O to:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# please:O help:O me:O to:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# please:O help:O me:O to:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O can:O i:O buy:O a:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O light:B-parttype for:O my:O oven:B-appliance bad:O <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance bad:O <=> buy
#
# where:O can:O i:O buy:O a:O door:B-parttype for:O my:O microwavawe:B-appliance bad:O <=> buy
#
# will:O you:O find:O the:O door:B-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# will:O you:O find:O the:O brackets:B-parttype for:O the:O oven:B-appliance <=> buy
#
# will:O you:O find:O the:O door:B-parttype for:O the:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O screws:B-parttype for:O my:O microwavawe:B-appliance wen:O <=> buy
#
# where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance wen:O <=> buy
#
# where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance wen:O <=> buy
#
# where:O can:O i:O buy:O graphite:B-parttype lubricant:I-parttype in:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O grease:B-parttype filter:I-parttype in:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O hardware:B-parttype kit:I-parttype in:O microwavawe:B-appliance <=> buy
#
# cant:O buy:O a:O light:B-parttype for:O my:O oven:B-appliance <=> buy
#
# cant:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# cant:O buy:O a:O brackets:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# looking:O to:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype in:O my:O microwavawe:B-appliance <=> buy
#
# looking:O to:O buy:O a:O screws:B-parttype in:O my:O microwavawe:B-appliance <=> buy
#
# looking:O to:O buy:O a:O exhaust:B-parttype filter:I-parttype in:O my:O microwavawe:B-appliance <=> buy
#
# what:O is:O the:O phone:O number:O of:O the:O store:O where:O they:O sell:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# what:O is:O the:O phone:O number:O of:O the:O store:O where:O they:O sell:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance <=> buy
#
# what:O is:O the:O phone:O number:O of:O the:O store:O where:O they:O sell:O screws:B-parttype for:O my:O oven:B-appliance <=> buy
#
# please:O explain:O to:O me:O how:O to:O buy:O the:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# please:O explain:O to:O me:O how:O to:O buy:O the:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# please:O explain:O to:O me:O how:O to:O buy:O the:O screws:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O buy:O a:O screws:B-parttype oven:B-appliance please:O <=> buy
#
# where:O can:O buy:O a:O storage:B-parttype drawer:I-parttype microwavawe:B-appliance please:O <=> buy
#
# where:O can:O buy:O a:O charcoal:B-parttype filter:I-parttype microwavawe:B-appliance please:O <=> buy
#
# i:O need:O buy:O a:O graphite:B-parttype lubricant:I-parttype to:O my:O microwavawe:B-appliance where:O i:O can:O <=> buy
#
# i:O need:O buy:O a:O glass:B-parttype tray:I-parttype to:O my:O oven:B-appliance where:O i:O can:O <=> buy
#
# i:O need:O buy:O a:O door:B-parttype to:O my:O oven:B-appliance where:O i:O can:O <=> buy
#
# how:O do:O i:O pay:O my:O door:B-parttype in:O the:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O pay:O my:O wirerack:B-parttype in:O the:O microwavawe:B-appliance <=> buy
#
# how:O do:O i:O pay:O my:O storage:B-parttype drawer:I-parttype in:O the:O microwavawe:B-appliance <=> buy
#
# what:O color:O is:O roller:B-parttype guide:I-parttype ring:I-parttype available:O for:O my:O oven:B-appliance <=> buy
#
# what:O color:O is:O exhaust:B-parttype filter:I-parttype available:O for:O my:O oven:B-appliance <=> buy
#
# what:O color:O is:O hardware:B-parttype kit:I-parttype available:O for:O my:O oven:B-appliance <=> buy
#
# how:O and:O where:O to:O buy:O light:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# how:O and:O where:O to:O buy:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance <=> buy
#
# how:O and:O where:O to:O buy:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O lapto:O today:O charcoal:B-parttype filter:I-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O lapto:O today:O storage:B-parttype drawer:I-parttype microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O lapto:O today:O hardware:B-parttype kit:I-parttype oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O simple:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O simple:O roller:B-parttype guide:I-parttype ring:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O simple:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O need:O to:O know:O please:O where:O can:O i:O buy:O a:O air:B-parttype fry:I-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O need:O to:O know:O please:O where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O need:O to:O know:O please:O where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# who:O the:O where:O can:O i:O buy:O a:O brackets:B-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O the:O where:O can:O i:O buy:O a:O wirerack:B-parttype for:O my:O oven:B-appliance <=> buy
#
# who:O the:O where:O can:O i:O buy:O a:O grease:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# what:O was:O where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O oven:B-appliance <=> buy
#
# what:O was:O where:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# what:O was:O where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O need:O know:O where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# i:O need:O know:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# i:O need:O know:O where:O can:O i:O buy:O a:O exhaust:B-parttype filter:I-parttype for:O my:O oven:B-appliance <=> buy
#
# hi:O darling:O where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance <=> buy
#
# hi:O darling:O where:O can:O i:O buy:O a:O graphite:B-parttype lubricant:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# hi:O darling:O where:O can:O i:O buy:O a:O glass:B-parttype tray:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# they:O have:O free:O wirerack:B-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# they:O have:O free:O hardware:B-parttype kit:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# they:O have:O free:O exhaust:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O oven:B-appliance here:O yes:O or:O no:O now:O <=> buy
#
# where:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance here:O yes:O or:O no:O now:O <=> buy
#
# where:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance here:O yes:O or:O no:O now:O <=> buy
#
# where:O can:O i:O buy:O a:O charcoal:B-parttype filter:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O hardware:B-parttype kit:I-parttype for:O my:O oven:B-appliance <=> buy
#
# where:O can:O i:O buy:O a:O storage:B-parttype drawer:I-parttype for:O my:O microwavawe:B-appliance <=> buy
#
# would:O you:O help:O me:O get:O roller:B-parttype guide:I-parttype ring:I-parttype for:O me:O oven:B-appliance <=> buy
#
# would:O you:O help:O me:O get:O light:B-parttype for:O me:O microwavawe:B-appliance <=> buy
#
# would:O you:O help:O me:O get:O glass:B-parttype tray:I-parttype for:O me:O microwavawe:B-appliance <=> buy
#
# yes:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# yes:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# yes:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# cleaning:O glass:B-cleanobject cooktop:I-cleanobject for:O my:O microwavawe:B-appliance <=> clean
#
# cleaning:O sugary-spills:B-cleanobject for:O my:O microwavawe:B-appliance <=> clean
#
# cleaning:O cooktop:B-cleanobject for:O my:O oven:B-appliance <=> clean
#
# what:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# what:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# what:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O can:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject off:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O clean:O the:O melted-plastic:B-cleanobject off:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject off:O the:O oven:B-appliance <=> clean
#
# how:O to:O make:O some:O of:O the:O cooktop:B-cleanobject seal:I-cleanobject microwavawe:B-appliance <=> clean
#
# how:O to:O make:O some:O of:O the:O sugary-spills:B-cleanobject microwavawe:B-appliance <=> clean
#
# how:O to:O make:O some:O of:O the:O melted-plastic:B-cleanobject microwavawe:B-appliance <=> clean
#
# can:O be:O cleaned:O now:O door:B-cleanobject gasket:I-cleanobject microwavawe:B-appliance <=> clean
#
# can:O be:O cleaned:O now:O cooktop:B-cleanobject seal:I-cleanobject microwavawe:B-appliance <=> clean
#
# can:O be:O cleaned:O now:O grease:B-cleanobject filter:I-cleanobject oven:B-appliance <=> clean
#
# sir:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# sir:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# sir:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# is:O there:O any:O way:O to:O stainless:B-cleanobject steel:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# is:O there:O any:O way:O to:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# is:O there:O any:O way:O to:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# im:O asking:O myself:O now:O the:O question:O about:O i:O need:O to:O know:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# always:O to:O have:O your:O things:O clean:O door:B-cleanobject gasket:I-cleanobject oven:B-appliance <=> clean
#
# always:O to:O have:O your:O things:O clean:O cooktop:B-cleanobject microwavawe:B-appliance <=> clean
#
# always:O to:O have:O your:O things:O clean:O melted-plastic:B-cleanobject microwavawe:B-appliance <=> clean
#
# how:O can:O i:O bring:O clean:O some:O of:O my:O grease:B-cleanobject filter:I-cleanobject oven:B-appliance <=> clean
#
# how:O can:O i:O bring:O clean:O some:O of:O my:O sugary-spills:B-cleanobject microwavawe:B-appliance <=> clean
#
# how:O can:O i:O bring:O clean:O some:O of:O my:O grease:B-cleanobject filter:I-cleanobject microwavawe:B-appliance <=> clean
#
# with:O which:O objects:O can:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject in:O microwavawe:B-appliance <=> clean
#
# with:O which:O objects:O can:O i:O clean:O the:O cooktop:B-cleanobject in:O oven:B-appliance <=> clean
#
# with:O which:O objects:O can:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject in:O microwavawe:B-appliance <=> clean
#
# how:O do:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance clean:O <=> clean
#
# how:O do:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance clean:O <=> clean
#
# how:O do:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance clean:O <=> clean
#
# how:O do:O i:O quickly:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O quickly:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O quickly:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O about:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O about:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# i:O would:O like:O to:O clarify:O the:O doubt:O about:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance really:O <=> clean
#
# how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance really:O <=> clean
#
# how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance really:O <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance wen:O <=> clean
#
# how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance wen:O <=> clean
#
# how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance wen:O <=> clean
#
# can:O you:O clean:O the:O melted-plastic:B-cleanobject in:O the:O oven:B-appliance <=> clean
#
# can:O you:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# can:O you:O clean:O the:O sugary-spills:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O phone:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O phone:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O phone:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O make:O very:O clean:O my:O cooktop:B-cleanobject microwavawe:B-appliance <=> clean
#
# how:O can:O i:O make:O very:O clean:O my:O melted-plastic:B-cleanobject oven:B-appliance <=> clean
#
# how:O can:O i:O make:O very:O clean:O my:O cooktop:B-cleanobject seal:I-cleanobject microwavawe:B-appliance <=> clean
#
# how:O is:O it:O better:O to:O clean:O the:O melted-plastic:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O is:O it:O better:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O is:O it:O better:O to:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# what:O was:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# what:O was:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# what:O was:O how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# the:O why:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# the:O why:O how:O do:O i:O clean:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# the:O why:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O clean:O this:O part:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O clean:O this:O part:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O clean:O this:O part:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# clean:O part:O of:O door:B-cleanobject gasket:I-cleanobject oven:B-appliance 2:O <=> clean
#
# clean:O part:O of:O sugary-spills:B-cleanobject oven:B-appliance 2:O <=> clean
#
# clean:O part:O of:O cooktop:B-cleanobject seal:I-cleanobject oven:B-appliance 2:O <=> clean
#
# how:O can:O i:O send:O it:O to:O the:O trash:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O send:O it:O to:O the:O trash:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O can:O i:O send:O it:O to:O the:O trash:O the:O sugary-spills:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O can:O i:O make:O my:O grease:B-cleanobject filter:I-cleanobject oven:B-appliance stunning:O <=> clean
#
# how:O can:O i:O make:O my:O cooktop:B-cleanobject seal:I-cleanobject microwavawe:B-appliance stunning:O <=> clean
#
# how:O can:O i:O make:O my:O cooktop:B-cleanobject seal:I-cleanobject oven:B-appliance stunning:O <=> clean
#
# does:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance need:O to:O be:O cleaned:O <=> clean
#
# does:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance need:O to:O be:O cleaned:O <=> clean
#
# does:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance need:O to:O be:O cleaned:O <=> clean
#
# can:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# can:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O to:O clean:O the:O inside:O of:O my:O device:O in:O sugary-spills:B-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O to:O clean:O the:O inside:O of:O my:O device:O in:O door:B-cleanobject gasket:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# how:O to:O clean:O the:O inside:O of:O my:O device:O in:O grease:B-cleanobject filter:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# please:O find:O me:O the:O right:O way:O to:O clean:O the:O grease:B-cleanobject filter:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# please:O find:O me:O the:O right:O way:O to:O clean:O the:O door:B-cleanobject gasket:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# please:O find:O me:O the:O right:O way:O to:O clean:O the:O sugary-spills:B-cleanobject in:O the:O oven:B-appliance <=> clean
#
# greeatings:O clean:O part:O of:O a:O appliance:O door:B-cleanobject gasket:I-cleanobject microwavawe:B-appliance <=> clean
#
# greeatings:O clean:O part:O of:O a:O appliance:O stainless:B-cleanobject steel:I-cleanobject oven:B-appliance <=> clean
#
# greeatings:O clean:O part:O of:O a:O appliance:O grease:B-cleanobject filter:I-cleanobject microwavawe:B-appliance <=> clean
#
# can:O you:O tell:O me:O how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O you:O tell:O me:O how:O do:O i:O clean:O the:O glass:B-cleanobject cooktop:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O you:O tell:O me:O how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# can:O you:O clean:O a:O cooktop:B-cleanobject in:O the:O oven:B-appliance <=> clean
#
# can:O you:O clean:O a:O grease:B-cleanobject filter:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# can:O you:O clean:O a:O glass:B-cleanobject cooktop:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# darling:O please:O tell:O me:O how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# darling:O please:O tell:O me:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# darling:O please:O tell:O me:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O you:O advise:O me:O to:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O do:O you:O advise:O me:O to:O clean:O the:O sugary-spills:B-cleanobject in:O the:O oven:B-appliance <=> clean
#
# how:O do:O you:O advise:O me:O to:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject in:O the:O microwavawe:B-appliance <=> clean
#
# i:O clean:O the:O cooktop:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# i:O clean:O the:O cooktop:B-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance before:O twelve:O oclock:O <=> clean
#
# how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O oven:B-appliance before:O twelve:O oclock:O <=> clean
#
# how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject on:O the:O microwavawe:B-appliance before:O twelve:O oclock:O <=> clean
#
# in:O which:O way:O do:O i:O clean:O grease:B-cleanobject filter:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# in:O which:O way:O do:O i:O clean:O grease:B-cleanobject filter:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# in:O which:O way:O do:O i:O clean:O door:B-cleanobject gasket:I-cleanobject on:O the:O oven:B-appliance <=> clean
#
# how:O do:O i:O clean:O the:O door:B-cleanobject gasket:I-cleanobject oven:B-appliance please:O please:O please:O 2:O <=> clean
#
# how:O do:O i:O clean:O the:O stainless:B-cleanobject steel:I-cleanobject oven:B-appliance please:O please:O please:O 2:O <=> clean
#
# how:O do:O i:O clean:O the:O melted-plastic:B-cleanobject microwavawe:B-appliance please:O please:O please:O 2:O <=> clean
#
# is:O it:O safe:O to:O clean:O sugary-spills:B-cleanobject on:O the:O oven:B-appliance <=> clean
#
# is:O it:O safe:O to:O clean:O door:B-cleanobject gasket:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# is:O it:O safe:O to:O clean:O stainless:B-cleanobject steel:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# please:O tell:O me:O how:O do:O i:O clean:O the:O cooktop:B-cleanobject seal:I-cleanobject on:O the:O microwavawe:B-appliance <=> clean
#
# ...
#
# no:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# no:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O to:O make:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O to:O make:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature oven:B-appliance <=> on_off
#
# how:O to:O make:O wifi:B-onofffeature microwavawe:B-appliance <=> on_off
#
# is:O it:O possible:O to:O disable:O sound:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# is:O it:O possible:O to:O disable:O wifi:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# is:O it:O possible:O to:O disable:O sound:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O the:O sound:B-onofffeature at:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O the:O sound:B-onofffeature at:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O the:O sound:B-onofffeature at:O the:O oven:B-appliance <=> on_off
#
# does:O wifi:B-onofffeature have:O this:O microwavawe:B-appliance <=> on_off
#
# does:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature have:O this:O microwavawe:B-appliance <=> on_off
#
# does:O sound:B-onofffeature have:O this:O oven:B-appliance <=> on_off
#
# how:O to:O activate:O sound:B-onofffeature in:O my:O oven:B-appliance <=> on_off
#
# how:O to:O activate:O wifi:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O to:O activate:O sound:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O turn:O off:O the:O sound:B-onofffeature i:O the:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O turn:O off:O the:O sound:B-onofffeature i:O the:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O turn:O off:O the:O wifi:B-onofffeature i:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O use:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O use:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O can:O i:O use:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# turn:O off:O already:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature and:O microwavawe:B-appliance <=> on_off
#
# turn:O off:O already:O sound:B-onofffeature and:O microwavawe:B-appliance <=> on_off
# turn:O off:O already:O wifi:B-onofffeature and:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O best:O way:O to:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O this:O oven:B-appliance <=> on_off
#
# what:O is:O the:O best:O way:O to:O switch:O the:O wifi:B-onofffeature off:O on:O this:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O best:O way:O to:O switch:O the:O wifi:B-onofffeature off:O on:O this:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature more:O quickly:O on:O the:O oven:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O the:O sound:B-onofffeature more:O quickly:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature more:O quickly:O on:O the:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O on:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O on:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O my:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O on:O wifi:B-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O sound:B-onofffeature oven:B-appliance now:O <=> on_off
#
# how:O to:O turn:O sound:B-onofffeature microwavawe:B-appliance now:O <=> on_off
#
# how:O to:O turn:O wifi:B-onofffeature microwavawe:B-appliance now:O <=> on_off
#
# how:O can:O i:O deactivate:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O my:O oven:B-appliance by:O day:O <=> on_off
#
# how:O can:O i:O deactivate:O sound:B-onofffeature on:O my:O microwavawe:B-appliance by:O day:O <=> on_off
#
# how:O can:O i:O deactivate:O sound:B-onofffeature on:O my:O oven:B-appliance by:O day:O <=> on_off
#
# how:O can:O i:O turn:O the:O sound:B-onofffeature on:O on:O the:O oven:B-appliance <=> on_off
#
# how:O can:O i:O turn:O the:O wifi:B-onofffeature on:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O on:O the:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O way:O to:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O way:O to:O turn:O off:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# what:O is:O the:O way:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# how:O is:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O is:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O is:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O can:O i:O activate:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O activate:O the:O wifi:B-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O activate:O the:O wifi:B-onofffeature oven:B-appliance <=> on_off
#
# how:O to:O turn:O on:O wifi:B-onofffeature in:O my:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O on:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O my:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O on:O wifi:B-onofffeature in:O my:O oven:B-appliance <=> on_off
#
# i:O want:O to:O turn:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# i:O want:O to:O turn:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# i:O want:O to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# is:O it:O possible:O to:O turn:O on:O sound:B-onofffeature on:O my:O favorite:O oven:B-appliance <=> on_off
#
# is:O it:O possible:O to:O turn:O on:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O my:O favorite:O oven:B-appliance <=> on_off
#
# is:O it:O possible:O to:O turn:O on:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O my:O favorite:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O start:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance app:O <=> on_off
#
# how:O can:O i:O start:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance app:O <=> on_off
#
# how:O can:O i:O start:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance app:O <=> on_off
#
# turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# turn:O on:O the:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# show:O me:O the:O way:O to:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# show:O me:O the:O way:O to:O turn:O on:O the:O sound:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# show:O me:O the:O way:O to:O turn:O on:O the:O sound:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# how:O do:O i:O quickly:O turn:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O quickly:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# how:O do:O i:O quickly:O turn:O off:O the:O sound:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# now:O sir:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# now:O sir:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# now:O sir:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O change:O my:O sound:B-onofffeature microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O change:O my:O sound:B-onofffeature oven:B-appliance <=> on_off
#
# how:O can:O i:O change:O my:O sound:B-onofffeature microwavawe:B-appliance <=> on_off
#
# the:O wifi:B-onofffeature is:O not:O turned:O off:O with:O oven:B-appliance <=> on_off
#
# the:O sound:B-onofffeature is:O not:O turned:O off:O with:O microwavawe:B-appliance <=> on_off
#
# the:O sound:B-onofffeature is:O not:O turned:O off:O with:O microwavawe:B-appliance <=> on_off
#
# do:O you:O need:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# do:O you:O need:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# do:O you:O need:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance <=> on_off
#
# greetings:O how:O to:O turn:O sound:B-onofffeature a:O feature:O on:O an:O microwavawe:B-appliance <=> on_off
#
# greetings:O how:O to:O turn:O wifi:B-onofffeature a:O feature:O on:O an:O oven:B-appliance <=> on_off
#
# greetings:O how:O to:O turn:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature a:O feature:O on:O an:O oven:B-appliance <=> on_off
#
# cars:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# cars:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# cars:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# where:O to:O turn:O a:O feature:O on:O an:O wifi:B-onofffeature oven:B-appliance 2:O <=> on_off
#
# where:O to:O turn:O a:O feature:O on:O an:O wifi:B-onofffeature oven:B-appliance 2:O <=> on_off
#
# where:O to:O turn:O a:O feature:O on:O an:O sound:B-onofffeature microwavawe:B-appliance 2:O <=> on_off
#
# the:O why:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# the:O why:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# the:O why:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# im:O asking:O myself:O now:O how:O do:O i:O switch:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# im:O asking:O myself:O now:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# im:O asking:O myself:O now:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O does:O it:O work:O sound:B-onofffeature oven:B-appliance <=> on_off
#
# how:O does:O it:O work:O wifi:B-onofffeature oven:B-appliance <=> on_off
#
# how:O does:O it:O work:O wifi:B-onofffeature oven:B-appliance <=> on_off
#
# honey:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# honey:O how:O do:O i:O switch:O the:O sound:B-onofffeature off:O on:O the:O microwavawe:B-appliance <=> on_off
#
# honey:O how:O do:O i:O switch:O the:O wifi:B-onofffeature off:O on:O the:O oven:B-appliance <=> on_off
#
# i:O need:O switch:O off:O the:O sound:B-onofffeature in:O microwavawe:B-appliance <=> on_off
#
# i:O need:O switch:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O microwavawe:B-appliance <=> on_off
#
# i:O need:O switch:O off:O the:O wifi:B-onofffeature in:O oven:B-appliance <=> on_off
#
# when:O i:O turn:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# when:O i:O turn:O sound:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# when:O i:O turn:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O on:O the:O wifi:B-onofffeature of:O my:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature of:O my:O microwavawe:B-appliance <=> on_off
#
# how:O can:O i:O turn:O on:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature of:O my:O microwavawe:B-appliance <=> on_off
#
# i:O activate:O the:O wifi:B-onofffeature in:O the:O oven:B-appliance explain:O to:O me:O <=> on_off
#
# i:O activate:O the:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance explain:O to:O me:O <=> on_off
#
# i:O activate:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O oven:B-appliance explain:O to:O me:O <=> on_off
#
# how:O to:O turn:O off:O a:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O an:O microwavawe:B-appliance <=> on_off
#
# how:O to:O turn:O off:O a:O sound:B-onofffeature on:O an:O oven:B-appliance <=> on_off
#
# how:O to:O turn:O off:O a:O sound:B-onofffeature on:O an:O microwavawe:B-appliance <=> on_off
#
# as:O requested:O by:O sound:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# as:O requested:O by:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# as:O requested:O by:O wifi:B-onofffeature in:O the:O microwavawe:B-appliance <=> on_off
#
# to:O turn:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# to:O turn:O off:O the:O wifi:B-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
#
# to:O turn:O off:O the:O sound:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O to:O switch:O off:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O to:O switch:O off:O the:O wifi:B-onofffeature on:O the:O oven:B-appliance <=> on_off
#
# can:O you:O tell:O me:O how:O to:O switch:O off:O the:O self:B-onofffeature cleaning:I-onofffeature cycle:I-onofffeature on:O the:O microwavawe:B-appliance <=> on_off
